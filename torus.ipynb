# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy import optimize, special
from numpy import *
from pylab import *
import decimal
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as pl

E=0.06
plt.style.use("seaborn-whitegrid")
n=500000
h=500/n
dt=0
xo=np.zeros(n+1,dtype='float64')
yo=np.zeros(n+1,dtype='float64')
pxo=np.zeros(n+1,dtype='float64')
pyo=np.zeros(n+1,dtype='float64')
Yo=np.zeros(n+1,dtype='float64')
PYo=np.zeros(n+1,dtype='float64')
xl=np.zeros(n+1,dtype='float64')
yl=np.zeros(n+1,dtype='float64')
pxl=np.zeros(n+1,dtype='float64')
pyl=np.zeros(n+1,dtype='float64')
Yl=np.zeros(n+1,dtype='float64')
PYl=np.zeros(n+1,dtype='float64')
xu=np.zeros(n+1,dtype='float64')
yu=np.zeros(n+1,dtype='float64')
pxu=np.zeros(n+1,dtype='float64')
pyu=np.zeros(n+1,dtype='float64')
Yu=np.zeros(n+1,dtype='float64')
PYu=np.zeros(n+1,dtype='float64')
xd=np.zeros(n+1,dtype='float64')
yd=np.zeros(n+1,dtype='float64')
pxd=np.zeros(n+1,dtype='float64')
pyd=np.zeros(n+1,dtype='float64')
Yd=np.zeros(n+1,dtype='float64')
PYd=np.zeros(n+1,dtype='float64')
xb=np.zeros(n+1,dtype='float64')
yb=np.zeros(n+1,dtype='float64')
pxb=np.zeros(n+1,dtype='float64')
pyb=np.zeros(n+1,dtype='float64')
Yb=np.zeros(n+1,dtype='float64')
PYb=np.zeros(n+1,dtype='float64')
i=0
xo[i]=0
yo[i]=-0.1475
pyo[i]=0
pxo[i]=(2*E-(pyo[i]**2)-(xo[i]**2)-(yo[i]**2)-2*(xo[i]**2)*yo[i]+(2*(yo[i]**3)/3))**(1/2)
i=i+1
print(pxo[0])

        
while i<=n:
    
    k11o=pxo[i-1]
    k12o=pyo[i-1]
    k13o=(-1)*xo[i-1]-2*xo[i-1]*yo[i-1]
    k14o=(-1)*yo[i-1]-(xo[i-1]**2)+(yo[i-1]**2)
    x1o=xo[i-1]+(h/2)*k11o
    y1o=yo[i-1]+(h/2)*k12o
    px1o=pxo[i-1]+(h/2)*k13o
    py1o=pyo[i-1]+(h/2)*k14o
    k21o=px1o
    k22o=py1o
    k23o=(-1)*x1o-2*(x1o)*(y1o)
    k24o=(-1)*y1o-((x1o)**2)+((y1o)**2)
    x2o=xo[i-1]+(h/2)*k21o
    y2o=yo[i-1]+(h/2)*k22o
    px2o=pxo[i-1]+(h/2)*k23o
    py2o=pyo[i-1]+(h/2)*k24o
    k31o=px2o
    k32o=py2o
    k33o=(-1)*x2o-2*(x2o)*(y2o)
    k34o=(-1)*y2o-((x2o)**2)+((y2o)**2)
    x3o=xo[i-1]+h*k31o
    y3o=yo[i-1]+h*k32o
    px3o=pxo[i-1]+h*k33o
    py3o=pyo[i-1]+h*k34o
    k41o=px3o
    k42o=py3o
    k43o=(-1)*x3o-2*(x3o)*(y3o)
    k44o=(-1)*y3o-((x3o)**2)+((y3o)**2)
    k1o=(1/6)*(k11o+2*k21o+2*k31o+k41o)
    k2o=(1/6)*(k12o+2*k22o+2*k32o+k42o)
    k3o=(1/6)*(k13o+2*k23o+2*k33o+k43o)
    k4o=(1/6)*(k14o+2*k24o+2*k34o+k44o)
    xo[i]=xo[i-1]+k1o*h
    yo[i]=yo[i-1]+k2o*h 
    pxo[i]=pxo[i-1]+k3o*h
    pyo[i]=pyo[i-1]+k4o*h
    
    if xo[i]*xo[i-1]<0 and pxo[i]>0 and pxo[i-1]>0:
            dt=-xo[i-1]/k1o
            xo[i]=0
            Yo[i]=(yo[i-1]+k2o*dt)
            PYo[i]=(pyo[i-1]+k4o*dt)
            i=i+1
    else:
            Yo[i]=0
            PYo[i]=0
            i=i+1
else :           
    plt.scatter(Yo,PYo,s=1)
    
plt.show()
# Out:
# 0.310007073171995

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy import optimize, special
from numpy import *
from pylab import *
import decimal
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as pl

E=1/12
plt.style.use("seaborn-whitegrid")
n=500000
h=500/n
dt=0
xo=np.zeros(n+1,dtype='float64')
yo=np.zeros(n+1,dtype='float64')
pxo=np.zeros(n+1,dtype='float64')
pyo=np.zeros(n+1,dtype='float64')
Yo=np.zeros(n+1,dtype='float64')
PYo=np.zeros(n+1,dtype='float64')
xl=np.zeros(n+1,dtype='float64')
yl=np.zeros(n+1,dtype='float64')
pxl=np.zeros(n+1,dtype='float64')
pyl=np.zeros(n+1,dtype='float64')
Yl=np.zeros(n+1,dtype='float64')
PYl=np.zeros(n+1,dtype='float64')
xu=np.zeros(n+1,dtype='float64')
yu=np.zeros(n+1,dtype='float64')
pxu=np.zeros(n+1,dtype='float64')
pyu=np.zeros(n+1,dtype='float64')
Yu=np.zeros(n+1,dtype='float64')
PYu=np.zeros(n+1,dtype='float64')
xd=np.zeros(n+1,dtype='float64')
yd=np.zeros(n+1,dtype='float64')
pxd=np.zeros(n+1,dtype='float64')
pyd=np.zeros(n+1,dtype='float64')
Yd=np.zeros(n+1,dtype='float64')
PYd=np.zeros(n+1,dtype='float64')
xb=np.zeros(n+1,dtype='float64')
yb=np.zeros(n+1,dtype='float64')
pxb=np.zeros(n+1,dtype='float64')
pyb=np.zeros(n+1,dtype='float64')
Yb=np.zeros(n+1,dtype='float64')
PYb=np.zeros(n+1,dtype='float64')
i=0
xo[i]=0
yo[i]=0
pyo[i]=0
pxo[i]=-(2*E-(pyo[i]**2)-(xo[i]**2)-(yo[i]**2)-2*(xo[i]**2)*yo[i]+(2*(yo[i]**3)/3))**(1/2)
i=i+1
print(pxo[0])

        
while i<=n:
    
    k11o=pxo[i-1]
    k12o=pyo[i-1]
    k13o=(-1)*xo[i-1]-2*xo[i-1]*yo[i-1]
    k14o=(-1)*yo[i-1]-(xo[i-1]**2)+(yo[i-1]**2)
    x1o=xo[i-1]+(h/2)*k11o
    y1o=yo[i-1]+(h/2)*k12o
    px1o=pxo[i-1]+(h/2)*k13o
    py1o=pyo[i-1]+(h/2)*k14o
    k21o=px1o
    k22o=py1o
    k23o=(-1)*x1o-2*(x1o)*(y1o)
    k24o=(-1)*y1o-((x1o)**2)+((y1o)**2)
    x2o=xo[i-1]+(h/2)*k21o
    y2o=yo[i-1]+(h/2)*k22o
    px2o=pxo[i-1]+(h/2)*k23o
    py2o=pyo[i-1]+(h/2)*k24o
    k31o=px2o
    k32o=py2o
    k33o=(-1)*x2o-2*(x2o)*(y2o)
    k34o=(-1)*y2o-((x2o)**2)+((y2o)**2)
    x3o=xo[i-1]+h*k31o
    y3o=yo[i-1]+h*k32o
    px3o=pxo[i-1]+h*k33o
    py3o=pyo[i-1]+h*k34o
    k41o=px3o
    k42o=py3o
    k43o=(-1)*x3o-2*(x3o)*(y3o)
    k44o=(-1)*y3o-((x3o)**2)+((y3o)**2)
    k1o=(1/6)*(k11o+2*k21o+2*k31o+k41o)
    k2o=(1/6)*(k12o+2*k22o+2*k32o+k42o)
    k3o=(1/6)*(k13o+2*k23o+2*k33o+k43o)
    k4o=(1/6)*(k14o+2*k24o+2*k34o+k44o)
    xo[i]=xo[i-1]+k1o*h
    yo[i]=yo[i-1]+k2o*h 
    pxo[i]=pxo[i-1]+k3o*h
    pyo[i]=pyo[i-1]+k4o*h
    
    if xo[i]*xo[i-1]<0 and pxo[i]<0 and pxo[i-1]<0:
            dt=-xo[i-1]/k1o
            xo[i]=0
            Yo[i]=(yo[i-1]+k2o*dt)
            PYo[i]=(pyo[i-1]+k4o*dt)
            i=i+1
    else:
            Yo[i]=0
            PYo[i]=0
            i=i+1
else :           
    plt.scatter(Yo,PYo,s=1)
    
plt.show()
# Out:
# -0.408248290463863

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy import optimize, special
from numpy import *
from pylab import *
import decimal
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as pl

E=0.06
plt.style.use("seaborn-whitegrid")
n=50000
h=500/n
dt=0
xo=np.zeros(n+1,dtype='float64')
yo=np.zeros(n+1,dtype='float64')
pxo=np.zeros(n+1,dtype='float64')
pyo=np.zeros(n+1,dtype='float64')
Yo=np.zeros(n+1,dtype='float64')
PYo=np.zeros(n+1,dtype='float64')
xl=np.zeros(n+1,dtype='float64')
yl=np.zeros(n+1,dtype='float64')
pxl=np.zeros(n+1,dtype='float64')
pyl=np.zeros(n+1,dtype='float64')
Yl=np.zeros(n+1,dtype='float64')
PYl=np.zeros(n+1,dtype='float64')
X=np.zeros(n+1,dtype='float64')
i=0
xo[i]=0
yo[i]=0.405542
pyo[i]=0
pxo[i]=(2*E-(pyo[i]**2)-(xo[i]**2)-(yo[i]**2)-2*(xo[i]**2)*yo[i]+(2*(yo[i]**3)/3))**(1/2)
i=i+1
print(pxo[0])

        
while i<=n:
    
    k11o=pxo[i-1]
    k12o=pyo[i-1]
    k13o=(-1)*xo[i-1]-2*xo[i-1]*yo[i-1]
    k14o=(-1)*yo[i-1]-(xo[i-1]**2)+(yo[i-1]**2)
    x1o=xo[i-1]+(h/2)*k11o
    y1o=yo[i-1]+(h/2)*k12o
    px1o=pxo[i-1]+(h/2)*k13o
    py1o=pyo[i-1]+(h/2)*k14o
    k21o=px1o
    k22o=py1o
    k23o=(-1)*x1o-2*(x1o)*(y1o)
    k24o=(-1)*y1o-((x1o)**2)+((y1o)**2)
    x2o=xo[i-1]+(h/2)*k21o
    y2o=yo[i-1]+(h/2)*k22o
    px2o=pxo[i-1]+(h/2)*k23o
    py2o=pyo[i-1]+(h/2)*k24o
    k31o=px2o
    k32o=py2o
    k33o=(-1)*x2o-2*(x2o)*(y2o)
    k34o=(-1)*y2o-((x2o)**2)+((y2o)**2)
    x3o=xo[i-1]+h*k31o
    y3o=yo[i-1]+h*k32o
    px3o=pxo[i-1]+h*k33o
    py3o=pyo[i-1]+h*k34o
    k41o=px3o
    k42o=py3o
    k43o=(-1)*x3o-2*(x3o)*(y3o)
    k44o=(-1)*y3o-((x3o)**2)+((y3o)**2)
    k1o=(1/6)*(k11o+2*k21o+2*k31o+k41o)
    k2o=(1/6)*(k12o+2*k22o+2*k32o+k42o)
    k3o=(1/6)*(k13o+2*k23o+2*k33o+k43o)
    k4o=(1/6)*(k14o+2*k24o+2*k34o+k44o)
    xo[i]=xo[i-1]+k1o*h
    yo[i]=yo[i-1]+k2o*h 
    pxo[i]=pxo[i-1]+k3o*h
    pyo[i]=pyo[i-1]+k4o*h
    
    if xo[i]*xo[i-1]<0:
            dt=-xo[i-1]/k1o
            
            Yo[i]=(yo[i-1]+k2o*dt)
            PYo[i]=(pyo[i-1]+k4o*dt)
            i=i+1
    else:
            Yo[i]=0
            PYo[i]=0
            i=i+1
else :  
    fig = plt.figure()
    ax = Axes3D(fig)
    
    ax.plot(yo,xo,pyo,c='orange',alpha=0.6)
    ax.scatter(Yo,X,PYo,c='k',s=5)
    ax.set_xlabel('Y')
    ax.set_ylabel('X')
    ax.set_zlabel('PY')
plt.show()
# Out:
# 0.0006909348643113139

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy import optimize, special
from numpy import *
from pylab import *
import decimal
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as pl

E=0.06
plt.style.use("seaborn-whitegrid")
n=50000
h=500/n
dt=0
xo=np.zeros(n+1,dtype='float64')
yo=np.zeros(n+1,dtype='float64')
pxo=np.zeros(n+1,dtype='float64')
pyo=np.zeros(n+1,dtype='float64')
Yo=np.zeros(n+1,dtype='float64')
PYo=np.zeros(n+1,dtype='float64')
xl=np.zeros(n+1,dtype='float64')
yl=np.zeros(n+1,dtype='float64')
pxl=np.zeros(n+1,dtype='float64')
pyl=np.zeros(n+1,dtype='float64')
Yl=np.zeros(n+1,dtype='float64')
PYl=np.zeros(n+1,dtype='float64')
X=np.zeros(n+1,dtype='float64')
cmaps = [('Perceptually Uniform Sequential',  
                            ['viridis', 'inferno', 'plasma', 'magma']),  
         ('Sequential',     ['Blues', 'BuGn', 'BuPu',  
                             'GnBu', 'Greens', 'Greys', 'Oranges', 'OrRd',  
                             'PuBu', 'PuBuGn', 'PuRd', 'Purples', 'RdPu',  
                             'Reds', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd']),  
         ('Sequential (2)', ['afmhot', 'autumn', 'bone', 'cool',  
                             'copper', 'gist_heat', 'gray', 'hot',  
                             'pink', 'spring', 'summer', 'winter']),  
         ('Diverging',      ['BrBG', 'bwr', 'coolwarm', 'PiYG', 'PRGn', 'PuOr',  
                             'RdBu', 'RdGy', 'RdYlBu', 'RdYlGn', 'Spectral',  
                             'seismic']),  
         ('Qualitative',    ['Accent', 'Dark2', 'Paired', 'Pastel1',  
                             'Pastel2', 'Set1', 'Set2', 'Set3']),  
         ('Miscellaneous',  ['gist_earth', 'terrain', 'ocean', 'gist_stern',  
                             'brg', 'CMRmap', 'cubehelix',  
                             'gnuplot', 'gnuplot2', 'gist_ncar',  
                             'nipy_spectral', 'jet', 'rainbow',  
                             'gist_rainbow', 'hsv', 'flag', 'prism'])]  

i=0
xo[i]=0
yo[i]=0.405542
pyo[i]=0
pxo[i]=(2*E-(pyo[i]**2)-(xo[i]**2)-(yo[i]**2)-2*(xo[i]**2)*yo[i]+(2*(yo[i]**3)/3))**(1/2)
i=i+1
print(pxo[0])

        
while i<=n:
    
    k11o=pxo[i-1]
    k12o=pyo[i-1]
    k13o=(-1)*xo[i-1]-2*xo[i-1]*yo[i-1]
    k14o=(-1)*yo[i-1]-(xo[i-1]**2)+(yo[i-1]**2)
    x1o=xo[i-1]+(h/2)*k11o
    y1o=yo[i-1]+(h/2)*k12o
    px1o=pxo[i-1]+(h/2)*k13o
    py1o=pyo[i-1]+(h/2)*k14o
    k21o=px1o
    k22o=py1o
    k23o=(-1)*x1o-2*(x1o)*(y1o)
    k24o=(-1)*y1o-((x1o)**2)+((y1o)**2)
    x2o=xo[i-1]+(h/2)*k21o
    y2o=yo[i-1]+(h/2)*k22o
    px2o=pxo[i-1]+(h/2)*k23o
    py2o=pyo[i-1]+(h/2)*k24o
    k31o=px2o
    k32o=py2o
    k33o=(-1)*x2o-2*(x2o)*(y2o)
    k34o=(-1)*y2o-((x2o)**2)+((y2o)**2)
    x3o=xo[i-1]+h*k31o
    y3o=yo[i-1]+h*k32o
    px3o=pxo[i-1]+h*k33o
    py3o=pyo[i-1]+h*k34o
    k41o=px3o
    k42o=py3o
    k43o=(-1)*x3o-2*(x3o)*(y3o)
    k44o=(-1)*y3o-((x3o)**2)+((y3o)**2)
    k1o=(1/6)*(k11o+2*k21o+2*k31o+k41o)
    k2o=(1/6)*(k12o+2*k22o+2*k32o+k42o)
    k3o=(1/6)*(k13o+2*k23o+2*k33o+k43o)
    k4o=(1/6)*(k14o+2*k24o+2*k34o+k44o)
    xo[i]=xo[i-1]+k1o*h
    yo[i]=yo[i-1]+k2o*h 
    pxo[i]=pxo[i-1]+k3o*h
    pyo[i]=pyo[i-1]+k4o*h
    
    if xo[i]*xo[i-1]<0:
            dt=-xo[i-1]/k1o
            
            Yo[i]=(yo[i-1]+k2o*dt)
            PYo[i]=(pyo[i-1]+k4o*dt)
            i=i+1
    else:
            Yo[i]=0
            PYo[i]=0
            i=i+1
else :  
    fig = plt.figure()
    ax = Axes3D(fig)
    
    ax.scatter(yo,xo,pyo,c=xo,cmap=plt.cm.gist_rainbow,alpha=0.15,s=0.3)
    ax.scatter(Yo,X,PYo,c='k',s=5)
    ax.set_xlabel('Y')
    ax.set_ylabel('X')
    ax.set_zlabel('PY')
plt.savefig("D:/temp6.png")
plt.show()
# Out:
# 0.0006909348643113139

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy import optimize, special
from numpy import *
from pylab import *
import decimal
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as pl

E=0.06
plt.style.use("seaborn-whitegrid")
n=50000
h=500/n
dt=0
xo=np.zeros(n+1,dtype='float64')
yo=np.zeros(n+1,dtype='float64')
pxo=np.zeros(n+1,dtype='float64')
pyo=np.zeros(n+1,dtype='float64')
Yo=np.zeros(n+1,dtype='float64')
PYo=np.zeros(n+1,dtype='float64')
X=np.zeros(n+1,dtype='float64')
cmaps = [('Perceptually Uniform Sequential',  
                            ['viridis', 'inferno', 'plasma', 'magma']),  
         ('Sequential',     ['Blues', 'BuGn', 'BuPu',  
                             'GnBu', 'Greens', 'Greys', 'Oranges', 'OrRd',  
                             'PuBu', 'PuBuGn', 'PuRd', 'Purples', 'RdPu',  
                             'Reds', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd']),  
         ('Sequential (2)', ['afmhot', 'autumn', 'bone', 'cool',  
                             'copper', 'gist_heat', 'gray', 'hot',  
                             'pink', 'spring', 'summer', 'winter']),  
         ('Diverging',      ['BrBG', 'bwr', 'coolwarm', 'PiYG', 'PRGn', 'PuOr',  
                             'RdBu', 'RdGy', 'RdYlBu', 'RdYlGn', 'Spectral',  
                             'seismic']),  
         ('Qualitative',    ['Accent', 'Dark2', 'Paired', 'Pastel1',  
                             'Pastel2', 'Set1', 'Set2', 'Set3']),  
         ('Miscellaneous',  ['gist_earth', 'terrain', 'ocean', 'gist_stern',  
                             'brg', 'CMRmap', 'cubehelix',  
                             'gnuplot', 'gnuplot2', 'gist_ncar',  
                             'nipy_spectral', 'jet', 'rainbow',  
                             'gist_rainbow', 'hsv', 'flag', 'prism'])]  

i=0
xo[i]=0
yo[i]=-0.1475
pyo[i]=0
pxo[i]=(2*E-(pyo[i]**2)-(xo[i]**2)-(yo[i]**2)-2*(xo[i]**2)*yo[i]+(2*(yo[i]**3)/3))**(1/2)
i=i+1
print(pxo[0])

        
while i<=n:
    
    k11o=pxo[i-1]
    k12o=pyo[i-1]
    k13o=(-1)*xo[i-1]-2*xo[i-1]*yo[i-1]
    k14o=(-1)*yo[i-1]-(xo[i-1]**2)+(yo[i-1]**2)
    x1o=xo[i-1]+(h/2)*k11o
    y1o=yo[i-1]+(h/2)*k12o
    px1o=pxo[i-1]+(h/2)*k13o
    py1o=pyo[i-1]+(h/2)*k14o
    k21o=px1o
    k22o=py1o
    k23o=(-1)*x1o-2*(x1o)*(y1o)
    k24o=(-1)*y1o-((x1o)**2)+((y1o)**2)
    x2o=xo[i-1]+(h/2)*k21o
    y2o=yo[i-1]+(h/2)*k22o
    px2o=pxo[i-1]+(h/2)*k23o
    py2o=pyo[i-1]+(h/2)*k24o
    k31o=px2o
    k32o=py2o
    k33o=(-1)*x2o-2*(x2o)*(y2o)
    k34o=(-1)*y2o-((x2o)**2)+((y2o)**2)
    x3o=xo[i-1]+h*k31o
    y3o=yo[i-1]+h*k32o
    px3o=pxo[i-1]+h*k33o
    py3o=pyo[i-1]+h*k34o
    k41o=px3o
    k42o=py3o
    k43o=(-1)*x3o-2*(x3o)*(y3o)
    k44o=(-1)*y3o-((x3o)**2)+((y3o)**2)
    k1o=(1/6)*(k11o+2*k21o+2*k31o+k41o)
    k2o=(1/6)*(k12o+2*k22o+2*k32o+k42o)
    k3o=(1/6)*(k13o+2*k23o+2*k33o+k43o)
    k4o=(1/6)*(k14o+2*k24o+2*k34o+k44o)
    xo[i]=xo[i-1]+k1o*h
    yo[i]=yo[i-1]+k2o*h 
    pxo[i]=pxo[i-1]+k3o*h
    pyo[i]=pyo[i-1]+k4o*h
    
    if xo[i]*xo[i-1]<0:
            dt=-xo[i-1]/k1o
            
            Yo[i]=(yo[i-1]+k2o*dt)
            PYo[i]=(pyo[i-1]+k4o*dt)
            i=i+1
    else:
            Yo[i]=0
            PYo[i]=0
            i=i+1
else :  
    fig = plt.figure()
    ax = Axes3D(fig)
    
    ax.scatter(yo,xo,pyo,c=xo,cmap=plt.cm.gist_rainbow,alpha=0.15,s=0.3)
    ax.scatter(Yo,X,PYo,c='k',s=3)
    ax.set_xlabel('Y')
    ax.set_ylabel('X')
    ax.set_zlabel('PY')
plt.savefig("D:/temp5.png")
plt.show()
# Out:
# 0.310007073171995

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy import optimize, special
from numpy import *
from pylab import *
import decimal
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as pl

E=1/12
plt.style.use("seaborn-whitegrid")
n=50000
h=500/n
dt=0
xo=np.zeros(n+1,dtype='float64')
yo=np.zeros(n+1,dtype='float64')
pxo=np.zeros(n+1,dtype='float64')
pyo=np.zeros(n+1,dtype='float64')
Yo=np.zeros(n+1,dtype='float64')
PYo=np.zeros(n+1,dtype='float64')
X=np.zeros(n+1,dtype='float64')
cmaps = [('Perceptually Uniform Sequential',  
                            ['viridis', 'inferno', 'plasma', 'magma']),  
         ('Sequential',     ['Blues', 'BuGn', 'BuPu',  
                             'GnBu', 'Greens', 'Greys', 'Oranges', 'OrRd',  
                             'PuBu', 'PuBuGn', 'PuRd', 'Purples', 'RdPu',  
                             'Reds', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd']),  
         ('Sequential (2)', ['afmhot', 'autumn', 'bone', 'cool',  
                             'copper', 'gist_heat', 'gray', 'hot',  
                             'pink', 'spring', 'summer', 'winter']),  
         ('Diverging',      ['BrBG', 'bwr', 'coolwarm', 'PiYG', 'PRGn', 'PuOr',  
                             'RdBu', 'RdGy', 'RdYlBu', 'RdYlGn', 'Spectral',  
                             'seismic']),  
         ('Qualitative',    ['Accent', 'Dark2', 'Paired', 'Pastel1',  
                             'Pastel2', 'Set1', 'Set2', 'Set3']),  
         ('Miscellaneous',  ['gist_earth', 'terrain', 'ocean', 'gist_stern',  
                             'brg', 'CMRmap', 'cubehelix',  
                             'gnuplot', 'gnuplot2', 'gist_ncar',  
                             'nipy_spectral', 'jet', 'rainbow',  
                             'gist_rainbow', 'hsv', 'flag', 'prism'])]  

i=0
xo[i]=0
yo[i]=-0.1475
pyo[i]=0
pxo[i]=(2*E-(pyo[i]**2)-(xo[i]**2)-(yo[i]**2)-2*(xo[i]**2)*yo[i]+(2*(yo[i]**3)/3))**(1/2)
i=i+1
print(pxo[0])

        
while i<=n:
    
    k11o=pxo[i-1]
    k12o=pyo[i-1]
    k13o=(-1)*xo[i-1]-2*xo[i-1]*yo[i-1]
    k14o=(-1)*yo[i-1]-(xo[i-1]**2)+(yo[i-1]**2)
    x1o=xo[i-1]+(h/2)*k11o
    y1o=yo[i-1]+(h/2)*k12o
    px1o=pxo[i-1]+(h/2)*k13o
    py1o=pyo[i-1]+(h/2)*k14o
    k21o=px1o
    k22o=py1o
    k23o=(-1)*x1o-2*(x1o)*(y1o)
    k24o=(-1)*y1o-((x1o)**2)+((y1o)**2)
    x2o=xo[i-1]+(h/2)*k21o
    y2o=yo[i-1]+(h/2)*k22o
    px2o=pxo[i-1]+(h/2)*k23o
    py2o=pyo[i-1]+(h/2)*k24o
    k31o=px2o
    k32o=py2o
    k33o=(-1)*x2o-2*(x2o)*(y2o)
    k34o=(-1)*y2o-((x2o)**2)+((y2o)**2)
    x3o=xo[i-1]+h*k31o
    y3o=yo[i-1]+h*k32o
    px3o=pxo[i-1]+h*k33o
    py3o=pyo[i-1]+h*k34o
    k41o=px3o
    k42o=py3o
    k43o=(-1)*x3o-2*(x3o)*(y3o)
    k44o=(-1)*y3o-((x3o)**2)+((y3o)**2)
    k1o=(1/6)*(k11o+2*k21o+2*k31o+k41o)
    k2o=(1/6)*(k12o+2*k22o+2*k32o+k42o)
    k3o=(1/6)*(k13o+2*k23o+2*k33o+k43o)
    k4o=(1/6)*(k14o+2*k24o+2*k34o+k44o)
    xo[i]=xo[i-1]+k1o*h
    yo[i]=yo[i-1]+k2o*h 
    pxo[i]=pxo[i-1]+k3o*h
    pyo[i]=pyo[i-1]+k4o*h
    
    if xo[i]*xo[i-1]<0:
            dt=-xo[i-1]/k1o
            
            Yo[i]=(yo[i-1]+k2o*dt)
            PYo[i]=(pyo[i-1]+k4o*dt)
            i=i+1
    else:
            Yo[i]=0
            PYo[i]=0
            i=i+1
else :  
    fig = plt.figure()
    ax = Axes3D(fig)
    
    ax.scatter(yo,xo,pyo,c=xo,cmap=plt.cm.gist_rainbow,alpha=0.15,s=0.3)
    ax.scatter(Yo,X,PYo,c='k',s=3)
    ax.set_xlabel('Y')
    ax.set_ylabel('X')
    ax.set_zlabel('PY')
    
plt.savefig("D:/temp4.png")
plt.show()
# Out:
# 0.37785056845707315

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy import optimize, special
from numpy import *
from pylab import *
import decimal
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as pl

E=1/8
plt.style.use("seaborn-whitegrid")
n=50000
h=500/n
dt=0
xo=np.zeros(n+1,dtype='float64')
yo=np.zeros(n+1,dtype='float64')
pxo=np.zeros(n+1,dtype='float64')
pyo=np.zeros(n+1,dtype='float64')
Yo=np.zeros(n+1,dtype='float64')
PYo=np.zeros(n+1,dtype='float64')
X=np.zeros(n+1,dtype='float64')
cmaps = [('Perceptually Uniform Sequential',  
                            ['viridis', 'inferno', 'plasma', 'magma']),  
         ('Sequential',     ['Blues', 'BuGn', 'BuPu',  
                             'GnBu', 'Greens', 'Greys', 'Oranges', 'OrRd',  
                             'PuBu', 'PuBuGn', 'PuRd', 'Purples', 'RdPu',  
                             'Reds', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd']),  
         ('Sequential (2)', ['afmhot', 'autumn', 'bone', 'cool',  
                             'copper', 'gist_heat', 'gray', 'hot',  
                             'pink', 'spring', 'summer', 'winter']),  
         ('Diverging',      ['BrBG', 'bwr', 'coolwarm', 'PiYG', 'PRGn', 'PuOr',  
                             'RdBu', 'RdGy', 'RdYlBu', 'RdYlGn', 'Spectral',  
                             'seismic']),  
         ('Qualitative',    ['Accent', 'Dark2', 'Paired', 'Pastel1',  
                             'Pastel2', 'Set1', 'Set2', 'Set3']),  
         ('Miscellaneous',  ['gist_earth', 'terrain', 'ocean', 'gist_stern',  
                             'brg', 'CMRmap', 'cubehelix',  
                             'gnuplot', 'gnuplot2', 'gist_ncar',  
                             'nipy_spectral', 'jet', 'rainbow',  
                             'gist_rainbow', 'hsv', 'flag', 'prism'])]  

i=0
xo[i]=0
yo[i]=-0.1475
pyo[i]=0
pxo[i]=(2*E-(pyo[i]**2)-(xo[i]**2)-(yo[i]**2)-2*(xo[i]**2)*yo[i]+(2*(yo[i]**3)/3))**(1/2)
i=i+1
print(pxo[0])

        
while i<=n:
    
    k11o=pxo[i-1]
    k12o=pyo[i-1]
    k13o=(-1)*xo[i-1]-2*xo[i-1]*yo[i-1]
    k14o=(-1)*yo[i-1]-(xo[i-1]**2)+(yo[i-1]**2)
    x1o=xo[i-1]+(h/2)*k11o
    y1o=yo[i-1]+(h/2)*k12o
    px1o=pxo[i-1]+(h/2)*k13o
    py1o=pyo[i-1]+(h/2)*k14o
    k21o=px1o
    k22o=py1o
    k23o=(-1)*x1o-2*(x1o)*(y1o)
    k24o=(-1)*y1o-((x1o)**2)+((y1o)**2)
    x2o=xo[i-1]+(h/2)*k21o
    y2o=yo[i-1]+(h/2)*k22o
    px2o=pxo[i-1]+(h/2)*k23o
    py2o=pyo[i-1]+(h/2)*k24o
    k31o=px2o
    k32o=py2o
    k33o=(-1)*x2o-2*(x2o)*(y2o)
    k34o=(-1)*y2o-((x2o)**2)+((y2o)**2)
    x3o=xo[i-1]+h*k31o
    y3o=yo[i-1]+h*k32o
    px3o=pxo[i-1]+h*k33o
    py3o=pyo[i-1]+h*k34o
    k41o=px3o
    k42o=py3o
    k43o=(-1)*x3o-2*(x3o)*(y3o)
    k44o=(-1)*y3o-((x3o)**2)+((y3o)**2)
    k1o=(1/6)*(k11o+2*k21o+2*k31o+k41o)
    k2o=(1/6)*(k12o+2*k22o+2*k32o+k42o)
    k3o=(1/6)*(k13o+2*k23o+2*k33o+k43o)
    k4o=(1/6)*(k14o+2*k24o+2*k34o+k44o)
    xo[i]=xo[i-1]+k1o*h
    yo[i]=yo[i-1]+k2o*h 
    pxo[i]=pxo[i-1]+k3o*h
    pyo[i]=pyo[i-1]+k4o*h
    
    if xo[i]*xo[i-1]<0:
            dt=-xo[i-1]/k1o
            
            Yo[i]=(yo[i-1]+k2o*dt)
            PYo[i]=(pyo[i-1]+k4o*dt)
            i=i+1
    else:
            Yo[i]=0
            PYo[i]=0
            i=i+1
else :  
    fig = plt.figure()
    ax = Axes3D(fig)
    
    ax.scatter(yo,xo,pyo,c=xo,cmap=plt.cm.gist_rainbow,alpha=0.15,s=0.3)
    ax.scatter(Yo,X,PYo,c='k',s=3)
    ax.set_xlabel('Y')
    ax.set_ylabel('X')
    ax.set_zlabel('PY')
    
plt.savefig("D:/temp3.png")
plt.show()
# Out:
# 0.47550434847293105

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy import optimize, special
from numpy import *
from pylab import *
import decimal
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as pl

E=1/8
plt.style.use("seaborn-whitegrid")
n=50000
h=1000/n
dt=0
xo=np.zeros(n+1,dtype='float64')
yo=np.zeros(n+1,dtype='float64')
pxo=np.zeros(n+1,dtype='float64')
pyo=np.zeros(n+1,dtype='float64')
Yo=np.zeros(n+1,dtype='float64')
PYo=np.zeros(n+1,dtype='float64')
X=np.zeros(n+1,dtype='float64')
cmaps = [('Perceptually Uniform Sequential',  
                            ['viridis', 'inferno', 'plasma', 'magma']),  
         ('Sequential',     ['Blues', 'BuGn', 'BuPu',  
                             'GnBu', 'Greens', 'Greys', 'Oranges', 'OrRd',  
                             'PuBu', 'PuBuGn', 'PuRd', 'Purples', 'RdPu',  
                             'Reds', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd']),  
         ('Sequential (2)', ['afmhot', 'autumn', 'bone', 'cool',  
                             'copper', 'gist_heat', 'gray', 'hot',  
                             'pink', 'spring', 'summer', 'winter']),  
         ('Diverging',      ['BrBG', 'bwr', 'coolwarm', 'PiYG', 'PRGn', 'PuOr',  
                             'RdBu', 'RdGy', 'RdYlBu', 'RdYlGn', 'Spectral',  
                             'seismic']),  
         ('Qualitative',    ['Accent', 'Dark2', 'Paired', 'Pastel1',  
                             'Pastel2', 'Set1', 'Set2', 'Set3']),  
         ('Miscellaneous',  ['gist_earth', 'terrain', 'ocean', 'gist_stern',  
                             'brg', 'CMRmap', 'cubehelix',  
                             'gnuplot', 'gnuplot2', 'gist_ncar',  
                             'nipy_spectral', 'jet', 'rainbow',  
                             'gist_rainbow', 'hsv', 'flag', 'prism'])]  

i=0
xo[i]=0
yo[i]=-0.15
pyo[i]=0.15
pxo[i]=(2*E-(pyo[i]**2)-(xo[i]**2)-(yo[i]**2)-2*(xo[i]**2)*yo[i]+(2*(yo[i]**3)/3))**(1/2)
i=i+1
print(pxo[0])

        
while i<=n:
    
    k11o=pxo[i-1]
    k12o=pyo[i-1]
    k13o=(-1)*xo[i-1]-2*xo[i-1]*yo[i-1]
    k14o=(-1)*yo[i-1]-(xo[i-1]**2)+(yo[i-1]**2)
    x1o=xo[i-1]+(h/2)*k11o
    y1o=yo[i-1]+(h/2)*k12o
    px1o=pxo[i-1]+(h/2)*k13o
    py1o=pyo[i-1]+(h/2)*k14o
    k21o=px1o
    k22o=py1o
    k23o=(-1)*x1o-2*(x1o)*(y1o)
    k24o=(-1)*y1o-((x1o)**2)+((y1o)**2)
    x2o=xo[i-1]+(h/2)*k21o
    y2o=yo[i-1]+(h/2)*k22o
    px2o=pxo[i-1]+(h/2)*k23o
    py2o=pyo[i-1]+(h/2)*k24o
    k31o=px2o
    k32o=py2o
    k33o=(-1)*x2o-2*(x2o)*(y2o)
    k34o=(-1)*y2o-((x2o)**2)+((y2o)**2)
    x3o=xo[i-1]+h*k31o
    y3o=yo[i-1]+h*k32o
    px3o=pxo[i-1]+h*k33o
    py3o=pyo[i-1]+h*k34o
    k41o=px3o
    k42o=py3o
    k43o=(-1)*x3o-2*(x3o)*(y3o)
    k44o=(-1)*y3o-((x3o)**2)+((y3o)**2)
    k1o=(1/6)*(k11o+2*k21o+2*k31o+k41o)
    k2o=(1/6)*(k12o+2*k22o+2*k32o+k42o)
    k3o=(1/6)*(k13o+2*k23o+2*k33o+k43o)
    k4o=(1/6)*(k14o+2*k24o+2*k34o+k44o)
    xo[i]=xo[i-1]+k1o*h
    yo[i]=yo[i-1]+k2o*h 
    pxo[i]=pxo[i-1]+k3o*h
    pyo[i]=pyo[i-1]+k4o*h
    
    if xo[i]*xo[i-1]<0:
            dt=-xo[i-1]/k1o
            
            Yo[i]=(yo[i-1]+k2o*dt)
            PYo[i]=(pyo[i-1]+k4o*dt)
            i=i+1
    else:
            Yo[i]=0
            PYo[i]=0
            i=i+1
else :  
    fig = plt.figure()
    ax = Axes3D(fig)
    
    ax.scatter(yo,xo,pyo,c=xo,cmap=plt.cm.gist_rainbow,alpha=0.15,s=0.3)
    ax.scatter(Yo,X,PYo,c='k',s=3)
    ax.set_xlabel('Y')
    ax.set_ylabel('X')
    ax.set_zlabel('PY')
    
plt.savefig("D:/temp2.png")
plt.show()
# Out:
# 0.4502776920967771

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy import optimize, special
from numpy import *
from pylab import *
import decimal
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as pl

E=1/16
plt.style.use("seaborn-whitegrid")
n=50000
h=350/n
dt=0
xo=np.zeros(n+1,dtype='float64')
yo=np.zeros(n+1,dtype='float64')
pxo=np.zeros(n+1,dtype='float64')
pyo=np.zeros(n+1,dtype='float64')
Yo=np.zeros(n+1,dtype='float64')
PYo=np.zeros(n+1,dtype='float64')
X=np.zeros(n+1,dtype='float64')


cmaps = [('Perceptually Uniform Sequential',  
                            ['viridis', 'inferno', 'plasma', 'magma']),  
         ('Sequential',     ['Blues', 'BuGn', 'BuPu',  
                             'GnBu', 'Greens', 'Greys', 'Oranges', 'OrRd',  
                             'PuBu', 'PuBuGn', 'PuRd', 'Purples', 'RdPu',  
                             'Reds', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd']),  
         ('Sequential (2)', ['afmhot', 'autumn', 'bone', 'cool',  
                             'copper', 'gist_heat', 'gray', 'hot',  
                             'pink', 'spring', 'summer', 'winter']),  
         ('Diverging',      ['BrBG', 'bwr', 'coolwarm', 'PiYG', 'PRGn', 'PuOr',  
                             'RdBu', 'RdGy', 'RdYlBu', 'RdYlGn', 'Spectral',  
                             'seismic']),  
         ('Qualitative',    ['Accent', 'Dark2', 'Paired', 'Pastel1',  
                             'Pastel2', 'Set1', 'Set2', 'Set3']),  
         ('Miscellaneous',  ['gist_earth', 'terrain', 'ocean', 'gist_stern',  
                             'brg', 'CMRmap', 'cubehelix',  
                             'gnuplot', 'gnuplot2', 'gist_ncar',  
                             'nipy_spectral', 'jet', 'rainbow',  
                             'gist_rainbow', 'hsv', 'flag', 'prism'])]  


nrows = max(len(cmap_list) for cmap_category, cmap_list in cmaps)  
gradient = np.linspace(0, 1, 256)  
gradient = np.vstack((gradient, gradient))  


def plot_color_gradients(cmap_category, cmap_list):  
    fig, axes = plt.subplots(nrows=nrows)  
    fig.subplots_adjust(top=0.95, bottom=0.01, left=0.2, right=0.99)  
    axes[0].set_title(cmap_category + ' colormaps', fontsize=14)  

i=0
xo[i]=0
yo[i]=0
pyo[i]=0.1
pxo[i]=(2*E-(pyo[i]**2)-(xo[i]**2)-(yo[i]**2)-2*(xo[i]**2)*yo[i]-(2*(yo[i]**3)/3))**(1/2)
i=i+1
print(pxo[0])

        
while i<=n:
    
    k11o=pxo[i-1]
    k12o=pyo[i-1]
    k13o=(-1)*xo[i-1]-2*xo[i-1]*yo[i-1]
    k14o=(-1)*yo[i-1]-(xo[i-1]**2)-(yo[i-1]**2)
    x1o=xo[i-1]+(h/2)*k11o
    y1o=yo[i-1]+(h/2)*k12o
    px1o=pxo[i-1]+(h/2)*k13o
    py1o=pyo[i-1]+(h/2)*k14o
    k21o=px1o
    k22o=py1o
    k23o=(-1)*x1o-2*(x1o)*(y1o)
    k24o=(-1)*y1o-((x1o)**2)-((y1o)**2)
    x2o=xo[i-1]+(h/2)*k21o
    y2o=yo[i-1]+(h/2)*k22o
    px2o=pxo[i-1]+(h/2)*k23o
    py2o=pyo[i-1]+(h/2)*k24o
    k31o=px2o
    k32o=py2o
    k33o=(-1)*x2o-2*(x2o)*(y2o)
    k34o=(-1)*y2o-((x2o)**2)-((y2o)**2)
    x3o=xo[i-1]+h*k31o
    y3o=yo[i-1]+h*k32o
    px3o=pxo[i-1]+h*k33o
    py3o=pyo[i-1]+h*k34o
    k41o=px3o
    k42o=py3o
    k43o=(-1)*x3o-2*(x3o)*(y3o)
    k44o=(-1)*y3o-((x3o)**2)+((y3o)**2)
    k1o=(1/6)*(k11o+2*k21o+2*k31o+k41o)
    k2o=(1/6)*(k12o+2*k22o+2*k32o+k42o)
    k3o=(1/6)*(k13o+2*k23o+2*k33o+k43o)
    k4o=(1/6)*(k14o+2*k24o+2*k34o+k44o)
    xo[i]=xo[i-1]+k1o*h
    yo[i]=yo[i-1]+k2o*h 
    pxo[i]=pxo[i-1]+k3o*h
    pyo[i]=pyo[i-1]+k4o*h
    if xo[i]*xo[i-1]<0:
            dt=-xo[i-1]/k1o
            Yo[i]=(yo[i-1]+k2o*dt)
            PYo[i]=(pyo[i-1]+k4o*dt)
            i=i+1
    else:
            Yo[i]=0
            PYo[i]=0
            i=i+1
else :  
    fig = plt.figure()
    ax = Axes3D(fig)
    ax.scatter(yo,xo,pyo,c=xo,cmap=plt.cm.gist_rainbow,alpha=0.15,s=0.3)
    ax.scatter(Yo,X,PYo,c='k',s=4)
    
    
    
    
    ax.set_xlabel('Y Label')
    ax.set_ylabel('X Label')
    ax.set_zlabel('PY Label')
plt.savefig("D:/temp1.png")
plt.show()
# Out:
# 0.3391164991562634

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy import optimize, special
from numpy import *
from pylab import *
import decimal
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as pl

E=1/16
plt.style.use("seaborn-whitegrid")
n=50000
h=350/n
dt=0
xo=np.zeros(n+1,dtype='float64')
yo=np.zeros(n+1,dtype='float64')
pxo=np.zeros(n+1,dtype='float64')
pyo=np.zeros(n+1,dtype='float64')
Yo=np.zeros(n+1,dtype='float64')
PYo=np.zeros(n+1,dtype='float64')
X=np.zeros(n+1,dtype='float64')
i=0
xo[i]=0
yo[i]=0
pyo[i]=0.1
pxo[i]=(2*E-(pyo[i]**2)-(xo[i]**2)-(yo[i]**2)-2*(xo[i]**2)*yo[i]-(2*(yo[i]**3)/3))**(1/2)
i=i+1
print(pxo[0])

        
while i<=n:
    
    k11o=pxo[i-1]
    k12o=pyo[i-1]
    k13o=(-1)*xo[i-1]-2*xo[i-1]*yo[i-1]
    k14o=(-1)*yo[i-1]-(xo[i-1]**2)-(yo[i-1]**2)
    x1o=xo[i-1]+(h/2)*k11o
    y1o=yo[i-1]+(h/2)*k12o
    px1o=pxo[i-1]+(h/2)*k13o
    py1o=pyo[i-1]+(h/2)*k14o
    k21o=px1o
    k22o=py1o
    k23o=(-1)*x1o-2*(x1o)*(y1o)
    k24o=(-1)*y1o-((x1o)**2)-((y1o)**2)
    x2o=xo[i-1]+(h/2)*k21o
    y2o=yo[i-1]+(h/2)*k22o
    px2o=pxo[i-1]+(h/2)*k23o
    py2o=pyo[i-1]+(h/2)*k24o
    k31o=px2o
    k32o=py2o
    k33o=(-1)*x2o-2*(x2o)*(y2o)
    k34o=(-1)*y2o-((x2o)**2)-((y2o)**2)
    x3o=xo[i-1]+h*k31o
    y3o=yo[i-1]+h*k32o
    px3o=pxo[i-1]+h*k33o
    py3o=pyo[i-1]+h*k34o
    k41o=px3o
    k42o=py3o
    k43o=(-1)*x3o-2*(x3o)*(y3o)
    k44o=(-1)*y3o-((x3o)**2)+((y3o)**2)
    k1o=(1/6)*(k11o+2*k21o+2*k31o+k41o)
    k2o=(1/6)*(k12o+2*k22o+2*k32o+k42o)
    k3o=(1/6)*(k13o+2*k23o+2*k33o+k43o)
    k4o=(1/6)*(k14o+2*k24o+2*k34o+k44o)
    xo[i]=xo[i-1]+k1o*h
    yo[i]=yo[i-1]+k2o*h 
    pxo[i]=pxo[i-1]+k3o*h
    pyo[i]=pyo[i-1]+k4o*h
    if xo[i]*xo[i-1]<0:
            dt=-xo[i-1]/k1o
            Yo[i]=(yo[i-1]+k2o*dt)
            PYo[i]=(pyo[i-1]+k4o*dt)
            i=i+1
    else:
            Yo[i]=0
            PYo[i]=0
            i=i+1
else :  
    fig = plt.figure()
    ax = Axes3D(fig)
    ax.plot(xo,yo,pyo,c='orange',alpha=0.6)
    ax.scatter(X,Yo,PYo,c='b',s=3)
    
    
    
    
    ax.set_xlabel('X Label')
    ax.set_ylabel('Y Label')
    ax.set_zlabel('PY Label')
plt.show()
# Out:
# 0.3391164991562634
