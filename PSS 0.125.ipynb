# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy import optimize, special
from numpy import *
from pylab import *
import decimal


E=1/8
plt.style.use("seaborn-whitegrid")
n=500000
h=2500/n
dt=0
xo=np.zeros(n+1,dtype='float64')
yo=np.zeros(n+1,dtype='float64')
pxo=np.zeros(n+1,dtype='float64')
pyo=np.zeros(n+1,dtype='float64')
Yo=np.zeros(n+1,dtype='float64')
PYo=np.zeros(n+1,dtype='float64')
xl=np.zeros(n+1,dtype='float64')
yl=np.zeros(n+1,dtype='float64')
pxl=np.zeros(n+1,dtype='float64')
pyl=np.zeros(n+1,dtype='float64')
Yl=np.zeros(n+1,dtype='float64')
PYl=np.zeros(n+1,dtype='float64')
xu=np.zeros(n+1,dtype='float64')
yu=np.zeros(n+1,dtype='float64')
pxu=np.zeros(n+1,dtype='float64')
pyu=np.zeros(n+1,dtype='float64')
Yu=np.zeros(n+1,dtype='float64')
PYu=np.zeros(n+1,dtype='float64')
xd=np.zeros(n+1,dtype='float64')
yd=np.zeros(n+1,dtype='float64')
pxd=np.zeros(n+1,dtype='float64')
pyd=np.zeros(n+1,dtype='float64')
Yd=np.zeros(n+1,dtype='float64')
PYd=np.zeros(n+1,dtype='float64')
xb=np.zeros(n+1,dtype='float64')
yb=np.zeros(n+1,dtype='float64')
pxb=np.zeros(n+1,dtype='float64')
pyb=np.zeros(n+1,dtype='float64')
Yb=np.zeros(n+1,dtype='float64')
PYb=np.zeros(n+1,dtype='float64')
i=0
xo[i]=0
yo[i]=0
pyo[i]=0
pxo[i]=(2*E-(pyo[i]**2)-(xo[i]**2)-(yo[i]**2)-2*(xo[i]**2)*yo[i]+(2*(yo[i]**3)/3))**(1/2)
i=i+1
print(pxo[0])

        
while i<=n:
    
    k11o=pxo[i-1]
    k12o=pyo[i-1]
    k13o=(-1)*xo[i-1]-2*xo[i-1]*yo[i-1]
    k14o=(-1)*yo[i-1]-(xo[i-1]**2)+(yo[i-1]**2)
    x1o=xo[i-1]+(h/2)*k11o
    y1o=yo[i-1]+(h/2)*k12o
    px1o=pxo[i-1]+(h/2)*k13o
    py1o=pyo[i-1]+(h/2)*k14o
    k21o=px1o
    k22o=py1o
    k23o=(-1)*x1o-2*(x1o)*(y1o)
    k24o=(-1)*y1o-((x1o)**2)+((y1o)**2)
    x2o=xo[i-1]+(h/2)*k21o
    y2o=yo[i-1]+(h/2)*k22o
    px2o=pxo[i-1]+(h/2)*k23o
    py2o=pyo[i-1]+(h/2)*k24o
    k31o=px2o
    k32o=py2o
    k33o=(-1)*x2o-2*(x2o)*(y2o)
    k34o=(-1)*y2o-((x2o)**2)+((y2o)**2)
    x3o=xo[i-1]+h*k31o
    y3o=yo[i-1]+h*k32o
    px3o=pxo[i-1]+h*k33o
    py3o=pyo[i-1]+h*k34o
    k41o=px3o
    k42o=py3o
    k43o=(-1)*x3o-2*(x3o)*(y3o)
    k44o=(-1)*y3o-((x3o)**2)+((y3o)**2)
    k1o=(1/6)*(k11o+2*k21o+2*k31o+k41o)
    k2o=(1/6)*(k12o+2*k22o+2*k32o+k42o)
    k3o=(1/6)*(k13o+2*k23o+2*k33o+k43o)
    k4o=(1/6)*(k14o+2*k24o+2*k34o+k44o)
    xo[i]=xo[i-1]+k1o*h
    yo[i]=yo[i-1]+k2o*h 
    pxo[i]=pxo[i-1]+k3o*h
    pyo[i]=pyo[i-1]+k4o*h
    
    if xo[i]*xo[i-1]<0 and pxo[i]>0 and pxo[i-1]>0:
            dt=-xo[i-1]/k1o
            xo[i]=0
            Yo[i]=(yo[i-1]+k2o*dt)
            PYo[i]=(pyo[i-1]+k4o*dt)
            i=i+1
    else:
            Yo[i]=0
            PYo[i]=0
            i=i+1
else :           
    plt.scatter(Yo,PYo,s=0.1,c='r')
    
i=0
xl[i]=0
yl[i]=0.08
pyl[i]=0
pxl[i]=(2*E-(pyl[i]**2)-(xl[i]**2)-(yl[i]**2)-2*(xl[i]**2)*yl[i]+(2*(yl[i]**3)/3))**(1/2)
i=i+1
print(pxl[0])

        
while i<=n:
    
    k11l=pxl[i-1]
    k12l=pyl[i-1]
    k13l=(-1)*xl[i-1]-2*xl[i-1]*yl[i-1]
    k14l=(-1)*yl[i-1]-(xl[i-1]**2)+(yl[i-1]**2)
    x1l=xl[i-1]+(h/2)*k11l
    y1l=yl[i-1]+(h/2)*k12l
    px1l=pxl[i-1]+(h/2)*k13l
    py1l=pyl[i-1]+(h/2)*k14l
    k21l=px1l
    k22l=py1l
    k23l=(-1)*x1l-2*(x1l)*(y1l)
    k24l=(-1)*y1l-((x1l)**2)+((y1l)**2)
    x2l=xl[i-1]+(h/2)*k21l
    y2l=yl[i-1]+(h/2)*k22l
    px2l=pxl[i-1]+(h/2)*k23l
    py2l=pyl[i-1]+(h/2)*k24l
    k31l=px2l
    k32l=py2l
    k33l=(-1)*x2l-2*(x2l)*(y2l)
    k34l=(-1)*y2l-((x2l)**2)+((y2l)**2)
    x3l=xl[i-1]+h*k31l
    y3l=yl[i-1]+h*k32l
    px3l=pxl[i-1]+h*k33l
    py3l=pyl[i-1]+h*k34l
    k41l=px3l
    k42l=py3l
    k43l=(-1)*x3l-2*(x3l)*(y3l)
    k44l=(-1)*y3l-((x3l)**2)+((y3l)**2)
    k1l=(1/6)*(k11l+2*k21l+2*k31l+k41l)
    k2l=(1/6)*(k12l+2*k22l+2*k32l+k42l)
    k3l=(1/6)*(k13l+2*k23l+2*k33l+k43l)
    k4l=(1/6)*(k14l+2*k24l+2*k34l+k44l)
    xl[i]=xl[i-1]+k1l*h
    yl[i]=yl[i-1]+k2l*h 
    pxl[i]=pxl[i-1]+k3l*h
    pyl[i]=pyl[i-1]+k4l*h
    
    
    if xl[i]*xl[i-1]<0 and pxl[i]>0 and pxl[i-1]>0:
            dt=-xl[i-1]/k1l
            Yl[i]=(yl[i-1]+k2l*dt)
            PYl[i]=(pyl[i-1]+k4l*dt)
            xl[i]=0
            i=i+1
    else:
            Yl[i]=0
            PYl[i]=0
            i=i+1
else :           
    plt.scatter(Yl,PYl,s=0.1,c='r')

i=0
xu[i]=0
yu[i]=0.16
pyu[i]=0
pxu[i]=(2*E-(pyu[i]**2)-(xu[i]**2)-(yu[i]**2)-2*(xu[i]**2)*yu[i]+(2*(yu[i]**3)/3))**(1/2)
i=i+1
print(pxu[0])

        
while i<=n:
   
    k11u=pxu[i-1]
    k12u=pyu[i-1]
    k13u=(-1)*xu[i-1]-2*xu[i-1]*yu[i-1]
    k14u=(-1)*yu[i-1]-(xu[i-1]**2)+(yu[i-1]**2)
    x1u=xu[i-1]+(h/2)*k11u
    y1u=yu[i-1]+(h/2)*k12u
    px1u=pxu[i-1]+(h/2)*k13u
    py1u=pyu[i-1]+(h/2)*k14u
    k21u=px1u
    k22u=py1u
    k23u=(-1)*x1u-2*(x1u)*(y1u)
    k24u=(-1)*y1u-((x1u)**2)+((y1u)**2)
    x2u=xu[i-1]+(h/2)*k21u
    y2u=yu[i-1]+(h/2)*k22u
    px2u=pxu[i-1]+(h/2)*k23u
    py2u=pyu[i-1]+(h/2)*k24u
    k31u=px2u
    k32u=py2u
    k33u=(-1)*x2u-2*(x2u)*(y2u)
    k34u=(-1)*y2u-((x2u)**2)+((y2u)**2)
    x3u=xu[i-1]+h*k31u
    y3u=yu[i-1]+h*k32u
    px3u=pxu[i-1]+h*k33u
    py3u=pyu[i-1]+h*k34u
    k41u=px3u
    k42u=py3u
    k43u=(-1)*x3u-2*(x3u)*(y3u)
    k44u=(-1)*y3u-((x3u)**2)+((y3u)**2)
    k1u=(1/6)*(k11u+2*k21u+2*k31u+k41u)
    k2u=(1/6)*(k12u+2*k22u+2*k32u+k42u)
    k3u=(1/6)*(k13u+2*k23u+2*k33u+k43u)
    k4u=(1/6)*(k14u+2*k24u+2*k34u+k44u)
    xu[i]=xu[i-1]+k1u*h
    yu[i]=yu[i-1]+k2u*h 
    pxu[i]=pxu[i-1]+k3u*h
    pyu[i]=pyu[i-1]+k4u*h
    
    
    if xu[i]*xu[i-1]<0 and pxu[i]>0 and pxu[i-1]>0:
            dt=-xu[i-1]/k1u
            Yu[i]=(yu[i-1]+k2u*dt)
            PYu[i]=(pyu[i-1]+k4u*dt)
            xu[i]=0
            i=i+1
    else:
            Yu[i]=0
            PYu[i]=0
            i=i+1
else :           
    plt.scatter(Yu,PYu,s=0.1,c='r')
    
i=0
xu[i]=0
yu[i]=0.24
pyu[i]=0
pxu[i]=(2*E-(pyu[i]**2)-(xu[i]**2)-(yu[i]**2)-2*(xu[i]**2)*yu[i]+(2*(yu[i]**3)/3))**(1/2)
i=i+1
print(pxu[0])

        
while i<=n:
   
    k11u=pxu[i-1]
    k12u=pyu[i-1]
    k13u=(-1)*xu[i-1]-2*xu[i-1]*yu[i-1]
    k14u=(-1)*yu[i-1]-(xu[i-1]**2)+(yu[i-1]**2)
    x1u=xu[i-1]+(h/2)*k11u
    y1u=yu[i-1]+(h/2)*k12u
    px1u=pxu[i-1]+(h/2)*k13u
    py1u=pyu[i-1]+(h/2)*k14u
    k21u=px1u
    k22u=py1u
    k23u=(-1)*x1u-2*(x1u)*(y1u)
    k24u=(-1)*y1u-((x1u)**2)+((y1u)**2)
    x2u=xu[i-1]+(h/2)*k21u
    y2u=yu[i-1]+(h/2)*k22u
    px2u=pxu[i-1]+(h/2)*k23u
    py2u=pyu[i-1]+(h/2)*k24u
    k31u=px2u
    k32u=py2u
    k33u=(-1)*x2u-2*(x2u)*(y2u)
    k34u=(-1)*y2u-((x2u)**2)+((y2u)**2)
    x3u=xu[i-1]+h*k31u
    y3u=yu[i-1]+h*k32u
    px3u=pxu[i-1]+h*k33u
    py3u=pyu[i-1]+h*k34u
    k41u=px3u
    k42u=py3u
    k43u=(-1)*x3u-2*(x3u)*(y3u)
    k44u=(-1)*y3u-((x3u)**2)+((y3u)**2)
    k1u=(1/6)*(k11u+2*k21u+2*k31u+k41u)
    k2u=(1/6)*(k12u+2*k22u+2*k32u+k42u)
    k3u=(1/6)*(k13u+2*k23u+2*k33u+k43u)
    k4u=(1/6)*(k14u+2*k24u+2*k34u+k44u)
    xu[i]=xu[i-1]+k1u*h
    yu[i]=yu[i-1]+k2u*h 
    pxu[i]=pxu[i-1]+k3u*h
    pyu[i]=pyu[i-1]+k4u*h
    
    
    if xu[i]*xu[i-1]<0 and pxu[i]>0 and pxu[i-1]>0:
            dt=-xu[i-1]/k1u
            Yu[i]=(yu[i-1]+k2u*dt)
            PYu[i]=(pyu[i-1]+k4u*dt)
            xu[i]=0
            i=i+1
    else:
            Yu[i]=0
            PYu[i]=0
            i=i+1
else :           
    plt.scatter(Yu,PYu,s=0.1,c='r')

i=0
xu[i]=0
yu[i]=-0.25
pyu[i]=0
pxu[i]=(2*E-(pyu[i]**2)-(xu[i]**2)-(yu[i]**2)-2*(xu[i]**2)*yu[i]+(2*(yu[i]**3)/3))**(1/2)
i=i+1
print(pxu[0])

        
while i<=n:
   
    k11u=pxu[i-1]
    k12u=pyu[i-1]
    k13u=(-1)*xu[i-1]-2*xu[i-1]*yu[i-1]
    k14u=(-1)*yu[i-1]-(xu[i-1]**2)+(yu[i-1]**2)
    x1u=xu[i-1]+(h/2)*k11u
    y1u=yu[i-1]+(h/2)*k12u
    px1u=pxu[i-1]+(h/2)*k13u
    py1u=pyu[i-1]+(h/2)*k14u
    k21u=px1u
    k22u=py1u
    k23u=(-1)*x1u-2*(x1u)*(y1u)
    k24u=(-1)*y1u-((x1u)**2)+((y1u)**2)
    x2u=xu[i-1]+(h/2)*k21u
    y2u=yu[i-1]+(h/2)*k22u
    px2u=pxu[i-1]+(h/2)*k23u
    py2u=pyu[i-1]+(h/2)*k24u
    k31u=px2u
    k32u=py2u
    k33u=(-1)*x2u-2*(x2u)*(y2u)
    k34u=(-1)*y2u-((x2u)**2)+((y2u)**2)
    x3u=xu[i-1]+h*k31u
    y3u=yu[i-1]+h*k32u
    px3u=pxu[i-1]+h*k33u
    py3u=pyu[i-1]+h*k34u
    k41u=px3u
    k42u=py3u
    k43u=(-1)*x3u-2*(x3u)*(y3u)
    k44u=(-1)*y3u-((x3u)**2)+((y3u)**2)
    k1u=(1/6)*(k11u+2*k21u+2*k31u+k41u)
    k2u=(1/6)*(k12u+2*k22u+2*k32u+k42u)
    k3u=(1/6)*(k13u+2*k23u+2*k33u+k43u)
    k4u=(1/6)*(k14u+2*k24u+2*k34u+k44u)
    xu[i]=xu[i-1]+k1u*h
    yu[i]=yu[i-1]+k2u*h 
    pxu[i]=pxu[i-1]+k3u*h
    pyu[i]=pyu[i-1]+k4u*h
    
    
    if xu[i]*xu[i-1]<0 and pxu[i]>0 and pxu[i-1]>0:
            dt=-xu[i-1]/k1u
            Yu[i]=(yu[i-1]+k2u*dt)
            PYu[i]=(pyu[i-1]+k4u*dt)
            xu[i]=0
            i=i+1
    else:
            Yu[i]=0
            PYu[i]=0
            i=i+1
else :           
    plt.scatter(Yu,PYu,s=0.1,c='b')
i=0
xu[i]=0
yu[i]=-0.275
pyu[i]=0
pxu[i]=(2*E-(pyu[i]**2)-(xu[i]**2)-(yu[i]**2)-2*(xu[i]**2)*yu[i]+(2*(yu[i]**3)/3))**(1/2)
i=i+1
print(pxu[0])

        
while i<=n:
   
    k11u=pxu[i-1]
    k12u=pyu[i-1]
    k13u=(-1)*xu[i-1]-2*xu[i-1]*yu[i-1]
    k14u=(-1)*yu[i-1]-(xu[i-1]**2)+(yu[i-1]**2)
    x1u=xu[i-1]+(h/2)*k11u
    y1u=yu[i-1]+(h/2)*k12u
    px1u=pxu[i-1]+(h/2)*k13u
    py1u=pyu[i-1]+(h/2)*k14u
    k21u=px1u
    k22u=py1u
    k23u=(-1)*x1u-2*(x1u)*(y1u)
    k24u=(-1)*y1u-((x1u)**2)+((y1u)**2)
    x2u=xu[i-1]+(h/2)*k21u
    y2u=yu[i-1]+(h/2)*k22u
    px2u=pxu[i-1]+(h/2)*k23u
    py2u=pyu[i-1]+(h/2)*k24u
    k31u=px2u
    k32u=py2u
    k33u=(-1)*x2u-2*(x2u)*(y2u)
    k34u=(-1)*y2u-((x2u)**2)+((y2u)**2)
    x3u=xu[i-1]+h*k31u
    y3u=yu[i-1]+h*k32u
    px3u=pxu[i-1]+h*k33u
    py3u=pyu[i-1]+h*k34u
    k41u=px3u
    k42u=py3u
    k43u=(-1)*x3u-2*(x3u)*(y3u)
    k44u=(-1)*y3u-((x3u)**2)+((y3u)**2)
    k1u=(1/6)*(k11u+2*k21u+2*k31u+k41u)
    k2u=(1/6)*(k12u+2*k22u+2*k32u+k42u)
    k3u=(1/6)*(k13u+2*k23u+2*k33u+k43u)
    k4u=(1/6)*(k14u+2*k24u+2*k34u+k44u)
    xu[i]=xu[i-1]+k1u*h
    yu[i]=yu[i-1]+k2u*h 
    pxu[i]=pxu[i-1]+k3u*h
    pyu[i]=pyu[i-1]+k4u*h
    
    
    if xu[i]*xu[i-1]<0 and pxu[i]>0 and pxu[i-1]>0:
            dt=-xu[i-1]/k1u
            Yu[i]=(yu[i-1]+k2u*dt)
            PYu[i]=(pyu[i-1]+k4u*dt)
            xu[i]=0
            i=i+1
    else:
            Yu[i]=0
            PYu[i]=0
            i=i+1
else :           
    plt.scatter(Yu,PYu,s=0.1,c='b')
i=0
xd[i]=0
yd[i]=-0.3
pyd[i]=0
pxd[i]=(2*E-(pyd[i]**2)-(xd[i]**2)-(yd[i]**2)-2*(xd[i]**2)*yd[i]+(2*(yd[i]**3)/3))**(1/2)
i=i+1
print(pxd[0])

        
while i<=n:
    
    k11d=pxd[i-1]
    k12d=pyd[i-1]
    k13d=(-1)*xd[i-1]-2*xd[i-1]*yd[i-1]
    k14d=(-1)*yd[i-1]-(xd[i-1]**2)+(yd[i-1]**2)
    x1d=xd[i-1]+(h/2)*k11d
    y1d=yd[i-1]+(h/2)*k12d
    px1d=pxd[i-1]+(h/2)*k13d
    py1d=pyd[i-1]+(h/2)*k14d
    k21d=px1d
    k22d=py1d
    k23d=(-1)*x1d-2*(x1d)*(y1d)
    k24d=(-1)*y1d-((x1d)**2)+((y1d)**2)
    x2d=xd[i-1]+(h/2)*k21d
    y2d=yd[i-1]+(h/2)*k22d
    px2d=pxd[i-1]+(h/2)*k23d
    py2d=pyd[i-1]+(h/2)*k24d
    k31d=px2d
    k32d=py2d
    k33d=(-1)*x2d-2*(x2d)*(y2d)
    k34d=(-1)*y2d-((x2d)**2)+((y2d)**2)
    x3d=xd[i-1]+h*k31d
    y3d=yd[i-1]+h*k32d
    px3d=pxd[i-1]+h*k33d
    py3d=pyd[i-1]+h*k34d
    k41d=px3d
    k42d=py3d
    k43d=(-1)*x3d-2*(x3d)*(y3d)
    k44d=(-1)*y3d-((x3d)**2)+((y3d)**2)
    k1d=(1/6)*(k11d+2*k21d+2*k31d+k41d)
    k2d=(1/6)*(k12d+2*k22d+2*k32d+k42d)
    k3d=(1/6)*(k13d+2*k23d+2*k33d+k43d)
    k4d=(1/6)*(k14d+2*k24d+2*k34d+k44d)
    xd[i]=xd[i-1]+k1d*h
    yd[i]=yd[i-1]+k2d*h 
    pxd[i]=pxd[i-1]+k3d*h
    pyd[i]=pyd[i-1]+k4d*h
    
    
    if xd[i]*xd[i-1]<0 and pxd[i]>0 and pxd[i-1]>0:
            dt=-xd[i-1]/k1d
            Yd[i]=(yd[i-1]+k2d*dt)
            PYd[i]=(pyd[i-1]+k4d*dt)
            xd[i]=0
            i=i+1
    else:
            Yd[i]=0
            PYd[i]=0
            i=i+1
else :           
    plt.scatter(Yd,PYd,s=0.1,c='b')
i=0
xd[i]=0
yd[i]=-0.325
pyd[i]=0
pxd[i]=(2*E-(pyd[i]**2)-(xd[i]**2)-(yd[i]**2)-2*(xd[i]**2)*yd[i]+(2*(yd[i]**3)/3))**(1/2)
i=i+1
print(pxd[0])

        
while i<=n:
    
    k11d=pxd[i-1]
    k12d=pyd[i-1]
    k13d=(-1)*xd[i-1]-2*xd[i-1]*yd[i-1]
    k14d=(-1)*yd[i-1]-(xd[i-1]**2)+(yd[i-1]**2)
    x1d=xd[i-1]+(h/2)*k11d
    y1d=yd[i-1]+(h/2)*k12d
    px1d=pxd[i-1]+(h/2)*k13d
    py1d=pyd[i-1]+(h/2)*k14d
    k21d=px1d
    k22d=py1d
    k23d=(-1)*x1d-2*(x1d)*(y1d)
    k24d=(-1)*y1d-((x1d)**2)+((y1d)**2)
    x2d=xd[i-1]+(h/2)*k21d
    y2d=yd[i-1]+(h/2)*k22d
    px2d=pxd[i-1]+(h/2)*k23d
    py2d=pyd[i-1]+(h/2)*k24d
    k31d=px2d
    k32d=py2d
    k33d=(-1)*x2d-2*(x2d)*(y2d)
    k34d=(-1)*y2d-((x2d)**2)+((y2d)**2)
    x3d=xd[i-1]+h*k31d
    y3d=yd[i-1]+h*k32d
    px3d=pxd[i-1]+h*k33d
    py3d=pyd[i-1]+h*k34d
    k41d=px3d
    k42d=py3d
    k43d=(-1)*x3d-2*(x3d)*(y3d)
    k44d=(-1)*y3d-((x3d)**2)+((y3d)**2)
    k1d=(1/6)*(k11d+2*k21d+2*k31d+k41d)
    k2d=(1/6)*(k12d+2*k22d+2*k32d+k42d)
    k3d=(1/6)*(k13d+2*k23d+2*k33d+k43d)
    k4d=(1/6)*(k14d+2*k24d+2*k34d+k44d)
    xd[i]=xd[i-1]+k1d*h
    yd[i]=yd[i-1]+k2d*h 
    pxd[i]=pxd[i-1]+k3d*h
    pyd[i]=pyd[i-1]+k4d*h
    
    
    if xd[i]*xd[i-1]<0 and pxd[i]>0 and pxd[i-1]>0:
            dt=-xd[i-1]/k1d
            Yd[i]=(yd[i-1]+k2d*dt)
            PYd[i]=(pyd[i-1]+k4d*dt)
            xd[i]=0
            i=i+1
    else:
            Yd[i]=0
            PYd[i]=0
            i=i+1
else :           
    plt.scatter(Yd,PYd,s=0.1,c='b')
i=0
xd[i]=0
yd[i]=-0.375
pyd[i]=0
pxd[i]=(2*E-(pyd[i]**2)-(xd[i]**2)-(yd[i]**2)-2*(xd[i]**2)*yd[i]+(2*(yd[i]**3)/3))**(1/2)
i=i+1
print(pxd[0])

        
while i<=n:
    
    k11d=pxd[i-1]
    k12d=pyd[i-1]
    k13d=(-1)*xd[i-1]-2*xd[i-1]*yd[i-1]
    k14d=(-1)*yd[i-1]-(xd[i-1]**2)+(yd[i-1]**2)
    x1d=xd[i-1]+(h/2)*k11d
    y1d=yd[i-1]+(h/2)*k12d
    px1d=pxd[i-1]+(h/2)*k13d
    py1d=pyd[i-1]+(h/2)*k14d
    k21d=px1d
    k22d=py1d
    k23d=(-1)*x1d-2*(x1d)*(y1d)
    k24d=(-1)*y1d-((x1d)**2)+((y1d)**2)
    x2d=xd[i-1]+(h/2)*k21d
    y2d=yd[i-1]+(h/2)*k22d
    px2d=pxd[i-1]+(h/2)*k23d
    py2d=pyd[i-1]+(h/2)*k24d
    k31d=px2d
    k32d=py2d
    k33d=(-1)*x2d-2*(x2d)*(y2d)
    k34d=(-1)*y2d-((x2d)**2)+((y2d)**2)
    x3d=xd[i-1]+h*k31d
    y3d=yd[i-1]+h*k32d
    px3d=pxd[i-1]+h*k33d
    py3d=pyd[i-1]+h*k34d
    k41d=px3d
    k42d=py3d
    k43d=(-1)*x3d-2*(x3d)*(y3d)
    k44d=(-1)*y3d-((x3d)**2)+((y3d)**2)
    k1d=(1/6)*(k11d+2*k21d+2*k31d+k41d)
    k2d=(1/6)*(k12d+2*k22d+2*k32d+k42d)
    k3d=(1/6)*(k13d+2*k23d+2*k33d+k43d)
    k4d=(1/6)*(k14d+2*k24d+2*k34d+k44d)
    xd[i]=xd[i-1]+k1d*h
    yd[i]=yd[i-1]+k2d*h 
    pxd[i]=pxd[i-1]+k3d*h
    pyd[i]=pyd[i-1]+k4d*h
    
    
    if xd[i]*xd[i-1]<0 and pxd[i]>0 and pxd[i-1]>0:
            dt=-xd[i-1]/k1d
            Yd[i]=(yd[i-1]+k2d*dt)
            PYd[i]=(pyd[i-1]+k4d*dt)
            xd[i]=0
            i=i+1
    else:
            Yd[i]=0
            PYd[i]=0
            i=i+1
else :           
    plt.scatter(Yd,PYd,s=0.1,c='b')
i=0
xb[i]=0
yb[i]=-0.4
pyb[i]=0
pxb[i]=(2*E-(pyb[i]**2)-(xb[i]**2)-(yb[i]**2)-2*(xb[i]**2)*yb[i]+(2*(yb[i]**3)/3))**(1/2)
i=i+1
print(pxb[0])

        
while i<=n:
    
    k11b=pxb[i-1]
    k12b=pyb[i-1]
    k13b=(-1)*xb[i-1]-2*xb[i-1]*yb[i-1]
    k14b=(-1)*yb[i-1]-(xb[i-1]**2)+(yb[i-1]**2)
    x1b=xb[i-1]+(h/2)*k11b
    y1b=yb[i-1]+(h/2)*k12b
    px1b=pxb[i-1]+(h/2)*k13b
    py1b=pyb[i-1]+(h/2)*k14b
    k21b=px1b
    k22b=py1b
    k23b=(-1)*x1b-2*(x1b)*(y1b)
    k24b=(-1)*y1b-((x1b)**2)+((y1b)**2)
    x2b=xb[i-1]+(h/2)*k21b
    y2b=yb[i-1]+(h/2)*k22b
    px2b=pxb[i-1]+(h/2)*k23b
    py2b=pyb[i-1]+(h/2)*k24b
    k31b=px2b
    k32b=py2b
    k33b=(-1)*x2b-2*(x2b)*(y2b)
    k34b=(-1)*y2b-((x2b)**2)+((y2b)**2)
    x3b=xb[i-1]+h*k31b
    y3b=yb[i-1]+h*k32b
    px3b=pxb[i-1]+h*k33b
    py3b=pyb[i-1]+h*k34b
    k41b=px3b
    k42b=py3b
    k43b=(-1)*x3b-2*(x3b)*(y3b)
    k44b=(-1)*y3b-((x3b)**2)+((y3b)**2)
    k1b=(1/6)*(k11b+2*k21b+2*k31b+k41b)
    k2b=(1/6)*(k12b+2*k22b+2*k32b+k42b)
    k3b=(1/6)*(k13b+2*k23b+2*k33b+k43b)
    k4b=(1/6)*(k14b+2*k24b+2*k34b+k44b)
    xb[i]=xb[i-1]+k1b*h
    yb[i]=yb[i-1]+k2b*h 
    pxb[i]=pxb[i-1]+k3b*h
    pyb[i]=pyb[i-1]+k4b*h
    
    
    if xb[i]*xb[i-1]<0 and pxb[i]>0 and pxb[i-1]>0:
            dt=-xb[i-1]/k1b
            Yb[i]=(yb[i-1]+k2b*dt)
            PYb[i]=(pyb[i-1]+k4b*dt)
            xb[i]=0
            i=i+1
    else:
            Yb[i]=0
            PYb[i]=0
            i=i+1
else :           
    plt.scatter(Yb,PYb,s=0.1,c='b')
    
i=0
xb[i]=0
yb[i]=0.02
pyb[i]=0.1
pxb[i]=(2*E-(pyb[i]**2)-(xb[i]**2)-(yb[i]**2)-2*(xb[i]**2)*yb[i]+(2*(yb[i]**3)/3))**(1/2)
i=i+1
print(pxb[0])

        
while i<=n:
    
    k11b=pxb[i-1]
    k12b=pyb[i-1]
    k13b=(-1)*xb[i-1]-2*xb[i-1]*yb[i-1]
    k14b=(-1)*yb[i-1]-(xb[i-1]**2)+(yb[i-1]**2)
    x1b=xb[i-1]+(h/2)*k11b
    y1b=yb[i-1]+(h/2)*k12b
    px1b=pxb[i-1]+(h/2)*k13b
    py1b=pyb[i-1]+(h/2)*k14b
    k21b=px1b
    k22b=py1b
    k23b=(-1)*x1b-2*(x1b)*(y1b)
    k24b=(-1)*y1b-((x1b)**2)+((y1b)**2)
    x2b=xb[i-1]+(h/2)*k21b
    y2b=yb[i-1]+(h/2)*k22b
    px2b=pxb[i-1]+(h/2)*k23b
    py2b=pyb[i-1]+(h/2)*k24b
    k31b=px2b
    k32b=py2b
    k33b=(-1)*x2b-2*(x2b)*(y2b)
    k34b=(-1)*y2b-((x2b)**2)+((y2b)**2)
    x3b=xb[i-1]+h*k31b
    y3b=yb[i-1]+h*k32b
    px3b=pxb[i-1]+h*k33b
    py3b=pyb[i-1]+h*k34b
    k41b=px3b
    k42b=py3b
    k43b=(-1)*x3b-2*(x3b)*(y3b)
    k44b=(-1)*y3b-((x3b)**2)+((y3b)**2)
    k1b=(1/6)*(k11b+2*k21b+2*k31b+k41b)
    k2b=(1/6)*(k12b+2*k22b+2*k32b+k42b)
    k3b=(1/6)*(k13b+2*k23b+2*k33b+k43b)
    k4b=(1/6)*(k14b+2*k24b+2*k34b+k44b)
    xb[i]=xb[i-1]+k1b*h
    yb[i]=yb[i-1]+k2b*h 
    pxb[i]=pxb[i-1]+k3b*h
    pyb[i]=pyb[i-1]+k4b*h
    
    
    if xb[i]*xb[i-1]<0 and pxb[i]>0 and pxb[i-1]>0:
            dt=-xb[i-1]/k1b
            Yb[i]=(yb[i-1]+k2b*dt)
            PYb[i]=(pyb[i-1]+k4b*dt)
            xb[i]=0
            i=i+1
    else:
            Yb[i]=0
            PYb[i]=0
            i=i+1
else :           
    plt.scatter(Yb,PYb,s=0.1,c='r')
    
i=0
xb[i]=0
yb[i]=0
pyb[i]=-0.23
pxb[i]=(2*E-(pyb[i]**2)-(xb[i]**2)-(yb[i]**2)-2*(xb[i]**2)*yb[i]+(2*(yb[i]**3)/3))**(1/2)
i=i+1
print(pxb[0])

        
while i<=n:
    
    k11b=pxb[i-1]
    k12b=pyb[i-1]
    k13b=(-1)*xb[i-1]-2*xb[i-1]*yb[i-1]
    k14b=(-1)*yb[i-1]-(xb[i-1]**2)+(yb[i-1]**2)
    x1b=xb[i-1]+(h/2)*k11b
    y1b=yb[i-1]+(h/2)*k12b
    px1b=pxb[i-1]+(h/2)*k13b
    py1b=pyb[i-1]+(h/2)*k14b
    k21b=px1b
    k22b=py1b
    k23b=(-1)*x1b-2*(x1b)*(y1b)
    k24b=(-1)*y1b-((x1b)**2)+((y1b)**2)
    x2b=xb[i-1]+(h/2)*k21b
    y2b=yb[i-1]+(h/2)*k22b
    px2b=pxb[i-1]+(h/2)*k23b
    py2b=pyb[i-1]+(h/2)*k24b
    k31b=px2b
    k32b=py2b
    k33b=(-1)*x2b-2*(x2b)*(y2b)
    k34b=(-1)*y2b-((x2b)**2)+((y2b)**2)
    x3b=xb[i-1]+h*k31b
    y3b=yb[i-1]+h*k32b
    px3b=pxb[i-1]+h*k33b
    py3b=pyb[i-1]+h*k34b
    k41b=px3b
    k42b=py3b
    k43b=(-1)*x3b-2*(x3b)*(y3b)
    k44b=(-1)*y3b-((x3b)**2)+((y3b)**2)
    k1b=(1/6)*(k11b+2*k21b+2*k31b+k41b)
    k2b=(1/6)*(k12b+2*k22b+2*k32b+k42b)
    k3b=(1/6)*(k13b+2*k23b+2*k33b+k43b)
    k4b=(1/6)*(k14b+2*k24b+2*k34b+k44b)
    xb[i]=xb[i-1]+k1b*h
    yb[i]=yb[i-1]+k2b*h 
    pxb[i]=pxb[i-1]+k3b*h
    pyb[i]=pyb[i-1]+k4b*h
    
    
    if xb[i]*xb[i-1]<0 and pxb[i]>0 and pxb[i-1]>0:
            dt=-xb[i-1]/k1b
            Yb[i]=(yb[i-1]+k2b*dt)
            PYb[i]=(pyb[i-1]+k4b*dt)
            xb[i]=0
            i=i+1
    else:
            Yb[i]=0
            PYb[i]=0
            i=i+1
else :           
    plt.scatter(Yb,PYb,s=0.1,c='m')
    
i=0
xb[i]=0
yb[i]=0
pyb[i]=0.2
pxb[i]=(2*E-(pyb[i]**2)-(xb[i]**2)-(yb[i]**2)-2*(xb[i]**2)*yb[i]+(2*(yb[i]**3)/3))**(1/2)
i=i+1
print(pxb[0])

        
while i<=n:
    
    k11b=pxb[i-1]
    k12b=pyb[i-1]
    k13b=(-1)*xb[i-1]-2*xb[i-1]*yb[i-1]
    k14b=(-1)*yb[i-1]-(xb[i-1]**2)+(yb[i-1]**2)
    x1b=xb[i-1]+(h/2)*k11b
    y1b=yb[i-1]+(h/2)*k12b
    px1b=pxb[i-1]+(h/2)*k13b
    py1b=pyb[i-1]+(h/2)*k14b
    k21b=px1b
    k22b=py1b
    k23b=(-1)*x1b-2*(x1b)*(y1b)
    k24b=(-1)*y1b-((x1b)**2)+((y1b)**2)
    x2b=xb[i-1]+(h/2)*k21b
    y2b=yb[i-1]+(h/2)*k22b
    px2b=pxb[i-1]+(h/2)*k23b
    py2b=pyb[i-1]+(h/2)*k24b
    k31b=px2b
    k32b=py2b
    k33b=(-1)*x2b-2*(x2b)*(y2b)
    k34b=(-1)*y2b-((x2b)**2)+((y2b)**2)
    x3b=xb[i-1]+h*k31b
    y3b=yb[i-1]+h*k32b
    px3b=pxb[i-1]+h*k33b
    py3b=pyb[i-1]+h*k34b
    k41b=px3b
    k42b=py3b
    k43b=(-1)*x3b-2*(x3b)*(y3b)
    k44b=(-1)*y3b-((x3b)**2)+((y3b)**2)
    k1b=(1/6)*(k11b+2*k21b+2*k31b+k41b)
    k2b=(1/6)*(k12b+2*k22b+2*k32b+k42b)
    k3b=(1/6)*(k13b+2*k23b+2*k33b+k43b)
    k4b=(1/6)*(k14b+2*k24b+2*k34b+k44b)
    xb[i]=xb[i-1]+k1b*h
    yb[i]=yb[i-1]+k2b*h 
    pxb[i]=pxb[i-1]+k3b*h
    pyb[i]=pyb[i-1]+k4b*h
    
    
    if xb[i]*xb[i-1]<0 and pxb[i]>0 and pxb[i-1]>0:
            dt=-xb[i-1]/k1b
            Yb[i]=(yb[i-1]+k2b*dt)
            PYb[i]=(pyb[i-1]+k4b*dt)
            xb[i]=0
            i=i+1
    else:
            Yb[i]=0
            PYb[i]=0
            i=i+1
else :           
    plt.scatter(Yb,PYb,s=0.1,c='m')
    
i=0
xb[i]=0
yb[i]=0
pyb[i]=-0.2
pxb[i]=(2*E-(pyb[i]**2)-(xb[i]**2)-(yb[i]**2)-2*(xb[i]**2)*yb[i]+(2*(yb[i]**3)/3))**(1/2)
i=i+1
print(pxb[0])

        
while i<=n:
    
    k11b=pxb[i-1]
    k12b=pyb[i-1]
    k13b=(-1)*xb[i-1]-2*xb[i-1]*yb[i-1]
    k14b=(-1)*yb[i-1]-(xb[i-1]**2)+(yb[i-1]**2)
    x1b=xb[i-1]+(h/2)*k11b
    y1b=yb[i-1]+(h/2)*k12b
    px1b=pxb[i-1]+(h/2)*k13b
    py1b=pyb[i-1]+(h/2)*k14b
    k21b=px1b
    k22b=py1b
    k23b=(-1)*x1b-2*(x1b)*(y1b)
    k24b=(-1)*y1b-((x1b)**2)+((y1b)**2)
    x2b=xb[i-1]+(h/2)*k21b
    y2b=yb[i-1]+(h/2)*k22b
    px2b=pxb[i-1]+(h/2)*k23b
    py2b=pyb[i-1]+(h/2)*k24b
    k31b=px2b
    k32b=py2b
    k33b=(-1)*x2b-2*(x2b)*(y2b)
    k34b=(-1)*y2b-((x2b)**2)+((y2b)**2)
    x3b=xb[i-1]+h*k31b
    y3b=yb[i-1]+h*k32b
    px3b=pxb[i-1]+h*k33b
    py3b=pyb[i-1]+h*k34b
    k41b=px3b
    k42b=py3b
    k43b=(-1)*x3b-2*(x3b)*(y3b)
    k44b=(-1)*y3b-((x3b)**2)+((y3b)**2)
    k1b=(1/6)*(k11b+2*k21b+2*k31b+k41b)
    k2b=(1/6)*(k12b+2*k22b+2*k32b+k42b)
    k3b=(1/6)*(k13b+2*k23b+2*k33b+k43b)
    k4b=(1/6)*(k14b+2*k24b+2*k34b+k44b)
    xb[i]=xb[i-1]+k1b*h
    yb[i]=yb[i-1]+k2b*h 
    pxb[i]=pxb[i-1]+k3b*h
    pyb[i]=pyb[i-1]+k4b*h
    
    
    if xb[i]*xb[i-1]<0 and pxb[i]>0 and pxb[i-1]>0:
            dt=-xb[i-1]/k1b
            Yb[i]=(yb[i-1]+k2b*dt)
            PYb[i]=(pyb[i-1]+k4b*dt)
            xb[i]=0
            i=i+1
    else:
            Yb[i]=0
            PYb[i]=0
            i=i+1
else :           
    plt.scatter(Yb,PYb,s=0.1,c='m')
    
i=0
xb[i]=0
yb[i]=0
pyb[i]=0.23
pxb[i]=(2*E-(pyb[i]**2)-(xb[i]**2)-(yb[i]**2)-2*(xb[i]**2)*yb[i]+(2*(yb[i]**3)/3))**(1/2)
i=i+1
print(pxb[0])

        
while i<=n:
    
    k11b=pxb[i-1]
    k12b=pyb[i-1]
    k13b=(-1)*xb[i-1]-2*xb[i-1]*yb[i-1]
    k14b=(-1)*yb[i-1]-(xb[i-1]**2)+(yb[i-1]**2)
    x1b=xb[i-1]+(h/2)*k11b
    y1b=yb[i-1]+(h/2)*k12b
    px1b=pxb[i-1]+(h/2)*k13b
    py1b=pyb[i-1]+(h/2)*k14b
    k21b=px1b
    k22b=py1b
    k23b=(-1)*x1b-2*(x1b)*(y1b)
    k24b=(-1)*y1b-((x1b)**2)+((y1b)**2)
    x2b=xb[i-1]+(h/2)*k21b
    y2b=yb[i-1]+(h/2)*k22b
    px2b=pxb[i-1]+(h/2)*k23b
    py2b=pyb[i-1]+(h/2)*k24b
    k31b=px2b
    k32b=py2b
    k33b=(-1)*x2b-2*(x2b)*(y2b)
    k34b=(-1)*y2b-((x2b)**2)+((y2b)**2)
    x3b=xb[i-1]+h*k31b
    y3b=yb[i-1]+h*k32b
    px3b=pxb[i-1]+h*k33b
    py3b=pyb[i-1]+h*k34b
    k41b=px3b
    k42b=py3b
    k43b=(-1)*x3b-2*(x3b)*(y3b)
    k44b=(-1)*y3b-((x3b)**2)+((y3b)**2)
    k1b=(1/6)*(k11b+2*k21b+2*k31b+k41b)
    k2b=(1/6)*(k12b+2*k22b+2*k32b+k42b)
    k3b=(1/6)*(k13b+2*k23b+2*k33b+k43b)
    k4b=(1/6)*(k14b+2*k24b+2*k34b+k44b)
    xb[i]=xb[i-1]+k1b*h
    yb[i]=yb[i-1]+k2b*h 
    pxb[i]=pxb[i-1]+k3b*h
    pyb[i]=pyb[i-1]+k4b*h
    
    
    if xb[i]*xb[i-1]<0 and pxb[i]>0 and pxb[i-1]>0:
            dt=-xb[i-1]/k1b
            Yb[i]=(yb[i-1]+k2b*dt)
            PYb[i]=(pyb[i-1]+k4b*dt)
            xb[i]=0
            i=i+1
    else:
            Yb[i]=0
            PYb[i]=0
            i=i+1
else :           
    plt.scatter(Yb,PYb,s=0.1,c='m')
i=0
xb[i]=0
yb[i]=0.08
pyb[i]=0.2
pxb[i]=(2*E-(pyb[i]**2)-(xb[i]**2)-(yb[i]**2)-2*(xb[i]**2)*yb[i]+(2*(yb[i]**3)/3))**(1/2)
i=i+1
print(pxb[0])

        
while i<=n:
    
    k11b=pxb[i-1]
    k12b=pyb[i-1]
    k13b=(-1)*xb[i-1]-2*xb[i-1]*yb[i-1]
    k14b=(-1)*yb[i-1]-(xb[i-1]**2)+(yb[i-1]**2)
    x1b=xb[i-1]+(h/2)*k11b
    y1b=yb[i-1]+(h/2)*k12b
    px1b=pxb[i-1]+(h/2)*k13b
    py1b=pyb[i-1]+(h/2)*k14b
    k21b=px1b
    k22b=py1b
    k23b=(-1)*x1b-2*(x1b)*(y1b)
    k24b=(-1)*y1b-((x1b)**2)+((y1b)**2)
    x2b=xb[i-1]+(h/2)*k21b
    y2b=yb[i-1]+(h/2)*k22b
    px2b=pxb[i-1]+(h/2)*k23b
    py2b=pyb[i-1]+(h/2)*k24b
    k31b=px2b
    k32b=py2b
    k33b=(-1)*x2b-2*(x2b)*(y2b)
    k34b=(-1)*y2b-((x2b)**2)+((y2b)**2)
    x3b=xb[i-1]+h*k31b
    y3b=yb[i-1]+h*k32b
    px3b=pxb[i-1]+h*k33b
    py3b=pyb[i-1]+h*k34b
    k41b=px3b
    k42b=py3b
    k43b=(-1)*x3b-2*(x3b)*(y3b)
    k44b=(-1)*y3b-((x3b)**2)+((y3b)**2)
    k1b=(1/6)*(k11b+2*k21b+2*k31b+k41b)
    k2b=(1/6)*(k12b+2*k22b+2*k32b+k42b)
    k3b=(1/6)*(k13b+2*k23b+2*k33b+k43b)
    k4b=(1/6)*(k14b+2*k24b+2*k34b+k44b)
    xb[i]=xb[i-1]+k1b*h
    yb[i]=yb[i-1]+k2b*h 
    pxb[i]=pxb[i-1]+k3b*h
    pyb[i]=pyb[i-1]+k4b*h
    
    
    if xb[i]*xb[i-1]<0 and pxb[i]>0 and pxb[i-1]>0:
            dt=-xb[i-1]/k1b
            Yb[i]=(yb[i-1]+k2b*dt)
            PYb[i]=(pyb[i-1]+k4b*dt)
            xb[i]=0
            i=i+1
    else:
            Yb[i]=0
            PYb[i]=0
            i=i+1
else :           
    plt.scatter(Yb,PYb,s=0.1,c='m')
    
i=0
xb[i]=0
yb[i]=0.08
pyb[i]=-0.2
pxb[i]=(2*E-(pyb[i]**2)-(xb[i]**2)-(yb[i]**2)-2*(xb[i]**2)*yb[i]+(2*(yb[i]**3)/3))**(1/2)
i=i+1
print(pxb[0])

        
while i<=n:
    
    k11b=pxb[i-1]
    k12b=pyb[i-1]
    k13b=(-1)*xb[i-1]-2*xb[i-1]*yb[i-1]
    k14b=(-1)*yb[i-1]-(xb[i-1]**2)+(yb[i-1]**2)
    x1b=xb[i-1]+(h/2)*k11b
    y1b=yb[i-1]+(h/2)*k12b
    px1b=pxb[i-1]+(h/2)*k13b
    py1b=pyb[i-1]+(h/2)*k14b
    k21b=px1b
    k22b=py1b
    k23b=(-1)*x1b-2*(x1b)*(y1b)
    k24b=(-1)*y1b-((x1b)**2)+((y1b)**2)
    x2b=xb[i-1]+(h/2)*k21b
    y2b=yb[i-1]+(h/2)*k22b
    px2b=pxb[i-1]+(h/2)*k23b
    py2b=pyb[i-1]+(h/2)*k24b
    k31b=px2b
    k32b=py2b
    k33b=(-1)*x2b-2*(x2b)*(y2b)
    k34b=(-1)*y2b-((x2b)**2)+((y2b)**2)
    x3b=xb[i-1]+h*k31b
    y3b=yb[i-1]+h*k32b
    px3b=pxb[i-1]+h*k33b
    py3b=pyb[i-1]+h*k34b
    k41b=px3b
    k42b=py3b
    k43b=(-1)*x3b-2*(x3b)*(y3b)
    k44b=(-1)*y3b-((x3b)**2)+((y3b)**2)
    k1b=(1/6)*(k11b+2*k21b+2*k31b+k41b)
    k2b=(1/6)*(k12b+2*k22b+2*k32b+k42b)
    k3b=(1/6)*(k13b+2*k23b+2*k33b+k43b)
    k4b=(1/6)*(k14b+2*k24b+2*k34b+k44b)
    xb[i]=xb[i-1]+k1b*h
    yb[i]=yb[i-1]+k2b*h 
    pxb[i]=pxb[i-1]+k3b*h
    pyb[i]=pyb[i-1]+k4b*h
    
    
    if xb[i]*xb[i-1]<0 and pxb[i]>0 and pxb[i-1]>0:
            dt=-xb[i-1]/k1b
            Yb[i]=(yb[i-1]+k2b*dt)
            PYb[i]=(pyb[i-1]+k4b*dt)
            xb[i]=0
            i=i+1
    else:
            Yb[i]=0
            PYb[i]=0
            i=i+1
else :           
    plt.scatter(Yb,PYb,s=0.1,c='m')
i=0
xb[i]=0
yb[i]=-0.35
pyb[i]=0
pxb[i]=(2*E-(pyb[i]**2)-(xb[i]**2)-(yb[i]**2)-2*(xb[i]**2)*yb[i]+(2*(yb[i]**3)/3))**(1/2)
i=i+1
print(pxb[0])

        
while i<=n:
    
    k11b=pxb[i-1]
    k12b=pyb[i-1]
    k13b=(-1)*xb[i-1]-2*xb[i-1]*yb[i-1]
    k14b=(-1)*yb[i-1]-(xb[i-1]**2)+(yb[i-1]**2)
    x1b=xb[i-1]+(h/2)*k11b
    y1b=yb[i-1]+(h/2)*k12b
    px1b=pxb[i-1]+(h/2)*k13b
    py1b=pyb[i-1]+(h/2)*k14b
    k21b=px1b
    k22b=py1b
    k23b=(-1)*x1b-2*(x1b)*(y1b)
    k24b=(-1)*y1b-((x1b)**2)+((y1b)**2)
    x2b=xb[i-1]+(h/2)*k21b
    y2b=yb[i-1]+(h/2)*k22b
    px2b=pxb[i-1]+(h/2)*k23b
    py2b=pyb[i-1]+(h/2)*k24b
    k31b=px2b
    k32b=py2b
    k33b=(-1)*x2b-2*(x2b)*(y2b)
    k34b=(-1)*y2b-((x2b)**2)+((y2b)**2)
    x3b=xb[i-1]+h*k31b
    y3b=yb[i-1]+h*k32b
    px3b=pxb[i-1]+h*k33b
    py3b=pyb[i-1]+h*k34b
    k41b=px3b
    k42b=py3b
    k43b=(-1)*x3b-2*(x3b)*(y3b)
    k44b=(-1)*y3b-((x3b)**2)+((y3b)**2)
    k1b=(1/6)*(k11b+2*k21b+2*k31b+k41b)
    k2b=(1/6)*(k12b+2*k22b+2*k32b+k42b)
    k3b=(1/6)*(k13b+2*k23b+2*k33b+k43b)
    k4b=(1/6)*(k14b+2*k24b+2*k34b+k44b)
    xb[i]=xb[i-1]+k1b*h
    yb[i]=yb[i-1]+k2b*h 
    pxb[i]=pxb[i-1]+k3b*h
    pyb[i]=pyb[i-1]+k4b*h
    
    
    if xb[i]*xb[i-1]<0 and pxb[i]>0 and pxb[i-1]>0:
            dt=-xb[i-1]/k1b
            Yb[i]=(yb[i-1]+k2b*dt)
            PYb[i]=(pyb[i-1]+k4b*dt)
            xb[i]=0
            i=i+1
    else:
            Yb[i]=0
            PYb[i]=0
            i=i+1
else :           
    plt.scatter(Yb,PYb,s=0.1,c='b')
    
i=0
xb[i]=0
yb[i]=-0.15
pyb[i]=-0.15
pxb[i]=(2*E-(pyb[i]**2)-(xb[i]**2)-(yb[i]**2)-2*(xb[i]**2)*yb[i]+(2*(yb[i]**3)/3))**(1/2)
i=i+1
print(pxb[0])

        
while i<=n:
    
    k11b=pxb[i-1]
    k12b=pyb[i-1]
    k13b=(-1)*xb[i-1]-2*xb[i-1]*yb[i-1]
    k14b=(-1)*yb[i-1]-(xb[i-1]**2)+(yb[i-1]**2)
    x1b=xb[i-1]+(h/2)*k11b
    y1b=yb[i-1]+(h/2)*k12b
    px1b=pxb[i-1]+(h/2)*k13b
    py1b=pyb[i-1]+(h/2)*k14b
    k21b=px1b
    k22b=py1b
    k23b=(-1)*x1b-2*(x1b)*(y1b)
    k24b=(-1)*y1b-((x1b)**2)+((y1b)**2)
    x2b=xb[i-1]+(h/2)*k21b
    y2b=yb[i-1]+(h/2)*k22b
    px2b=pxb[i-1]+(h/2)*k23b
    py2b=pyb[i-1]+(h/2)*k24b
    k31b=px2b
    k32b=py2b
    k33b=(-1)*x2b-2*(x2b)*(y2b)
    k34b=(-1)*y2b-((x2b)**2)+((y2b)**2)
    x3b=xb[i-1]+h*k31b
    y3b=yb[i-1]+h*k32b
    px3b=pxb[i-1]+h*k33b
    py3b=pyb[i-1]+h*k34b
    k41b=px3b
    k42b=py3b
    k43b=(-1)*x3b-2*(x3b)*(y3b)
    k44b=(-1)*y3b-((x3b)**2)+((y3b)**2)
    k1b=(1/6)*(k11b+2*k21b+2*k31b+k41b)
    k2b=(1/6)*(k12b+2*k22b+2*k32b+k42b)
    k3b=(1/6)*(k13b+2*k23b+2*k33b+k43b)
    k4b=(1/6)*(k14b+2*k24b+2*k34b+k44b)
    xb[i]=xb[i-1]+k1b*h
    yb[i]=yb[i-1]+k2b*h 
    pxb[i]=pxb[i-1]+k3b*h
    pyb[i]=pyb[i-1]+k4b*h
    
    
    if xb[i]*xb[i-1]<0 and pxb[i]>0 and pxb[i-1]>0:
            dt=-xb[i-1]/k1b
            Yb[i]=(yb[i-1]+k2b*dt)
            PYb[i]=(pyb[i-1]+k4b*dt)
            xb[i]=0
            i=i+1
    else:
            Yb[i]=0
            PYb[i]=0
            i=i+1
else :           
    plt.scatter(Yb,PYb,s=0.1,c='orange')

plt.show()
# Out:
# 0.5
# 0.4939041742416573
# 0.47658227691204236
# 0.4490167034754943
# 0.4208127057650866
# 0.40063751280511245
# 0.37682887362833545
# 0.3485535587730145
# 0.2724311839712921
# 0.21756225162774284
# 0.48949497784281026
# 0.4439594576084623
# 0.458257569495584
# 0.458257569495584
# 0.4439594576084623
# 0.45159864186391585
# 0.45159864186391585
# 0.31451020121240375
# 0.4502776920967771

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy import optimize, special
from numpy import *
from pylab import *
import decimal


E=1/8
plt.style.use("seaborn-whitegrid")
n=500000
h=2500/n
dt=0
xo=np.zeros(n+1,dtype='float64')
yo=np.zeros(n+1,dtype='float64')
pxo=np.zeros(n+1,dtype='float64')
pyo=np.zeros(n+1,dtype='float64')
Yo=np.zeros(n+1,dtype='float64')
PYo=np.zeros(n+1,dtype='float64')
xl=np.zeros(n+1,dtype='float64')
yl=np.zeros(n+1,dtype='float64')
pxl=np.zeros(n+1,dtype='float64')
pyl=np.zeros(n+1,dtype='float64')
Yl=np.zeros(n+1,dtype='float64')
PYl=np.zeros(n+1,dtype='float64')
xu=np.zeros(n+1,dtype='float64')
yu=np.zeros(n+1,dtype='float64')
pxu=np.zeros(n+1,dtype='float64')
pyu=np.zeros(n+1,dtype='float64')
Yu=np.zeros(n+1,dtype='float64')
PYu=np.zeros(n+1,dtype='float64')
xd=np.zeros(n+1,dtype='float64')
yd=np.zeros(n+1,dtype='float64')
pxd=np.zeros(n+1,dtype='float64')
pyd=np.zeros(n+1,dtype='float64')
Yd=np.zeros(n+1,dtype='float64')
PYd=np.zeros(n+1,dtype='float64')
xb=np.zeros(n+1,dtype='float64')
yb=np.zeros(n+1,dtype='float64')
pxb=np.zeros(n+1,dtype='float64')
pyb=np.zeros(n+1,dtype='float64')
Yb=np.zeros(n+1,dtype='float64')
PYb=np.zeros(n+1,dtype='float64')

    







i=0
xb[i]=0
yb[i]=-0.15
pyb[i]=0
pxb[i]=(2*E-(pyb[i]**2)-(xb[i]**2)-(yb[i]**2)-2*(xb[i]**2)*yb[i]+(2*(yb[i]**3)/3))**(1/2)
i=i+1
print(pxb[0])

        
while i<=n:
    
    k11b=pxb[i-1]
    k12b=pyb[i-1]
    k13b=(-1)*xb[i-1]-2*xb[i-1]*yb[i-1]
    k14b=(-1)*yb[i-1]-(xb[i-1]**2)+(yb[i-1]**2)
    x1b=xb[i-1]+(h/2)*k11b
    y1b=yb[i-1]+(h/2)*k12b
    px1b=pxb[i-1]+(h/2)*k13b
    py1b=pyb[i-1]+(h/2)*k14b
    k21b=px1b
    k22b=py1b
    k23b=(-1)*x1b-2*(x1b)*(y1b)
    k24b=(-1)*y1b-((x1b)**2)+((y1b)**2)
    x2b=xb[i-1]+(h/2)*k21b
    y2b=yb[i-1]+(h/2)*k22b
    px2b=pxb[i-1]+(h/2)*k23b
    py2b=pyb[i-1]+(h/2)*k24b
    k31b=px2b
    k32b=py2b
    k33b=(-1)*x2b-2*(x2b)*(y2b)
    k34b=(-1)*y2b-((x2b)**2)+((y2b)**2)
    x3b=xb[i-1]+h*k31b
    y3b=yb[i-1]+h*k32b
    px3b=pxb[i-1]+h*k33b
    py3b=pyb[i-1]+h*k34b
    k41b=px3b
    k42b=py3b
    k43b=(-1)*x3b-2*(x3b)*(y3b)
    k44b=(-1)*y3b-((x3b)**2)+((y3b)**2)
    k1b=(1/6)*(k11b+2*k21b+2*k31b+k41b)
    k2b=(1/6)*(k12b+2*k22b+2*k32b+k42b)
    k3b=(1/6)*(k13b+2*k23b+2*k33b+k43b)
    k4b=(1/6)*(k14b+2*k24b+2*k34b+k44b)
    xb[i]=xb[i-1]+k1b*h
    yb[i]=yb[i-1]+k2b*h 
    pxb[i]=pxb[i-1]+k3b*h
    pyb[i]=pyb[i-1]+k4b*h
    
    
    if xb[i]*xb[i-1]<0 and pxb[i]>0 and pxb[i-1]>0:
            dt=-xb[i-1]/k1b
            Yb[i]=(yb[i-1]+k2b*dt)
            PYb[i]=(pyb[i-1]+k4b*dt)
            xb[i]=0
            i=i+1
    else:
            Yb[i]=0
            PYb[i]=0
            i=i+1
else :           
    plt.scatter(Yb,PYb,s=0.1)
    


plt.show()
# Out:
# 0.47460509900337144

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy import optimize, special
from numpy import *
from pylab import *
import decimal


E=1/8
plt.style.use("seaborn-whitegrid")
n=5000000
h=2500/n
dt=0
xo=np.zeros(n+1,dtype='float64')
yo=np.zeros(n+1,dtype='float64')
pxo=np.zeros(n+1,dtype='float64')
pyo=np.zeros(n+1,dtype='float64')
Yo=np.zeros(n+1,dtype='float64')
PYo=np.zeros(n+1,dtype='float64')
xl=np.zeros(n+1,dtype='float64')
yl=np.zeros(n+1,dtype='float64')
pxl=np.zeros(n+1,dtype='float64')
pyl=np.zeros(n+1,dtype='float64')
Yl=np.zeros(n+1,dtype='float64')
PYl=np.zeros(n+1,dtype='float64')
xu=np.zeros(n+1,dtype='float64')
yu=np.zeros(n+1,dtype='float64')
pxu=np.zeros(n+1,dtype='float64')
pyu=np.zeros(n+1,dtype='float64')
Yu=np.zeros(n+1,dtype='float64')
PYu=np.zeros(n+1,dtype='float64')
xd=np.zeros(n+1,dtype='float64')
yd=np.zeros(n+1,dtype='float64')
pxd=np.zeros(n+1,dtype='float64')
pyd=np.zeros(n+1,dtype='float64')
Yd=np.zeros(n+1,dtype='float64')
PYd=np.zeros(n+1,dtype='float64')
xb=np.zeros(n+1,dtype='float64')
yb=np.zeros(n+1,dtype='float64')
pxb=np.zeros(n+1,dtype='float64')
pyb=np.zeros(n+1,dtype='float64')
Yb=np.zeros(n+1,dtype='float64')
PYb=np.zeros(n+1,dtype='float64')
i=0
xo[i]=0
yo[i]=0
pyo[i]=0
pxo[i]=(2*E-(pyo[i]**2)-(xo[i]**2)-(yo[i]**2)-2*(xo[i]**2)*yo[i]+(2*(yo[i]**3)/3))**(1/2)
i=i+1
print(pxo[0])

        
while i<=n:
    
    k11o=pxo[i-1]
    k12o=pyo[i-1]
    k13o=(-1)*xo[i-1]-2*xo[i-1]*yo[i-1]
    k14o=(-1)*yo[i-1]-(xo[i-1]**2)+(yo[i-1]**2)
    x1o=xo[i-1]+(h/2)*k11o
    y1o=yo[i-1]+(h/2)*k12o
    px1o=pxo[i-1]+(h/2)*k13o
    py1o=pyo[i-1]+(h/2)*k14o
    k21o=px1o
    k22o=py1o
    k23o=(-1)*x1o-2*(x1o)*(y1o)
    k24o=(-1)*y1o-((x1o)**2)+((y1o)**2)
    x2o=xo[i-1]+(h/2)*k21o
    y2o=yo[i-1]+(h/2)*k22o
    px2o=pxo[i-1]+(h/2)*k23o
    py2o=pyo[i-1]+(h/2)*k24o
    k31o=px2o
    k32o=py2o
    k33o=(-1)*x2o-2*(x2o)*(y2o)
    k34o=(-1)*y2o-((x2o)**2)+((y2o)**2)
    x3o=xo[i-1]+h*k31o
    y3o=yo[i-1]+h*k32o
    px3o=pxo[i-1]+h*k33o
    py3o=pyo[i-1]+h*k34o
    k41o=px3o
    k42o=py3o
    k43o=(-1)*x3o-2*(x3o)*(y3o)
    k44o=(-1)*y3o-((x3o)**2)+((y3o)**2)
    k1o=(1/6)*(k11o+2*k21o+2*k31o+k41o)
    k2o=(1/6)*(k12o+2*k22o+2*k32o+k42o)
    k3o=(1/6)*(k13o+2*k23o+2*k33o+k43o)
    k4o=(1/6)*(k14o+2*k24o+2*k34o+k44o)
    xo[i]=xo[i-1]+k1o*h
    yo[i]=yo[i-1]+k2o*h 
    pxo[i]=pxo[i-1]+k3o*h
    pyo[i]=pyo[i-1]+k4o*h
    
    if xo[i]*xo[i-1]<0 and pxo[i]>0 and pxo[i-1]>0:
            dt=-xo[i-1]/k1o
            xo[i]=0
            Yo[i]=(yo[i-1]+k2o*dt)
            PYo[i]=(pyo[i-1]+k4o*dt)
            i=i+1
    else:
            Yo[i]=0
            PYo[i]=0
            i=i+1
else :           
    plt.scatter(Yo,PYo,s=0.1,c='r')
    
i=0
xl[i]=0
yl[i]=0.08
pyl[i]=0
pxl[i]=(2*E-(pyl[i]**2)-(xl[i]**2)-(yl[i]**2)-2*(xl[i]**2)*yl[i]+(2*(yl[i]**3)/3))**(1/2)
i=i+1
print(pxl[0])

        
while i<=n:
    
    k11l=pxl[i-1]
    k12l=pyl[i-1]
    k13l=(-1)*xl[i-1]-2*xl[i-1]*yl[i-1]
    k14l=(-1)*yl[i-1]-(xl[i-1]**2)+(yl[i-1]**2)
    x1l=xl[i-1]+(h/2)*k11l
    y1l=yl[i-1]+(h/2)*k12l
    px1l=pxl[i-1]+(h/2)*k13l
    py1l=pyl[i-1]+(h/2)*k14l
    k21l=px1l
    k22l=py1l
    k23l=(-1)*x1l-2*(x1l)*(y1l)
    k24l=(-1)*y1l-((x1l)**2)+((y1l)**2)
    x2l=xl[i-1]+(h/2)*k21l
    y2l=yl[i-1]+(h/2)*k22l
    px2l=pxl[i-1]+(h/2)*k23l
    py2l=pyl[i-1]+(h/2)*k24l
    k31l=px2l
    k32l=py2l
    k33l=(-1)*x2l-2*(x2l)*(y2l)
    k34l=(-1)*y2l-((x2l)**2)+((y2l)**2)
    x3l=xl[i-1]+h*k31l
    y3l=yl[i-1]+h*k32l
    px3l=pxl[i-1]+h*k33l
    py3l=pyl[i-1]+h*k34l
    k41l=px3l
    k42l=py3l
    k43l=(-1)*x3l-2*(x3l)*(y3l)
    k44l=(-1)*y3l-((x3l)**2)+((y3l)**2)
    k1l=(1/6)*(k11l+2*k21l+2*k31l+k41l)
    k2l=(1/6)*(k12l+2*k22l+2*k32l+k42l)
    k3l=(1/6)*(k13l+2*k23l+2*k33l+k43l)
    k4l=(1/6)*(k14l+2*k24l+2*k34l+k44l)
    xl[i]=xl[i-1]+k1l*h
    yl[i]=yl[i-1]+k2l*h 
    pxl[i]=pxl[i-1]+k3l*h
    pyl[i]=pyl[i-1]+k4l*h
    
    
    if xl[i]*xl[i-1]<0 and pxl[i]>0 and pxl[i-1]>0:
            dt=-xl[i-1]/k1l
            Yl[i]=(yl[i-1]+k2l*dt)
            PYl[i]=(pyl[i-1]+k4l*dt)
            xl[i]=0
            i=i+1
    else:
            Yl[i]=0
            PYl[i]=0
            i=i+1
else :           
    plt.scatter(Yl,PYl,s=0.1,c='r')

i=0
xu[i]=0
yu[i]=0.16
pyu[i]=0
pxu[i]=(2*E-(pyu[i]**2)-(xu[i]**2)-(yu[i]**2)-2*(xu[i]**2)*yu[i]+(2*(yu[i]**3)/3))**(1/2)
i=i+1
print(pxu[0])

        
while i<=n:
   
    k11u=pxu[i-1]
    k12u=pyu[i-1]
    k13u=(-1)*xu[i-1]-2*xu[i-1]*yu[i-1]
    k14u=(-1)*yu[i-1]-(xu[i-1]**2)+(yu[i-1]**2)
    x1u=xu[i-1]+(h/2)*k11u
    y1u=yu[i-1]+(h/2)*k12u
    px1u=pxu[i-1]+(h/2)*k13u
    py1u=pyu[i-1]+(h/2)*k14u
    k21u=px1u
    k22u=py1u
    k23u=(-1)*x1u-2*(x1u)*(y1u)
    k24u=(-1)*y1u-((x1u)**2)+((y1u)**2)
    x2u=xu[i-1]+(h/2)*k21u
    y2u=yu[i-1]+(h/2)*k22u
    px2u=pxu[i-1]+(h/2)*k23u
    py2u=pyu[i-1]+(h/2)*k24u
    k31u=px2u
    k32u=py2u
    k33u=(-1)*x2u-2*(x2u)*(y2u)
    k34u=(-1)*y2u-((x2u)**2)+((y2u)**2)
    x3u=xu[i-1]+h*k31u
    y3u=yu[i-1]+h*k32u
    px3u=pxu[i-1]+h*k33u
    py3u=pyu[i-1]+h*k34u
    k41u=px3u
    k42u=py3u
    k43u=(-1)*x3u-2*(x3u)*(y3u)
    k44u=(-1)*y3u-((x3u)**2)+((y3u)**2)
    k1u=(1/6)*(k11u+2*k21u+2*k31u+k41u)
    k2u=(1/6)*(k12u+2*k22u+2*k32u+k42u)
    k3u=(1/6)*(k13u+2*k23u+2*k33u+k43u)
    k4u=(1/6)*(k14u+2*k24u+2*k34u+k44u)
    xu[i]=xu[i-1]+k1u*h
    yu[i]=yu[i-1]+k2u*h 
    pxu[i]=pxu[i-1]+k3u*h
    pyu[i]=pyu[i-1]+k4u*h
    
    
    if xu[i]*xu[i-1]<0 and pxu[i]>0 and pxu[i-1]>0:
            dt=-xu[i-1]/k1u
            Yu[i]=(yu[i-1]+k2u*dt)
            PYu[i]=(pyu[i-1]+k4u*dt)
            xu[i]=0
            i=i+1
    else:
            Yu[i]=0
            PYu[i]=0
            i=i+1
else :           
    plt.scatter(Yu,PYu,s=0.1,c='r')
    
i=0
xu[i]=0
yu[i]=0.24
pyu[i]=0
pxu[i]=(2*E-(pyu[i]**2)-(xu[i]**2)-(yu[i]**2)-2*(xu[i]**2)*yu[i]+(2*(yu[i]**3)/3))**(1/2)
i=i+1
print(pxu[0])

        
while i<=n:
   
    k11u=pxu[i-1]
    k12u=pyu[i-1]
    k13u=(-1)*xu[i-1]-2*xu[i-1]*yu[i-1]
    k14u=(-1)*yu[i-1]-(xu[i-1]**2)+(yu[i-1]**2)
    x1u=xu[i-1]+(h/2)*k11u
    y1u=yu[i-1]+(h/2)*k12u
    px1u=pxu[i-1]+(h/2)*k13u
    py1u=pyu[i-1]+(h/2)*k14u
    k21u=px1u
    k22u=py1u
    k23u=(-1)*x1u-2*(x1u)*(y1u)
    k24u=(-1)*y1u-((x1u)**2)+((y1u)**2)
    x2u=xu[i-1]+(h/2)*k21u
    y2u=yu[i-1]+(h/2)*k22u
    px2u=pxu[i-1]+(h/2)*k23u
    py2u=pyu[i-1]+(h/2)*k24u
    k31u=px2u
    k32u=py2u
    k33u=(-1)*x2u-2*(x2u)*(y2u)
    k34u=(-1)*y2u-((x2u)**2)+((y2u)**2)
    x3u=xu[i-1]+h*k31u
    y3u=yu[i-1]+h*k32u
    px3u=pxu[i-1]+h*k33u
    py3u=pyu[i-1]+h*k34u
    k41u=px3u
    k42u=py3u
    k43u=(-1)*x3u-2*(x3u)*(y3u)
    k44u=(-1)*y3u-((x3u)**2)+((y3u)**2)
    k1u=(1/6)*(k11u+2*k21u+2*k31u+k41u)
    k2u=(1/6)*(k12u+2*k22u+2*k32u+k42u)
    k3u=(1/6)*(k13u+2*k23u+2*k33u+k43u)
    k4u=(1/6)*(k14u+2*k24u+2*k34u+k44u)
    xu[i]=xu[i-1]+k1u*h
    yu[i]=yu[i-1]+k2u*h 
    pxu[i]=pxu[i-1]+k3u*h
    pyu[i]=pyu[i-1]+k4u*h
    
    
    if xu[i]*xu[i-1]<0 and pxu[i]>0 and pxu[i-1]>0:
            dt=-xu[i-1]/k1u
            Yu[i]=(yu[i-1]+k2u*dt)
            PYu[i]=(pyu[i-1]+k4u*dt)
            xu[i]=0
            i=i+1
    else:
            Yu[i]=0
            PYu[i]=0
            i=i+1
else :           
    plt.scatter(Yu,PYu,s=0.1,c='r')

i=0
xu[i]=0
yu[i]=-0.25
pyu[i]=0
pxu[i]=(2*E-(pyu[i]**2)-(xu[i]**2)-(yu[i]**2)-2*(xu[i]**2)*yu[i]+(2*(yu[i]**3)/3))**(1/2)
i=i+1
print(pxu[0])

        
while i<=n:
   
    k11u=pxu[i-1]
    k12u=pyu[i-1]
    k13u=(-1)*xu[i-1]-2*xu[i-1]*yu[i-1]
    k14u=(-1)*yu[i-1]-(xu[i-1]**2)+(yu[i-1]**2)
    x1u=xu[i-1]+(h/2)*k11u
    y1u=yu[i-1]+(h/2)*k12u
    px1u=pxu[i-1]+(h/2)*k13u
    py1u=pyu[i-1]+(h/2)*k14u
    k21u=px1u
    k22u=py1u
    k23u=(-1)*x1u-2*(x1u)*(y1u)
    k24u=(-1)*y1u-((x1u)**2)+((y1u)**2)
    x2u=xu[i-1]+(h/2)*k21u
    y2u=yu[i-1]+(h/2)*k22u
    px2u=pxu[i-1]+(h/2)*k23u
    py2u=pyu[i-1]+(h/2)*k24u
    k31u=px2u
    k32u=py2u
    k33u=(-1)*x2u-2*(x2u)*(y2u)
    k34u=(-1)*y2u-((x2u)**2)+((y2u)**2)
    x3u=xu[i-1]+h*k31u
    y3u=yu[i-1]+h*k32u
    px3u=pxu[i-1]+h*k33u
    py3u=pyu[i-1]+h*k34u
    k41u=px3u
    k42u=py3u
    k43u=(-1)*x3u-2*(x3u)*(y3u)
    k44u=(-1)*y3u-((x3u)**2)+((y3u)**2)
    k1u=(1/6)*(k11u+2*k21u+2*k31u+k41u)
    k2u=(1/6)*(k12u+2*k22u+2*k32u+k42u)
    k3u=(1/6)*(k13u+2*k23u+2*k33u+k43u)
    k4u=(1/6)*(k14u+2*k24u+2*k34u+k44u)
    xu[i]=xu[i-1]+k1u*h
    yu[i]=yu[i-1]+k2u*h 
    pxu[i]=pxu[i-1]+k3u*h
    pyu[i]=pyu[i-1]+k4u*h
    
    
    if xu[i]*xu[i-1]<0 and pxu[i]>0 and pxu[i-1]>0:
            dt=-xu[i-1]/k1u
            Yu[i]=(yu[i-1]+k2u*dt)
            PYu[i]=(pyu[i-1]+k4u*dt)
            xu[i]=0
            i=i+1
    else:
            Yu[i]=0
            PYu[i]=0
            i=i+1
else :           
    plt.scatter(Yu,PYu,s=0.1,c='b')
i=0
xu[i]=0
yu[i]=-0.275
pyu[i]=0
pxu[i]=(2*E-(pyu[i]**2)-(xu[i]**2)-(yu[i]**2)-2*(xu[i]**2)*yu[i]+(2*(yu[i]**3)/3))**(1/2)
i=i+1
print(pxu[0])

        
while i<=n:
   
    k11u=pxu[i-1]
    k12u=pyu[i-1]
    k13u=(-1)*xu[i-1]-2*xu[i-1]*yu[i-1]
    k14u=(-1)*yu[i-1]-(xu[i-1]**2)+(yu[i-1]**2)
    x1u=xu[i-1]+(h/2)*k11u
    y1u=yu[i-1]+(h/2)*k12u
    px1u=pxu[i-1]+(h/2)*k13u
    py1u=pyu[i-1]+(h/2)*k14u
    k21u=px1u
    k22u=py1u
    k23u=(-1)*x1u-2*(x1u)*(y1u)
    k24u=(-1)*y1u-((x1u)**2)+((y1u)**2)
    x2u=xu[i-1]+(h/2)*k21u
    y2u=yu[i-1]+(h/2)*k22u
    px2u=pxu[i-1]+(h/2)*k23u
    py2u=pyu[i-1]+(h/2)*k24u
    k31u=px2u
    k32u=py2u
    k33u=(-1)*x2u-2*(x2u)*(y2u)
    k34u=(-1)*y2u-((x2u)**2)+((y2u)**2)
    x3u=xu[i-1]+h*k31u
    y3u=yu[i-1]+h*k32u
    px3u=pxu[i-1]+h*k33u
    py3u=pyu[i-1]+h*k34u
    k41u=px3u
    k42u=py3u
    k43u=(-1)*x3u-2*(x3u)*(y3u)
    k44u=(-1)*y3u-((x3u)**2)+((y3u)**2)
    k1u=(1/6)*(k11u+2*k21u+2*k31u+k41u)
    k2u=(1/6)*(k12u+2*k22u+2*k32u+k42u)
    k3u=(1/6)*(k13u+2*k23u+2*k33u+k43u)
    k4u=(1/6)*(k14u+2*k24u+2*k34u+k44u)
    xu[i]=xu[i-1]+k1u*h
    yu[i]=yu[i-1]+k2u*h 
    pxu[i]=pxu[i-1]+k3u*h
    pyu[i]=pyu[i-1]+k4u*h
    
    
    if xu[i]*xu[i-1]<0 and pxu[i]>0 and pxu[i-1]>0:
            dt=-xu[i-1]/k1u
            Yu[i]=(yu[i-1]+k2u*dt)
            PYu[i]=(pyu[i-1]+k4u*dt)
            xu[i]=0
            i=i+1
    else:
            Yu[i]=0
            PYu[i]=0
            i=i+1
else :           
    plt.scatter(Yu,PYu,s=0.1,c='b')
i=0
xd[i]=0
yd[i]=-0.3
pyd[i]=0
pxd[i]=(2*E-(pyd[i]**2)-(xd[i]**2)-(yd[i]**2)-2*(xd[i]**2)*yd[i]+(2*(yd[i]**3)/3))**(1/2)
i=i+1
print(pxd[0])

        
while i<=n:
    
    k11d=pxd[i-1]
    k12d=pyd[i-1]
    k13d=(-1)*xd[i-1]-2*xd[i-1]*yd[i-1]
    k14d=(-1)*yd[i-1]-(xd[i-1]**2)+(yd[i-1]**2)
    x1d=xd[i-1]+(h/2)*k11d
    y1d=yd[i-1]+(h/2)*k12d
    px1d=pxd[i-1]+(h/2)*k13d
    py1d=pyd[i-1]+(h/2)*k14d
    k21d=px1d
    k22d=py1d
    k23d=(-1)*x1d-2*(x1d)*(y1d)
    k24d=(-1)*y1d-((x1d)**2)+((y1d)**2)
    x2d=xd[i-1]+(h/2)*k21d
    y2d=yd[i-1]+(h/2)*k22d
    px2d=pxd[i-1]+(h/2)*k23d
    py2d=pyd[i-1]+(h/2)*k24d
    k31d=px2d
    k32d=py2d
    k33d=(-1)*x2d-2*(x2d)*(y2d)
    k34d=(-1)*y2d-((x2d)**2)+((y2d)**2)
    x3d=xd[i-1]+h*k31d
    y3d=yd[i-1]+h*k32d
    px3d=pxd[i-1]+h*k33d
    py3d=pyd[i-1]+h*k34d
    k41d=px3d
    k42d=py3d
    k43d=(-1)*x3d-2*(x3d)*(y3d)
    k44d=(-1)*y3d-((x3d)**2)+((y3d)**2)
    k1d=(1/6)*(k11d+2*k21d+2*k31d+k41d)
    k2d=(1/6)*(k12d+2*k22d+2*k32d+k42d)
    k3d=(1/6)*(k13d+2*k23d+2*k33d+k43d)
    k4d=(1/6)*(k14d+2*k24d+2*k34d+k44d)
    xd[i]=xd[i-1]+k1d*h
    yd[i]=yd[i-1]+k2d*h 
    pxd[i]=pxd[i-1]+k3d*h
    pyd[i]=pyd[i-1]+k4d*h
    
    
    if xd[i]*xd[i-1]<0 and pxd[i]>0 and pxd[i-1]>0:
            dt=-xd[i-1]/k1d
            Yd[i]=(yd[i-1]+k2d*dt)
            PYd[i]=(pyd[i-1]+k4d*dt)
            xd[i]=0
            i=i+1
    else:
            Yd[i]=0
            PYd[i]=0
            i=i+1
else :           
    plt.scatter(Yd,PYd,s=0.1,c='b')
i=0
xd[i]=0
yd[i]=-0.325
pyd[i]=0
pxd[i]=(2*E-(pyd[i]**2)-(xd[i]**2)-(yd[i]**2)-2*(xd[i]**2)*yd[i]+(2*(yd[i]**3)/3))**(1/2)
i=i+1
print(pxd[0])

        
while i<=n:
    
    k11d=pxd[i-1]
    k12d=pyd[i-1]
    k13d=(-1)*xd[i-1]-2*xd[i-1]*yd[i-1]
    k14d=(-1)*yd[i-1]-(xd[i-1]**2)+(yd[i-1]**2)
    x1d=xd[i-1]+(h/2)*k11d
    y1d=yd[i-1]+(h/2)*k12d
    px1d=pxd[i-1]+(h/2)*k13d
    py1d=pyd[i-1]+(h/2)*k14d
    k21d=px1d
    k22d=py1d
    k23d=(-1)*x1d-2*(x1d)*(y1d)
    k24d=(-1)*y1d-((x1d)**2)+((y1d)**2)
    x2d=xd[i-1]+(h/2)*k21d
    y2d=yd[i-1]+(h/2)*k22d
    px2d=pxd[i-1]+(h/2)*k23d
    py2d=pyd[i-1]+(h/2)*k24d
    k31d=px2d
    k32d=py2d
    k33d=(-1)*x2d-2*(x2d)*(y2d)
    k34d=(-1)*y2d-((x2d)**2)+((y2d)**2)
    x3d=xd[i-1]+h*k31d
    y3d=yd[i-1]+h*k32d
    px3d=pxd[i-1]+h*k33d
    py3d=pyd[i-1]+h*k34d
    k41d=px3d
    k42d=py3d
    k43d=(-1)*x3d-2*(x3d)*(y3d)
    k44d=(-1)*y3d-((x3d)**2)+((y3d)**2)
    k1d=(1/6)*(k11d+2*k21d+2*k31d+k41d)
    k2d=(1/6)*(k12d+2*k22d+2*k32d+k42d)
    k3d=(1/6)*(k13d+2*k23d+2*k33d+k43d)
    k4d=(1/6)*(k14d+2*k24d+2*k34d+k44d)
    xd[i]=xd[i-1]+k1d*h
    yd[i]=yd[i-1]+k2d*h 
    pxd[i]=pxd[i-1]+k3d*h
    pyd[i]=pyd[i-1]+k4d*h
    
    
    if xd[i]*xd[i-1]<0 and pxd[i]>0 and pxd[i-1]>0:
            dt=-xd[i-1]/k1d
            Yd[i]=(yd[i-1]+k2d*dt)
            PYd[i]=(pyd[i-1]+k4d*dt)
            xd[i]=0
            i=i+1
    else:
            Yd[i]=0
            PYd[i]=0
            i=i+1
else :           
    plt.scatter(Yd,PYd,s=0.1,c='b')
i=0
xd[i]=0
yd[i]=-0.375
pyd[i]=0
pxd[i]=(2*E-(pyd[i]**2)-(xd[i]**2)-(yd[i]**2)-2*(xd[i]**2)*yd[i]+(2*(yd[i]**3)/3))**(1/2)
i=i+1
print(pxd[0])

        
while i<=n:
    
    k11d=pxd[i-1]
    k12d=pyd[i-1]
    k13d=(-1)*xd[i-1]-2*xd[i-1]*yd[i-1]
    k14d=(-1)*yd[i-1]-(xd[i-1]**2)+(yd[i-1]**2)
    x1d=xd[i-1]+(h/2)*k11d
    y1d=yd[i-1]+(h/2)*k12d
    px1d=pxd[i-1]+(h/2)*k13d
    py1d=pyd[i-1]+(h/2)*k14d
    k21d=px1d
    k22d=py1d
    k23d=(-1)*x1d-2*(x1d)*(y1d)
    k24d=(-1)*y1d-((x1d)**2)+((y1d)**2)
    x2d=xd[i-1]+(h/2)*k21d
    y2d=yd[i-1]+(h/2)*k22d
    px2d=pxd[i-1]+(h/2)*k23d
    py2d=pyd[i-1]+(h/2)*k24d
    k31d=px2d
    k32d=py2d
    k33d=(-1)*x2d-2*(x2d)*(y2d)
    k34d=(-1)*y2d-((x2d)**2)+((y2d)**2)
    x3d=xd[i-1]+h*k31d
    y3d=yd[i-1]+h*k32d
    px3d=pxd[i-1]+h*k33d
    py3d=pyd[i-1]+h*k34d
    k41d=px3d
    k42d=py3d
    k43d=(-1)*x3d-2*(x3d)*(y3d)
    k44d=(-1)*y3d-((x3d)**2)+((y3d)**2)
    k1d=(1/6)*(k11d+2*k21d+2*k31d+k41d)
    k2d=(1/6)*(k12d+2*k22d+2*k32d+k42d)
    k3d=(1/6)*(k13d+2*k23d+2*k33d+k43d)
    k4d=(1/6)*(k14d+2*k24d+2*k34d+k44d)
    xd[i]=xd[i-1]+k1d*h
    yd[i]=yd[i-1]+k2d*h 
    pxd[i]=pxd[i-1]+k3d*h
    pyd[i]=pyd[i-1]+k4d*h
    
    
    if xd[i]*xd[i-1]<0 and pxd[i]>0 and pxd[i-1]>0:
            dt=-xd[i-1]/k1d
            Yd[i]=(yd[i-1]+k2d*dt)
            PYd[i]=(pyd[i-1]+k4d*dt)
            xd[i]=0
            i=i+1
    else:
            Yd[i]=0
            PYd[i]=0
            i=i+1
else :           
    plt.scatter(Yd,PYd,s=0.1,c='b')
i=0
xb[i]=0
yb[i]=-0.4
pyb[i]=0
pxb[i]=(2*E-(pyb[i]**2)-(xb[i]**2)-(yb[i]**2)-2*(xb[i]**2)*yb[i]+(2*(yb[i]**3)/3))**(1/2)
i=i+1
print(pxb[0])

        
while i<=n:
    
    k11b=pxb[i-1]
    k12b=pyb[i-1]
    k13b=(-1)*xb[i-1]-2*xb[i-1]*yb[i-1]
    k14b=(-1)*yb[i-1]-(xb[i-1]**2)+(yb[i-1]**2)
    x1b=xb[i-1]+(h/2)*k11b
    y1b=yb[i-1]+(h/2)*k12b
    px1b=pxb[i-1]+(h/2)*k13b
    py1b=pyb[i-1]+(h/2)*k14b
    k21b=px1b
    k22b=py1b
    k23b=(-1)*x1b-2*(x1b)*(y1b)
    k24b=(-1)*y1b-((x1b)**2)+((y1b)**2)
    x2b=xb[i-1]+(h/2)*k21b
    y2b=yb[i-1]+(h/2)*k22b
    px2b=pxb[i-1]+(h/2)*k23b
    py2b=pyb[i-1]+(h/2)*k24b
    k31b=px2b
    k32b=py2b
    k33b=(-1)*x2b-2*(x2b)*(y2b)
    k34b=(-1)*y2b-((x2b)**2)+((y2b)**2)
    x3b=xb[i-1]+h*k31b
    y3b=yb[i-1]+h*k32b
    px3b=pxb[i-1]+h*k33b
    py3b=pyb[i-1]+h*k34b
    k41b=px3b
    k42b=py3b
    k43b=(-1)*x3b-2*(x3b)*(y3b)
    k44b=(-1)*y3b-((x3b)**2)+((y3b)**2)
    k1b=(1/6)*(k11b+2*k21b+2*k31b+k41b)
    k2b=(1/6)*(k12b+2*k22b+2*k32b+k42b)
    k3b=(1/6)*(k13b+2*k23b+2*k33b+k43b)
    k4b=(1/6)*(k14b+2*k24b+2*k34b+k44b)
    xb[i]=xb[i-1]+k1b*h
    yb[i]=yb[i-1]+k2b*h 
    pxb[i]=pxb[i-1]+k3b*h
    pyb[i]=pyb[i-1]+k4b*h
    
    
    if xb[i]*xb[i-1]<0 and pxb[i]>0 and pxb[i-1]>0:
            dt=-xb[i-1]/k1b
            Yb[i]=(yb[i-1]+k2b*dt)
            PYb[i]=(pyb[i-1]+k4b*dt)
            xb[i]=0
            i=i+1
    else:
            Yb[i]=0
            PYb[i]=0
            i=i+1
else :           
    plt.scatter(Yb,PYb,s=0.1,c='b')
    
i=0
xb[i]=0
yb[i]=0.02
pyb[i]=0.1
pxb[i]=(2*E-(pyb[i]**2)-(xb[i]**2)-(yb[i]**2)-2*(xb[i]**2)*yb[i]+(2*(yb[i]**3)/3))**(1/2)
i=i+1
print(pxb[0])

        
while i<=n:
    
    k11b=pxb[i-1]
    k12b=pyb[i-1]
    k13b=(-1)*xb[i-1]-2*xb[i-1]*yb[i-1]
    k14b=(-1)*yb[i-1]-(xb[i-1]**2)+(yb[i-1]**2)
    x1b=xb[i-1]+(h/2)*k11b
    y1b=yb[i-1]+(h/2)*k12b
    px1b=pxb[i-1]+(h/2)*k13b
    py1b=pyb[i-1]+(h/2)*k14b
    k21b=px1b
    k22b=py1b
    k23b=(-1)*x1b-2*(x1b)*(y1b)
    k24b=(-1)*y1b-((x1b)**2)+((y1b)**2)
    x2b=xb[i-1]+(h/2)*k21b
    y2b=yb[i-1]+(h/2)*k22b
    px2b=pxb[i-1]+(h/2)*k23b
    py2b=pyb[i-1]+(h/2)*k24b
    k31b=px2b
    k32b=py2b
    k33b=(-1)*x2b-2*(x2b)*(y2b)
    k34b=(-1)*y2b-((x2b)**2)+((y2b)**2)
    x3b=xb[i-1]+h*k31b
    y3b=yb[i-1]+h*k32b
    px3b=pxb[i-1]+h*k33b
    py3b=pyb[i-1]+h*k34b
    k41b=px3b
    k42b=py3b
    k43b=(-1)*x3b-2*(x3b)*(y3b)
    k44b=(-1)*y3b-((x3b)**2)+((y3b)**2)
    k1b=(1/6)*(k11b+2*k21b+2*k31b+k41b)
    k2b=(1/6)*(k12b+2*k22b+2*k32b+k42b)
    k3b=(1/6)*(k13b+2*k23b+2*k33b+k43b)
    k4b=(1/6)*(k14b+2*k24b+2*k34b+k44b)
    xb[i]=xb[i-1]+k1b*h
    yb[i]=yb[i-1]+k2b*h 
    pxb[i]=pxb[i-1]+k3b*h
    pyb[i]=pyb[i-1]+k4b*h
    
    
    if xb[i]*xb[i-1]<0 and pxb[i]>0 and pxb[i-1]>0:
            dt=-xb[i-1]/k1b
            Yb[i]=(yb[i-1]+k2b*dt)
            PYb[i]=(pyb[i-1]+k4b*dt)
            xb[i]=0
            i=i+1
    else:
            Yb[i]=0
            PYb[i]=0
            i=i+1
else :           
    plt.scatter(Yb,PYb,s=0.1,c='r')
    
i=0
xb[i]=0
yb[i]=0
pyb[i]=-0.23
pxb[i]=(2*E-(pyb[i]**2)-(xb[i]**2)-(yb[i]**2)-2*(xb[i]**2)*yb[i]+(2*(yb[i]**3)/3))**(1/2)
i=i+1
print(pxb[0])

        
while i<=n:
    
    k11b=pxb[i-1]
    k12b=pyb[i-1]
    k13b=(-1)*xb[i-1]-2*xb[i-1]*yb[i-1]
    k14b=(-1)*yb[i-1]-(xb[i-1]**2)+(yb[i-1]**2)
    x1b=xb[i-1]+(h/2)*k11b
    y1b=yb[i-1]+(h/2)*k12b
    px1b=pxb[i-1]+(h/2)*k13b
    py1b=pyb[i-1]+(h/2)*k14b
    k21b=px1b
    k22b=py1b
    k23b=(-1)*x1b-2*(x1b)*(y1b)
    k24b=(-1)*y1b-((x1b)**2)+((y1b)**2)
    x2b=xb[i-1]+(h/2)*k21b
    y2b=yb[i-1]+(h/2)*k22b
    px2b=pxb[i-1]+(h/2)*k23b
    py2b=pyb[i-1]+(h/2)*k24b
    k31b=px2b
    k32b=py2b
    k33b=(-1)*x2b-2*(x2b)*(y2b)
    k34b=(-1)*y2b-((x2b)**2)+((y2b)**2)
    x3b=xb[i-1]+h*k31b
    y3b=yb[i-1]+h*k32b
    px3b=pxb[i-1]+h*k33b
    py3b=pyb[i-1]+h*k34b
    k41b=px3b
    k42b=py3b
    k43b=(-1)*x3b-2*(x3b)*(y3b)
    k44b=(-1)*y3b-((x3b)**2)+((y3b)**2)
    k1b=(1/6)*(k11b+2*k21b+2*k31b+k41b)
    k2b=(1/6)*(k12b+2*k22b+2*k32b+k42b)
    k3b=(1/6)*(k13b+2*k23b+2*k33b+k43b)
    k4b=(1/6)*(k14b+2*k24b+2*k34b+k44b)
    xb[i]=xb[i-1]+k1b*h
    yb[i]=yb[i-1]+k2b*h 
    pxb[i]=pxb[i-1]+k3b*h
    pyb[i]=pyb[i-1]+k4b*h
    
    
    if xb[i]*xb[i-1]<0 and pxb[i]>0 and pxb[i-1]>0:
            dt=-xb[i-1]/k1b
            Yb[i]=(yb[i-1]+k2b*dt)
            PYb[i]=(pyb[i-1]+k4b*dt)
            xb[i]=0
            i=i+1
    else:
            Yb[i]=0
            PYb[i]=0
            i=i+1
else :           
    plt.scatter(Yb,PYb,s=0.1,c='g')
    
i=0
xb[i]=0
yb[i]=0
pyb[i]=0.2
pxb[i]=(2*E-(pyb[i]**2)-(xb[i]**2)-(yb[i]**2)-2*(xb[i]**2)*yb[i]+(2*(yb[i]**3)/3))**(1/2)
i=i+1
print(pxb[0])

        
while i<=n:
    
    k11b=pxb[i-1]
    k12b=pyb[i-1]
    k13b=(-1)*xb[i-1]-2*xb[i-1]*yb[i-1]
    k14b=(-1)*yb[i-1]-(xb[i-1]**2)+(yb[i-1]**2)
    x1b=xb[i-1]+(h/2)*k11b
    y1b=yb[i-1]+(h/2)*k12b
    px1b=pxb[i-1]+(h/2)*k13b
    py1b=pyb[i-1]+(h/2)*k14b
    k21b=px1b
    k22b=py1b
    k23b=(-1)*x1b-2*(x1b)*(y1b)
    k24b=(-1)*y1b-((x1b)**2)+((y1b)**2)
    x2b=xb[i-1]+(h/2)*k21b
    y2b=yb[i-1]+(h/2)*k22b
    px2b=pxb[i-1]+(h/2)*k23b
    py2b=pyb[i-1]+(h/2)*k24b
    k31b=px2b
    k32b=py2b
    k33b=(-1)*x2b-2*(x2b)*(y2b)
    k34b=(-1)*y2b-((x2b)**2)+((y2b)**2)
    x3b=xb[i-1]+h*k31b
    y3b=yb[i-1]+h*k32b
    px3b=pxb[i-1]+h*k33b
    py3b=pyb[i-1]+h*k34b
    k41b=px3b
    k42b=py3b
    k43b=(-1)*x3b-2*(x3b)*(y3b)
    k44b=(-1)*y3b-((x3b)**2)+((y3b)**2)
    k1b=(1/6)*(k11b+2*k21b+2*k31b+k41b)
    k2b=(1/6)*(k12b+2*k22b+2*k32b+k42b)
    k3b=(1/6)*(k13b+2*k23b+2*k33b+k43b)
    k4b=(1/6)*(k14b+2*k24b+2*k34b+k44b)
    xb[i]=xb[i-1]+k1b*h
    yb[i]=yb[i-1]+k2b*h 
    pxb[i]=pxb[i-1]+k3b*h
    pyb[i]=pyb[i-1]+k4b*h
    
    
    if xb[i]*xb[i-1]<0 and pxb[i]>0 and pxb[i-1]>0:
            dt=-xb[i-1]/k1b
            Yb[i]=(yb[i-1]+k2b*dt)
            PYb[i]=(pyb[i-1]+k4b*dt)
            xb[i]=0
            i=i+1
    else:
            Yb[i]=0
            PYb[i]=0
            i=i+1
else :           
    plt.scatter(Yb,PYb,s=0.1,c='g')
    
i=0
xb[i]=0
yb[i]=0
pyb[i]=-0.2
pxb[i]=(2*E-(pyb[i]**2)-(xb[i]**2)-(yb[i]**2)-2*(xb[i]**2)*yb[i]+(2*(yb[i]**3)/3))**(1/2)
i=i+1
print(pxb[0])

        
while i<=n:
    
    k11b=pxb[i-1]
    k12b=pyb[i-1]
    k13b=(-1)*xb[i-1]-2*xb[i-1]*yb[i-1]
    k14b=(-1)*yb[i-1]-(xb[i-1]**2)+(yb[i-1]**2)
    x1b=xb[i-1]+(h/2)*k11b
    y1b=yb[i-1]+(h/2)*k12b
    px1b=pxb[i-1]+(h/2)*k13b
    py1b=pyb[i-1]+(h/2)*k14b
    k21b=px1b
    k22b=py1b
    k23b=(-1)*x1b-2*(x1b)*(y1b)
    k24b=(-1)*y1b-((x1b)**2)+((y1b)**2)
    x2b=xb[i-1]+(h/2)*k21b
    y2b=yb[i-1]+(h/2)*k22b
    px2b=pxb[i-1]+(h/2)*k23b
    py2b=pyb[i-1]+(h/2)*k24b
    k31b=px2b
    k32b=py2b
    k33b=(-1)*x2b-2*(x2b)*(y2b)
    k34b=(-1)*y2b-((x2b)**2)+((y2b)**2)
    x3b=xb[i-1]+h*k31b
    y3b=yb[i-1]+h*k32b
    px3b=pxb[i-1]+h*k33b
    py3b=pyb[i-1]+h*k34b
    k41b=px3b
    k42b=py3b
    k43b=(-1)*x3b-2*(x3b)*(y3b)
    k44b=(-1)*y3b-((x3b)**2)+((y3b)**2)
    k1b=(1/6)*(k11b+2*k21b+2*k31b+k41b)
    k2b=(1/6)*(k12b+2*k22b+2*k32b+k42b)
    k3b=(1/6)*(k13b+2*k23b+2*k33b+k43b)
    k4b=(1/6)*(k14b+2*k24b+2*k34b+k44b)
    xb[i]=xb[i-1]+k1b*h
    yb[i]=yb[i-1]+k2b*h 
    pxb[i]=pxb[i-1]+k3b*h
    pyb[i]=pyb[i-1]+k4b*h
    
    
    if xb[i]*xb[i-1]<0 and pxb[i]>0 and pxb[i-1]>0:
            dt=-xb[i-1]/k1b
            Yb[i]=(yb[i-1]+k2b*dt)
            PYb[i]=(pyb[i-1]+k4b*dt)
            xb[i]=0
            i=i+1
    else:
            Yb[i]=0
            PYb[i]=0
            i=i+1
else :           
    plt.scatter(Yb,PYb,s=0.1,c='g')
    
i=0
xb[i]=0
yb[i]=0
pyb[i]=0.23
pxb[i]=(2*E-(pyb[i]**2)-(xb[i]**2)-(yb[i]**2)-2*(xb[i]**2)*yb[i]+(2*(yb[i]**3)/3))**(1/2)
i=i+1
print(pxb[0])

        
while i<=n:
    
    k11b=pxb[i-1]
    k12b=pyb[i-1]
    k13b=(-1)*xb[i-1]-2*xb[i-1]*yb[i-1]
    k14b=(-1)*yb[i-1]-(xb[i-1]**2)+(yb[i-1]**2)
    x1b=xb[i-1]+(h/2)*k11b
    y1b=yb[i-1]+(h/2)*k12b
    px1b=pxb[i-1]+(h/2)*k13b
    py1b=pyb[i-1]+(h/2)*k14b
    k21b=px1b
    k22b=py1b
    k23b=(-1)*x1b-2*(x1b)*(y1b)
    k24b=(-1)*y1b-((x1b)**2)+((y1b)**2)
    x2b=xb[i-1]+(h/2)*k21b
    y2b=yb[i-1]+(h/2)*k22b
    px2b=pxb[i-1]+(h/2)*k23b
    py2b=pyb[i-1]+(h/2)*k24b
    k31b=px2b
    k32b=py2b
    k33b=(-1)*x2b-2*(x2b)*(y2b)
    k34b=(-1)*y2b-((x2b)**2)+((y2b)**2)
    x3b=xb[i-1]+h*k31b
    y3b=yb[i-1]+h*k32b
    px3b=pxb[i-1]+h*k33b
    py3b=pyb[i-1]+h*k34b
    k41b=px3b
    k42b=py3b
    k43b=(-1)*x3b-2*(x3b)*(y3b)
    k44b=(-1)*y3b-((x3b)**2)+((y3b)**2)
    k1b=(1/6)*(k11b+2*k21b+2*k31b+k41b)
    k2b=(1/6)*(k12b+2*k22b+2*k32b+k42b)
    k3b=(1/6)*(k13b+2*k23b+2*k33b+k43b)
    k4b=(1/6)*(k14b+2*k24b+2*k34b+k44b)
    xb[i]=xb[i-1]+k1b*h
    yb[i]=yb[i-1]+k2b*h 
    pxb[i]=pxb[i-1]+k3b*h
    pyb[i]=pyb[i-1]+k4b*h
    
    
    if xb[i]*xb[i-1]<0 and pxb[i]>0 and pxb[i-1]>0:
            dt=-xb[i-1]/k1b
            Yb[i]=(yb[i-1]+k2b*dt)
            PYb[i]=(pyb[i-1]+k4b*dt)
            xb[i]=0
            i=i+1
    else:
            Yb[i]=0
            PYb[i]=0
            i=i+1
else :           
    plt.scatter(Yb,PYb,s=0.1,c='g')
i=0
xb[i]=0
yb[i]=0.08
pyb[i]=0.2
pxb[i]=(2*E-(pyb[i]**2)-(xb[i]**2)-(yb[i]**2)-2*(xb[i]**2)*yb[i]+(2*(yb[i]**3)/3))**(1/2)
i=i+1
print(pxb[0])

        
while i<=n:
    
    k11b=pxb[i-1]
    k12b=pyb[i-1]
    k13b=(-1)*xb[i-1]-2*xb[i-1]*yb[i-1]
    k14b=(-1)*yb[i-1]-(xb[i-1]**2)+(yb[i-1]**2)
    x1b=xb[i-1]+(h/2)*k11b
    y1b=yb[i-1]+(h/2)*k12b
    px1b=pxb[i-1]+(h/2)*k13b
    py1b=pyb[i-1]+(h/2)*k14b
    k21b=px1b
    k22b=py1b
    k23b=(-1)*x1b-2*(x1b)*(y1b)
    k24b=(-1)*y1b-((x1b)**2)+((y1b)**2)
    x2b=xb[i-1]+(h/2)*k21b
    y2b=yb[i-1]+(h/2)*k22b
    px2b=pxb[i-1]+(h/2)*k23b
    py2b=pyb[i-1]+(h/2)*k24b
    k31b=px2b
    k32b=py2b
    k33b=(-1)*x2b-2*(x2b)*(y2b)
    k34b=(-1)*y2b-((x2b)**2)+((y2b)**2)
    x3b=xb[i-1]+h*k31b
    y3b=yb[i-1]+h*k32b
    px3b=pxb[i-1]+h*k33b
    py3b=pyb[i-1]+h*k34b
    k41b=px3b
    k42b=py3b
    k43b=(-1)*x3b-2*(x3b)*(y3b)
    k44b=(-1)*y3b-((x3b)**2)+((y3b)**2)
    k1b=(1/6)*(k11b+2*k21b+2*k31b+k41b)
    k2b=(1/6)*(k12b+2*k22b+2*k32b+k42b)
    k3b=(1/6)*(k13b+2*k23b+2*k33b+k43b)
    k4b=(1/6)*(k14b+2*k24b+2*k34b+k44b)
    xb[i]=xb[i-1]+k1b*h
    yb[i]=yb[i-1]+k2b*h 
    pxb[i]=pxb[i-1]+k3b*h
    pyb[i]=pyb[i-1]+k4b*h
    
    
    if xb[i]*xb[i-1]<0 and pxb[i]>0 and pxb[i-1]>0:
            dt=-xb[i-1]/k1b
            Yb[i]=(yb[i-1]+k2b*dt)
            PYb[i]=(pyb[i-1]+k4b*dt)
            xb[i]=0
            i=i+1
    else:
            Yb[i]=0
            PYb[i]=0
            i=i+1
else :           
    plt.scatter(Yb,PYb,s=0.1,c='g')
    
i=0
xb[i]=0
yb[i]=0.08
pyb[i]=-0.2
pxb[i]=(2*E-(pyb[i]**2)-(xb[i]**2)-(yb[i]**2)-2*(xb[i]**2)*yb[i]+(2*(yb[i]**3)/3))**(1/2)
i=i+1
print(pxb[0])

        
while i<=n:
    
    k11b=pxb[i-1]
    k12b=pyb[i-1]
    k13b=(-1)*xb[i-1]-2*xb[i-1]*yb[i-1]
    k14b=(-1)*yb[i-1]-(xb[i-1]**2)+(yb[i-1]**2)
    x1b=xb[i-1]+(h/2)*k11b
    y1b=yb[i-1]+(h/2)*k12b
    px1b=pxb[i-1]+(h/2)*k13b
    py1b=pyb[i-1]+(h/2)*k14b
    k21b=px1b
    k22b=py1b
    k23b=(-1)*x1b-2*(x1b)*(y1b)
    k24b=(-1)*y1b-((x1b)**2)+((y1b)**2)
    x2b=xb[i-1]+(h/2)*k21b
    y2b=yb[i-1]+(h/2)*k22b
    px2b=pxb[i-1]+(h/2)*k23b
    py2b=pyb[i-1]+(h/2)*k24b
    k31b=px2b
    k32b=py2b
    k33b=(-1)*x2b-2*(x2b)*(y2b)
    k34b=(-1)*y2b-((x2b)**2)+((y2b)**2)
    x3b=xb[i-1]+h*k31b
    y3b=yb[i-1]+h*k32b
    px3b=pxb[i-1]+h*k33b
    py3b=pyb[i-1]+h*k34b
    k41b=px3b
    k42b=py3b
    k43b=(-1)*x3b-2*(x3b)*(y3b)
    k44b=(-1)*y3b-((x3b)**2)+((y3b)**2)
    k1b=(1/6)*(k11b+2*k21b+2*k31b+k41b)
    k2b=(1/6)*(k12b+2*k22b+2*k32b+k42b)
    k3b=(1/6)*(k13b+2*k23b+2*k33b+k43b)
    k4b=(1/6)*(k14b+2*k24b+2*k34b+k44b)
    xb[i]=xb[i-1]+k1b*h
    yb[i]=yb[i-1]+k2b*h 
    pxb[i]=pxb[i-1]+k3b*h
    pyb[i]=pyb[i-1]+k4b*h
    
    
    if xb[i]*xb[i-1]<0 and pxb[i]>0 and pxb[i-1]>0:
            dt=-xb[i-1]/k1b
            Yb[i]=(yb[i-1]+k2b*dt)
            PYb[i]=(pyb[i-1]+k4b*dt)
            xb[i]=0
            i=i+1
    else:
            Yb[i]=0
            PYb[i]=0
            i=i+1
else :           
    plt.scatter(Yb,PYb,s=0.1,c='g')
i=0
xb[i]=0
yb[i]=-0.35
pyb[i]=0
pxb[i]=(2*E-(pyb[i]**2)-(xb[i]**2)-(yb[i]**2)-2*(xb[i]**2)*yb[i]+(2*(yb[i]**3)/3))**(1/2)
i=i+1
print(pxb[0])

        
while i<=n:
    
    k11b=pxb[i-1]
    k12b=pyb[i-1]
    k13b=(-1)*xb[i-1]-2*xb[i-1]*yb[i-1]
    k14b=(-1)*yb[i-1]-(xb[i-1]**2)+(yb[i-1]**2)
    x1b=xb[i-1]+(h/2)*k11b
    y1b=yb[i-1]+(h/2)*k12b
    px1b=pxb[i-1]+(h/2)*k13b
    py1b=pyb[i-1]+(h/2)*k14b
    k21b=px1b
    k22b=py1b
    k23b=(-1)*x1b-2*(x1b)*(y1b)
    k24b=(-1)*y1b-((x1b)**2)+((y1b)**2)
    x2b=xb[i-1]+(h/2)*k21b
    y2b=yb[i-1]+(h/2)*k22b
    px2b=pxb[i-1]+(h/2)*k23b
    py2b=pyb[i-1]+(h/2)*k24b
    k31b=px2b
    k32b=py2b
    k33b=(-1)*x2b-2*(x2b)*(y2b)
    k34b=(-1)*y2b-((x2b)**2)+((y2b)**2)
    x3b=xb[i-1]+h*k31b
    y3b=yb[i-1]+h*k32b
    px3b=pxb[i-1]+h*k33b
    py3b=pyb[i-1]+h*k34b
    k41b=px3b
    k42b=py3b
    k43b=(-1)*x3b-2*(x3b)*(y3b)
    k44b=(-1)*y3b-((x3b)**2)+((y3b)**2)
    k1b=(1/6)*(k11b+2*k21b+2*k31b+k41b)
    k2b=(1/6)*(k12b+2*k22b+2*k32b+k42b)
    k3b=(1/6)*(k13b+2*k23b+2*k33b+k43b)
    k4b=(1/6)*(k14b+2*k24b+2*k34b+k44b)
    xb[i]=xb[i-1]+k1b*h
    yb[i]=yb[i-1]+k2b*h 
    pxb[i]=pxb[i-1]+k3b*h
    pyb[i]=pyb[i-1]+k4b*h
    
    
    if xb[i]*xb[i-1]<0 and pxb[i]>0 and pxb[i-1]>0:
            dt=-xb[i-1]/k1b
            Yb[i]=(yb[i-1]+k2b*dt)
            PYb[i]=(pyb[i-1]+k4b*dt)
            xb[i]=0
            i=i+1
    else:
            Yb[i]=0
            PYb[i]=0
            i=i+1
else :           
    plt.scatter(Yb,PYb,s=0.1,c='b')
    
i=0
xb[i]=0
yb[i]=-0.15
pyb[i]=-0.15
pxb[i]=(2*E-(pyb[i]**2)-(xb[i]**2)-(yb[i]**2)-2*(xb[i]**2)*yb[i]+(2*(yb[i]**3)/3))**(1/2)
i=i+1
print(pxb[0])

        
while i<=n:
    
    k11b=pxb[i-1]
    k12b=pyb[i-1]
    k13b=(-1)*xb[i-1]-2*xb[i-1]*yb[i-1]
    k14b=(-1)*yb[i-1]-(xb[i-1]**2)+(yb[i-1]**2)
    x1b=xb[i-1]+(h/2)*k11b
    y1b=yb[i-1]+(h/2)*k12b
    px1b=pxb[i-1]+(h/2)*k13b
    py1b=pyb[i-1]+(h/2)*k14b
    k21b=px1b
    k22b=py1b
    k23b=(-1)*x1b-2*(x1b)*(y1b)
    k24b=(-1)*y1b-((x1b)**2)+((y1b)**2)
    x2b=xb[i-1]+(h/2)*k21b
    y2b=yb[i-1]+(h/2)*k22b
    px2b=pxb[i-1]+(h/2)*k23b
    py2b=pyb[i-1]+(h/2)*k24b
    k31b=px2b
    k32b=py2b
    k33b=(-1)*x2b-2*(x2b)*(y2b)
    k34b=(-1)*y2b-((x2b)**2)+((y2b)**2)
    x3b=xb[i-1]+h*k31b
    y3b=yb[i-1]+h*k32b
    px3b=pxb[i-1]+h*k33b
    py3b=pyb[i-1]+h*k34b
    k41b=px3b
    k42b=py3b
    k43b=(-1)*x3b-2*(x3b)*(y3b)
    k44b=(-1)*y3b-((x3b)**2)+((y3b)**2)
    k1b=(1/6)*(k11b+2*k21b+2*k31b+k41b)
    k2b=(1/6)*(k12b+2*k22b+2*k32b+k42b)
    k3b=(1/6)*(k13b+2*k23b+2*k33b+k43b)
    k4b=(1/6)*(k14b+2*k24b+2*k34b+k44b)
    xb[i]=xb[i-1]+k1b*h
    yb[i]=yb[i-1]+k2b*h 
    pxb[i]=pxb[i-1]+k3b*h
    pyb[i]=pyb[i-1]+k4b*h
    
    
    if xb[i]*xb[i-1]<0 and pxb[i]>0 and pxb[i-1]>0:
            dt=-xb[i-1]/k1b
            Yb[i]=(yb[i-1]+k2b*dt)
            PYb[i]=(pyb[i-1]+k4b*dt)
            xb[i]=0
            i=i+1
    else:
            Yb[i]=0
            PYb[i]=0
            i=i+1
else :           
    plt.scatter(Yb,PYb,s=0.1,c='orange')

plt.show()
# Out:
# 0.5
# 0.4939041742416573
# 0.47658227691204236
# 0.4490167034754943
# 0.4208127057650866
# 0.40063751280511245
# 0.37682887362833545
# 0.3485535587730145
# 0.2724311839712921
# 0.21756225162774284
# 0.48949497784281026
# 0.4439594576084623
# 0.458257569495584
# 0.458257569495584
# 0.4439594576084623
# 0.45159864186391585
# 0.45159864186391585
# 0.31451020121240375
# 0.4502776920967771

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy import optimize, special
from numpy import *
from pylab import *
import decimal


E=1/8
plt.style.use("seaborn-whitegrid")
n=5000000
h=5500/n
dt=0
xo=np.zeros(n+1,dtype='float64')
yo=np.zeros(n+1,dtype='float64')
pxo=np.zeros(n+1,dtype='float64')
pyo=np.zeros(n+1,dtype='float64')
Yo=np.zeros(n+1,dtype='float64')
PYo=np.zeros(n+1,dtype='float64')
xl=np.zeros(n+1,dtype='float64')
yl=np.zeros(n+1,dtype='float64')
pxl=np.zeros(n+1,dtype='float64')
pyl=np.zeros(n+1,dtype='float64')
Yl=np.zeros(n+1,dtype='float64')
PYl=np.zeros(n+1,dtype='float64')
xu=np.zeros(n+1,dtype='float64')
yu=np.zeros(n+1,dtype='float64')
pxu=np.zeros(n+1,dtype='float64')
pyu=np.zeros(n+1,dtype='float64')
Yu=np.zeros(n+1,dtype='float64')
PYu=np.zeros(n+1,dtype='float64')
xd=np.zeros(n+1,dtype='float64')
yd=np.zeros(n+1,dtype='float64')
pxd=np.zeros(n+1,dtype='float64')
pyd=np.zeros(n+1,dtype='float64')
Yd=np.zeros(n+1,dtype='float64')
PYd=np.zeros(n+1,dtype='float64')
xb=np.zeros(n+1,dtype='float64')
yb=np.zeros(n+1,dtype='float64')
pxb=np.zeros(n+1,dtype='float64')
pyb=np.zeros(n+1,dtype='float64')
Yb=np.zeros(n+1,dtype='float64')
PYb=np.zeros(n+1,dtype='float64')
i=0
xo[i]=0
yo[i]=0
pyo[i]=0
pxo[i]=(2*E-(pyo[i]**2)-(xo[i]**2)-(yo[i]**2)-2*(xo[i]**2)*yo[i]+(2*(yo[i]**3)/3))**(1/2)
i=i+1
print(pxo[0])

        
while i<=n:
    
    k11o=pxo[i-1]
    k12o=pyo[i-1]
    k13o=(-1)*xo[i-1]-2*xo[i-1]*yo[i-1]
    k14o=(-1)*yo[i-1]-(xo[i-1]**2)+(yo[i-1]**2)
    x1o=xo[i-1]+(h/2)*k11o
    y1o=yo[i-1]+(h/2)*k12o
    px1o=pxo[i-1]+(h/2)*k13o
    py1o=pyo[i-1]+(h/2)*k14o
    k21o=px1o
    k22o=py1o
    k23o=(-1)*x1o-2*(x1o)*(y1o)
    k24o=(-1)*y1o-((x1o)**2)+((y1o)**2)
    x2o=xo[i-1]+(h/2)*k21o
    y2o=yo[i-1]+(h/2)*k22o
    px2o=pxo[i-1]+(h/2)*k23o
    py2o=pyo[i-1]+(h/2)*k24o
    k31o=px2o
    k32o=py2o
    k33o=(-1)*x2o-2*(x2o)*(y2o)
    k34o=(-1)*y2o-((x2o)**2)+((y2o)**2)
    x3o=xo[i-1]+h*k31o
    y3o=yo[i-1]+h*k32o
    px3o=pxo[i-1]+h*k33o
    py3o=pyo[i-1]+h*k34o
    k41o=px3o
    k42o=py3o
    k43o=(-1)*x3o-2*(x3o)*(y3o)
    k44o=(-1)*y3o-((x3o)**2)+((y3o)**2)
    k1o=(1/6)*(k11o+2*k21o+2*k31o+k41o)
    k2o=(1/6)*(k12o+2*k22o+2*k32o+k42o)
    k3o=(1/6)*(k13o+2*k23o+2*k33o+k43o)
    k4o=(1/6)*(k14o+2*k24o+2*k34o+k44o)
    xo[i]=xo[i-1]+k1o*h
    yo[i]=yo[i-1]+k2o*h 
    pxo[i]=pxo[i-1]+k3o*h
    pyo[i]=pyo[i-1]+k4o*h
    
    if xo[i]*xo[i-1]<0 and pxo[i]>0 and pxo[i-1]>0:
            dt=-xo[i-1]/k1o
            xo[i]=0
            Yo[i]=(yo[i-1]+k2o*dt)
            PYo[i]=(pyo[i-1]+k4o*dt)
            i=i+1
    else:
            Yo[i]=0
            PYo[i]=0
            i=i+1
else :           
    plt.scatter(Yo,PYo,s=0.1,c='r')
    
i=0
xl[i]=0
yl[i]=0.08
pyl[i]=0
pxl[i]=(2*E-(pyl[i]**2)-(xl[i]**2)-(yl[i]**2)-2*(xl[i]**2)*yl[i]+(2*(yl[i]**3)/3))**(1/2)
i=i+1
print(pxl[0])

        
while i<=n:
    
    k11l=pxl[i-1]
    k12l=pyl[i-1]
    k13l=(-1)*xl[i-1]-2*xl[i-1]*yl[i-1]
    k14l=(-1)*yl[i-1]-(xl[i-1]**2)+(yl[i-1]**2)
    x1l=xl[i-1]+(h/2)*k11l
    y1l=yl[i-1]+(h/2)*k12l
    px1l=pxl[i-1]+(h/2)*k13l
    py1l=pyl[i-1]+(h/2)*k14l
    k21l=px1l
    k22l=py1l
    k23l=(-1)*x1l-2*(x1l)*(y1l)
    k24l=(-1)*y1l-((x1l)**2)+((y1l)**2)
    x2l=xl[i-1]+(h/2)*k21l
    y2l=yl[i-1]+(h/2)*k22l
    px2l=pxl[i-1]+(h/2)*k23l
    py2l=pyl[i-1]+(h/2)*k24l
    k31l=px2l
    k32l=py2l
    k33l=(-1)*x2l-2*(x2l)*(y2l)
    k34l=(-1)*y2l-((x2l)**2)+((y2l)**2)
    x3l=xl[i-1]+h*k31l
    y3l=yl[i-1]+h*k32l
    px3l=pxl[i-1]+h*k33l
    py3l=pyl[i-1]+h*k34l
    k41l=px3l
    k42l=py3l
    k43l=(-1)*x3l-2*(x3l)*(y3l)
    k44l=(-1)*y3l-((x3l)**2)+((y3l)**2)
    k1l=(1/6)*(k11l+2*k21l+2*k31l+k41l)
    k2l=(1/6)*(k12l+2*k22l+2*k32l+k42l)
    k3l=(1/6)*(k13l+2*k23l+2*k33l+k43l)
    k4l=(1/6)*(k14l+2*k24l+2*k34l+k44l)
    xl[i]=xl[i-1]+k1l*h
    yl[i]=yl[i-1]+k2l*h 
    pxl[i]=pxl[i-1]+k3l*h
    pyl[i]=pyl[i-1]+k4l*h
    
    
    if xl[i]*xl[i-1]<0 and pxl[i]>0 and pxl[i-1]>0:
            dt=-xl[i-1]/k1l
            Yl[i]=(yl[i-1]+k2l*dt)
            PYl[i]=(pyl[i-1]+k4l*dt)
            xl[i]=0
            i=i+1
    else:
            Yl[i]=0
            PYl[i]=0
            i=i+1
else :           
    plt.scatter(Yl,PYl,s=0.1,c='r')

i=0
xu[i]=0
yu[i]=0.16
pyu[i]=0
pxu[i]=(2*E-(pyu[i]**2)-(xu[i]**2)-(yu[i]**2)-2*(xu[i]**2)*yu[i]+(2*(yu[i]**3)/3))**(1/2)
i=i+1
print(pxu[0])

        
while i<=n:
   
    k11u=pxu[i-1]
    k12u=pyu[i-1]
    k13u=(-1)*xu[i-1]-2*xu[i-1]*yu[i-1]
    k14u=(-1)*yu[i-1]-(xu[i-1]**2)+(yu[i-1]**2)
    x1u=xu[i-1]+(h/2)*k11u
    y1u=yu[i-1]+(h/2)*k12u
    px1u=pxu[i-1]+(h/2)*k13u
    py1u=pyu[i-1]+(h/2)*k14u
    k21u=px1u
    k22u=py1u
    k23u=(-1)*x1u-2*(x1u)*(y1u)
    k24u=(-1)*y1u-((x1u)**2)+((y1u)**2)
    x2u=xu[i-1]+(h/2)*k21u
    y2u=yu[i-1]+(h/2)*k22u
    px2u=pxu[i-1]+(h/2)*k23u
    py2u=pyu[i-1]+(h/2)*k24u
    k31u=px2u
    k32u=py2u
    k33u=(-1)*x2u-2*(x2u)*(y2u)
    k34u=(-1)*y2u-((x2u)**2)+((y2u)**2)
    x3u=xu[i-1]+h*k31u
    y3u=yu[i-1]+h*k32u
    px3u=pxu[i-1]+h*k33u
    py3u=pyu[i-1]+h*k34u
    k41u=px3u
    k42u=py3u
    k43u=(-1)*x3u-2*(x3u)*(y3u)
    k44u=(-1)*y3u-((x3u)**2)+((y3u)**2)
    k1u=(1/6)*(k11u+2*k21u+2*k31u+k41u)
    k2u=(1/6)*(k12u+2*k22u+2*k32u+k42u)
    k3u=(1/6)*(k13u+2*k23u+2*k33u+k43u)
    k4u=(1/6)*(k14u+2*k24u+2*k34u+k44u)
    xu[i]=xu[i-1]+k1u*h
    yu[i]=yu[i-1]+k2u*h 
    pxu[i]=pxu[i-1]+k3u*h
    pyu[i]=pyu[i-1]+k4u*h
    
    
    if xu[i]*xu[i-1]<0 and pxu[i]>0 and pxu[i-1]>0:
            dt=-xu[i-1]/k1u
            Yu[i]=(yu[i-1]+k2u*dt)
            PYu[i]=(pyu[i-1]+k4u*dt)
            xu[i]=0
            i=i+1
    else:
            Yu[i]=0
            PYu[i]=0
            i=i+1
else :           
    plt.scatter(Yu,PYu,s=0.1,c='r')
    
i=0
xu[i]=0
yu[i]=0.24
pyu[i]=0
pxu[i]=(2*E-(pyu[i]**2)-(xu[i]**2)-(yu[i]**2)-2*(xu[i]**2)*yu[i]+(2*(yu[i]**3)/3))**(1/2)
i=i+1
print(pxu[0])

        
while i<=n:
   
    k11u=pxu[i-1]
    k12u=pyu[i-1]
    k13u=(-1)*xu[i-1]-2*xu[i-1]*yu[i-1]
    k14u=(-1)*yu[i-1]-(xu[i-1]**2)+(yu[i-1]**2)
    x1u=xu[i-1]+(h/2)*k11u
    y1u=yu[i-1]+(h/2)*k12u
    px1u=pxu[i-1]+(h/2)*k13u
    py1u=pyu[i-1]+(h/2)*k14u
    k21u=px1u
    k22u=py1u
    k23u=(-1)*x1u-2*(x1u)*(y1u)
    k24u=(-1)*y1u-((x1u)**2)+((y1u)**2)
    x2u=xu[i-1]+(h/2)*k21u
    y2u=yu[i-1]+(h/2)*k22u
    px2u=pxu[i-1]+(h/2)*k23u
    py2u=pyu[i-1]+(h/2)*k24u
    k31u=px2u
    k32u=py2u
    k33u=(-1)*x2u-2*(x2u)*(y2u)
    k34u=(-1)*y2u-((x2u)**2)+((y2u)**2)
    x3u=xu[i-1]+h*k31u
    y3u=yu[i-1]+h*k32u
    px3u=pxu[i-1]+h*k33u
    py3u=pyu[i-1]+h*k34u
    k41u=px3u
    k42u=py3u
    k43u=(-1)*x3u-2*(x3u)*(y3u)
    k44u=(-1)*y3u-((x3u)**2)+((y3u)**2)
    k1u=(1/6)*(k11u+2*k21u+2*k31u+k41u)
    k2u=(1/6)*(k12u+2*k22u+2*k32u+k42u)
    k3u=(1/6)*(k13u+2*k23u+2*k33u+k43u)
    k4u=(1/6)*(k14u+2*k24u+2*k34u+k44u)
    xu[i]=xu[i-1]+k1u*h
    yu[i]=yu[i-1]+k2u*h 
    pxu[i]=pxu[i-1]+k3u*h
    pyu[i]=pyu[i-1]+k4u*h
    
    
    if xu[i]*xu[i-1]<0 and pxu[i]>0 and pxu[i-1]>0:
            dt=-xu[i-1]/k1u
            Yu[i]=(yu[i-1]+k2u*dt)
            PYu[i]=(pyu[i-1]+k4u*dt)
            xu[i]=0
            i=i+1
    else:
            Yu[i]=0
            PYu[i]=0
            i=i+1
else :           
    plt.scatter(Yu,PYu,s=0.1,c='r')

i=0
xu[i]=0
yu[i]=-0.25
pyu[i]=0
pxu[i]=(2*E-(pyu[i]**2)-(xu[i]**2)-(yu[i]**2)-2*(xu[i]**2)*yu[i]+(2*(yu[i]**3)/3))**(1/2)
i=i+1
print(pxu[0])

        
while i<=n:
   
    k11u=pxu[i-1]
    k12u=pyu[i-1]
    k13u=(-1)*xu[i-1]-2*xu[i-1]*yu[i-1]
    k14u=(-1)*yu[i-1]-(xu[i-1]**2)+(yu[i-1]**2)
    x1u=xu[i-1]+(h/2)*k11u
    y1u=yu[i-1]+(h/2)*k12u
    px1u=pxu[i-1]+(h/2)*k13u
    py1u=pyu[i-1]+(h/2)*k14u
    k21u=px1u
    k22u=py1u
    k23u=(-1)*x1u-2*(x1u)*(y1u)
    k24u=(-1)*y1u-((x1u)**2)+((y1u)**2)
    x2u=xu[i-1]+(h/2)*k21u
    y2u=yu[i-1]+(h/2)*k22u
    px2u=pxu[i-1]+(h/2)*k23u
    py2u=pyu[i-1]+(h/2)*k24u
    k31u=px2u
    k32u=py2u
    k33u=(-1)*x2u-2*(x2u)*(y2u)
    k34u=(-1)*y2u-((x2u)**2)+((y2u)**2)
    x3u=xu[i-1]+h*k31u
    y3u=yu[i-1]+h*k32u
    px3u=pxu[i-1]+h*k33u
    py3u=pyu[i-1]+h*k34u
    k41u=px3u
    k42u=py3u
    k43u=(-1)*x3u-2*(x3u)*(y3u)
    k44u=(-1)*y3u-((x3u)**2)+((y3u)**2)
    k1u=(1/6)*(k11u+2*k21u+2*k31u+k41u)
    k2u=(1/6)*(k12u+2*k22u+2*k32u+k42u)
    k3u=(1/6)*(k13u+2*k23u+2*k33u+k43u)
    k4u=(1/6)*(k14u+2*k24u+2*k34u+k44u)
    xu[i]=xu[i-1]+k1u*h
    yu[i]=yu[i-1]+k2u*h 
    pxu[i]=pxu[i-1]+k3u*h
    pyu[i]=pyu[i-1]+k4u*h
    
    
    if xu[i]*xu[i-1]<0 and pxu[i]>0 and pxu[i-1]>0:
            dt=-xu[i-1]/k1u
            Yu[i]=(yu[i-1]+k2u*dt)
            PYu[i]=(pyu[i-1]+k4u*dt)
            xu[i]=0
            i=i+1
    else:
            Yu[i]=0
            PYu[i]=0
            i=i+1
else :           
    plt.scatter(Yu,PYu,s=0.1,c='b')
i=0
xu[i]=0
yu[i]=-0.275
pyu[i]=0
pxu[i]=(2*E-(pyu[i]**2)-(xu[i]**2)-(yu[i]**2)-2*(xu[i]**2)*yu[i]+(2*(yu[i]**3)/3))**(1/2)
i=i+1
print(pxu[0])

        
while i<=n:
   
    k11u=pxu[i-1]
    k12u=pyu[i-1]
    k13u=(-1)*xu[i-1]-2*xu[i-1]*yu[i-1]
    k14u=(-1)*yu[i-1]-(xu[i-1]**2)+(yu[i-1]**2)
    x1u=xu[i-1]+(h/2)*k11u
    y1u=yu[i-1]+(h/2)*k12u
    px1u=pxu[i-1]+(h/2)*k13u
    py1u=pyu[i-1]+(h/2)*k14u
    k21u=px1u
    k22u=py1u
    k23u=(-1)*x1u-2*(x1u)*(y1u)
    k24u=(-1)*y1u-((x1u)**2)+((y1u)**2)
    x2u=xu[i-1]+(h/2)*k21u
    y2u=yu[i-1]+(h/2)*k22u
    px2u=pxu[i-1]+(h/2)*k23u
    py2u=pyu[i-1]+(h/2)*k24u
    k31u=px2u
    k32u=py2u
    k33u=(-1)*x2u-2*(x2u)*(y2u)
    k34u=(-1)*y2u-((x2u)**2)+((y2u)**2)
    x3u=xu[i-1]+h*k31u
    y3u=yu[i-1]+h*k32u
    px3u=pxu[i-1]+h*k33u
    py3u=pyu[i-1]+h*k34u
    k41u=px3u
    k42u=py3u
    k43u=(-1)*x3u-2*(x3u)*(y3u)
    k44u=(-1)*y3u-((x3u)**2)+((y3u)**2)
    k1u=(1/6)*(k11u+2*k21u+2*k31u+k41u)
    k2u=(1/6)*(k12u+2*k22u+2*k32u+k42u)
    k3u=(1/6)*(k13u+2*k23u+2*k33u+k43u)
    k4u=(1/6)*(k14u+2*k24u+2*k34u+k44u)
    xu[i]=xu[i-1]+k1u*h
    yu[i]=yu[i-1]+k2u*h 
    pxu[i]=pxu[i-1]+k3u*h
    pyu[i]=pyu[i-1]+k4u*h
    
    
    if xu[i]*xu[i-1]<0 and pxu[i]>0 and pxu[i-1]>0:
            dt=-xu[i-1]/k1u
            Yu[i]=(yu[i-1]+k2u*dt)
            PYu[i]=(pyu[i-1]+k4u*dt)
            xu[i]=0
            i=i+1
    else:
            Yu[i]=0
            PYu[i]=0
            i=i+1
else :           
    plt.scatter(Yu,PYu,s=0.1,c='b')
i=0
xd[i]=0
yd[i]=-0.3
pyd[i]=0
pxd[i]=(2*E-(pyd[i]**2)-(xd[i]**2)-(yd[i]**2)-2*(xd[i]**2)*yd[i]+(2*(yd[i]**3)/3))**(1/2)
i=i+1
print(pxd[0])

        
while i<=n:
    
    k11d=pxd[i-1]
    k12d=pyd[i-1]
    k13d=(-1)*xd[i-1]-2*xd[i-1]*yd[i-1]
    k14d=(-1)*yd[i-1]-(xd[i-1]**2)+(yd[i-1]**2)
    x1d=xd[i-1]+(h/2)*k11d
    y1d=yd[i-1]+(h/2)*k12d
    px1d=pxd[i-1]+(h/2)*k13d
    py1d=pyd[i-1]+(h/2)*k14d
    k21d=px1d
    k22d=py1d
    k23d=(-1)*x1d-2*(x1d)*(y1d)
    k24d=(-1)*y1d-((x1d)**2)+((y1d)**2)
    x2d=xd[i-1]+(h/2)*k21d
    y2d=yd[i-1]+(h/2)*k22d
    px2d=pxd[i-1]+(h/2)*k23d
    py2d=pyd[i-1]+(h/2)*k24d
    k31d=px2d
    k32d=py2d
    k33d=(-1)*x2d-2*(x2d)*(y2d)
    k34d=(-1)*y2d-((x2d)**2)+((y2d)**2)
    x3d=xd[i-1]+h*k31d
    y3d=yd[i-1]+h*k32d
    px3d=pxd[i-1]+h*k33d
    py3d=pyd[i-1]+h*k34d
    k41d=px3d
    k42d=py3d
    k43d=(-1)*x3d-2*(x3d)*(y3d)
    k44d=(-1)*y3d-((x3d)**2)+((y3d)**2)
    k1d=(1/6)*(k11d+2*k21d+2*k31d+k41d)
    k2d=(1/6)*(k12d+2*k22d+2*k32d+k42d)
    k3d=(1/6)*(k13d+2*k23d+2*k33d+k43d)
    k4d=(1/6)*(k14d+2*k24d+2*k34d+k44d)
    xd[i]=xd[i-1]+k1d*h
    yd[i]=yd[i-1]+k2d*h 
    pxd[i]=pxd[i-1]+k3d*h
    pyd[i]=pyd[i-1]+k4d*h
    
    
    if xd[i]*xd[i-1]<0 and pxd[i]>0 and pxd[i-1]>0:
            dt=-xd[i-1]/k1d
            Yd[i]=(yd[i-1]+k2d*dt)
            PYd[i]=(pyd[i-1]+k4d*dt)
            xd[i]=0
            i=i+1
    else:
            Yd[i]=0
            PYd[i]=0
            i=i+1
else :           
    plt.scatter(Yd,PYd,s=0.1,c='b')
i=0
xd[i]=0
yd[i]=-0.325
pyd[i]=0
pxd[i]=(2*E-(pyd[i]**2)-(xd[i]**2)-(yd[i]**2)-2*(xd[i]**2)*yd[i]+(2*(yd[i]**3)/3))**(1/2)
i=i+1
print(pxd[0])

        
while i<=n:
    
    k11d=pxd[i-1]
    k12d=pyd[i-1]
    k13d=(-1)*xd[i-1]-2*xd[i-1]*yd[i-1]
    k14d=(-1)*yd[i-1]-(xd[i-1]**2)+(yd[i-1]**2)
    x1d=xd[i-1]+(h/2)*k11d
    y1d=yd[i-1]+(h/2)*k12d
    px1d=pxd[i-1]+(h/2)*k13d
    py1d=pyd[i-1]+(h/2)*k14d
    k21d=px1d
    k22d=py1d
    k23d=(-1)*x1d-2*(x1d)*(y1d)
    k24d=(-1)*y1d-((x1d)**2)+((y1d)**2)
    x2d=xd[i-1]+(h/2)*k21d
    y2d=yd[i-1]+(h/2)*k22d
    px2d=pxd[i-1]+(h/2)*k23d
    py2d=pyd[i-1]+(h/2)*k24d
    k31d=px2d
    k32d=py2d
    k33d=(-1)*x2d-2*(x2d)*(y2d)
    k34d=(-1)*y2d-((x2d)**2)+((y2d)**2)
    x3d=xd[i-1]+h*k31d
    y3d=yd[i-1]+h*k32d
    px3d=pxd[i-1]+h*k33d
    py3d=pyd[i-1]+h*k34d
    k41d=px3d
    k42d=py3d
    k43d=(-1)*x3d-2*(x3d)*(y3d)
    k44d=(-1)*y3d-((x3d)**2)+((y3d)**2)
    k1d=(1/6)*(k11d+2*k21d+2*k31d+k41d)
    k2d=(1/6)*(k12d+2*k22d+2*k32d+k42d)
    k3d=(1/6)*(k13d+2*k23d+2*k33d+k43d)
    k4d=(1/6)*(k14d+2*k24d+2*k34d+k44d)
    xd[i]=xd[i-1]+k1d*h
    yd[i]=yd[i-1]+k2d*h 
    pxd[i]=pxd[i-1]+k3d*h
    pyd[i]=pyd[i-1]+k4d*h
    
    
    if xd[i]*xd[i-1]<0 and pxd[i]>0 and pxd[i-1]>0:
            dt=-xd[i-1]/k1d
            Yd[i]=(yd[i-1]+k2d*dt)
            PYd[i]=(pyd[i-1]+k4d*dt)
            xd[i]=0
            i=i+1
    else:
            Yd[i]=0
            PYd[i]=0
            i=i+1
else :           
    plt.scatter(Yd,PYd,s=0.1,c='b')
i=0
xd[i]=0
yd[i]=-0.375
pyd[i]=0
pxd[i]=(2*E-(pyd[i]**2)-(xd[i]**2)-(yd[i]**2)-2*(xd[i]**2)*yd[i]+(2*(yd[i]**3)/3))**(1/2)
i=i+1
print(pxd[0])

        
while i<=n:
    
    k11d=pxd[i-1]
    k12d=pyd[i-1]
    k13d=(-1)*xd[i-1]-2*xd[i-1]*yd[i-1]
    k14d=(-1)*yd[i-1]-(xd[i-1]**2)+(yd[i-1]**2)
    x1d=xd[i-1]+(h/2)*k11d
    y1d=yd[i-1]+(h/2)*k12d
    px1d=pxd[i-1]+(h/2)*k13d
    py1d=pyd[i-1]+(h/2)*k14d
    k21d=px1d
    k22d=py1d
    k23d=(-1)*x1d-2*(x1d)*(y1d)
    k24d=(-1)*y1d-((x1d)**2)+((y1d)**2)
    x2d=xd[i-1]+(h/2)*k21d
    y2d=yd[i-1]+(h/2)*k22d
    px2d=pxd[i-1]+(h/2)*k23d
    py2d=pyd[i-1]+(h/2)*k24d
    k31d=px2d
    k32d=py2d
    k33d=(-1)*x2d-2*(x2d)*(y2d)
    k34d=(-1)*y2d-((x2d)**2)+((y2d)**2)
    x3d=xd[i-1]+h*k31d
    y3d=yd[i-1]+h*k32d
    px3d=pxd[i-1]+h*k33d
    py3d=pyd[i-1]+h*k34d
    k41d=px3d
    k42d=py3d
    k43d=(-1)*x3d-2*(x3d)*(y3d)
    k44d=(-1)*y3d-((x3d)**2)+((y3d)**2)
    k1d=(1/6)*(k11d+2*k21d+2*k31d+k41d)
    k2d=(1/6)*(k12d+2*k22d+2*k32d+k42d)
    k3d=(1/6)*(k13d+2*k23d+2*k33d+k43d)
    k4d=(1/6)*(k14d+2*k24d+2*k34d+k44d)
    xd[i]=xd[i-1]+k1d*h
    yd[i]=yd[i-1]+k2d*h 
    pxd[i]=pxd[i-1]+k3d*h
    pyd[i]=pyd[i-1]+k4d*h
    
    
    if xd[i]*xd[i-1]<0 and pxd[i]>0 and pxd[i-1]>0:
            dt=-xd[i-1]/k1d
            Yd[i]=(yd[i-1]+k2d*dt)
            PYd[i]=(pyd[i-1]+k4d*dt)
            xd[i]=0
            i=i+1
    else:
            Yd[i]=0
            PYd[i]=0
            i=i+1
else :           
    plt.scatter(Yd,PYd,s=0.1,c='b')
i=0
xb[i]=0
yb[i]=-0.4
pyb[i]=0
pxb[i]=(2*E-(pyb[i]**2)-(xb[i]**2)-(yb[i]**2)-2*(xb[i]**2)*yb[i]+(2*(yb[i]**3)/3))**(1/2)
i=i+1
print(pxb[0])

        
while i<=n:
    
    k11b=pxb[i-1]
    k12b=pyb[i-1]
    k13b=(-1)*xb[i-1]-2*xb[i-1]*yb[i-1]
    k14b=(-1)*yb[i-1]-(xb[i-1]**2)+(yb[i-1]**2)
    x1b=xb[i-1]+(h/2)*k11b
    y1b=yb[i-1]+(h/2)*k12b
    px1b=pxb[i-1]+(h/2)*k13b
    py1b=pyb[i-1]+(h/2)*k14b
    k21b=px1b
    k22b=py1b
    k23b=(-1)*x1b-2*(x1b)*(y1b)
    k24b=(-1)*y1b-((x1b)**2)+((y1b)**2)
    x2b=xb[i-1]+(h/2)*k21b
    y2b=yb[i-1]+(h/2)*k22b
    px2b=pxb[i-1]+(h/2)*k23b
    py2b=pyb[i-1]+(h/2)*k24b
    k31b=px2b
    k32b=py2b
    k33b=(-1)*x2b-2*(x2b)*(y2b)
    k34b=(-1)*y2b-((x2b)**2)+((y2b)**2)
    x3b=xb[i-1]+h*k31b
    y3b=yb[i-1]+h*k32b
    px3b=pxb[i-1]+h*k33b
    py3b=pyb[i-1]+h*k34b
    k41b=px3b
    k42b=py3b
    k43b=(-1)*x3b-2*(x3b)*(y3b)
    k44b=(-1)*y3b-((x3b)**2)+((y3b)**2)
    k1b=(1/6)*(k11b+2*k21b+2*k31b+k41b)
    k2b=(1/6)*(k12b+2*k22b+2*k32b+k42b)
    k3b=(1/6)*(k13b+2*k23b+2*k33b+k43b)
    k4b=(1/6)*(k14b+2*k24b+2*k34b+k44b)
    xb[i]=xb[i-1]+k1b*h
    yb[i]=yb[i-1]+k2b*h 
    pxb[i]=pxb[i-1]+k3b*h
    pyb[i]=pyb[i-1]+k4b*h
    
    
    if xb[i]*xb[i-1]<0 and pxb[i]>0 and pxb[i-1]>0:
            dt=-xb[i-1]/k1b
            Yb[i]=(yb[i-1]+k2b*dt)
            PYb[i]=(pyb[i-1]+k4b*dt)
            xb[i]=0
            i=i+1
    else:
            Yb[i]=0
            PYb[i]=0
            i=i+1
else :           
    plt.scatter(Yb,PYb,s=0.1,c='b')
    
i=0
xb[i]=0
yb[i]=0.02
pyb[i]=0.1
pxb[i]=(2*E-(pyb[i]**2)-(xb[i]**2)-(yb[i]**2)-2*(xb[i]**2)*yb[i]+(2*(yb[i]**3)/3))**(1/2)
i=i+1
print(pxb[0])

        
while i<=n:
    
    k11b=pxb[i-1]
    k12b=pyb[i-1]
    k13b=(-1)*xb[i-1]-2*xb[i-1]*yb[i-1]
    k14b=(-1)*yb[i-1]-(xb[i-1]**2)+(yb[i-1]**2)
    x1b=xb[i-1]+(h/2)*k11b
    y1b=yb[i-1]+(h/2)*k12b
    px1b=pxb[i-1]+(h/2)*k13b
    py1b=pyb[i-1]+(h/2)*k14b
    k21b=px1b
    k22b=py1b
    k23b=(-1)*x1b-2*(x1b)*(y1b)
    k24b=(-1)*y1b-((x1b)**2)+((y1b)**2)
    x2b=xb[i-1]+(h/2)*k21b
    y2b=yb[i-1]+(h/2)*k22b
    px2b=pxb[i-1]+(h/2)*k23b
    py2b=pyb[i-1]+(h/2)*k24b
    k31b=px2b
    k32b=py2b
    k33b=(-1)*x2b-2*(x2b)*(y2b)
    k34b=(-1)*y2b-((x2b)**2)+((y2b)**2)
    x3b=xb[i-1]+h*k31b
    y3b=yb[i-1]+h*k32b
    px3b=pxb[i-1]+h*k33b
    py3b=pyb[i-1]+h*k34b
    k41b=px3b
    k42b=py3b
    k43b=(-1)*x3b-2*(x3b)*(y3b)
    k44b=(-1)*y3b-((x3b)**2)+((y3b)**2)
    k1b=(1/6)*(k11b+2*k21b+2*k31b+k41b)
    k2b=(1/6)*(k12b+2*k22b+2*k32b+k42b)
    k3b=(1/6)*(k13b+2*k23b+2*k33b+k43b)
    k4b=(1/6)*(k14b+2*k24b+2*k34b+k44b)
    xb[i]=xb[i-1]+k1b*h
    yb[i]=yb[i-1]+k2b*h 
    pxb[i]=pxb[i-1]+k3b*h
    pyb[i]=pyb[i-1]+k4b*h
    
    
    if xb[i]*xb[i-1]<0 and pxb[i]>0 and pxb[i-1]>0:
            dt=-xb[i-1]/k1b
            Yb[i]=(yb[i-1]+k2b*dt)
            PYb[i]=(pyb[i-1]+k4b*dt)
            xb[i]=0
            i=i+1
    else:
            Yb[i]=0
            PYb[i]=0
            i=i+1
else :           
    plt.scatter(Yb,PYb,s=0.1,c='r')
    
i=0
xb[i]=0
yb[i]=0
pyb[i]=-0.23
pxb[i]=(2*E-(pyb[i]**2)-(xb[i]**2)-(yb[i]**2)-2*(xb[i]**2)*yb[i]+(2*(yb[i]**3)/3))**(1/2)
i=i+1
print(pxb[0])

        
while i<=n:
    
    k11b=pxb[i-1]
    k12b=pyb[i-1]
    k13b=(-1)*xb[i-1]-2*xb[i-1]*yb[i-1]
    k14b=(-1)*yb[i-1]-(xb[i-1]**2)+(yb[i-1]**2)
    x1b=xb[i-1]+(h/2)*k11b
    y1b=yb[i-1]+(h/2)*k12b
    px1b=pxb[i-1]+(h/2)*k13b
    py1b=pyb[i-1]+(h/2)*k14b
    k21b=px1b
    k22b=py1b
    k23b=(-1)*x1b-2*(x1b)*(y1b)
    k24b=(-1)*y1b-((x1b)**2)+((y1b)**2)
    x2b=xb[i-1]+(h/2)*k21b
    y2b=yb[i-1]+(h/2)*k22b
    px2b=pxb[i-1]+(h/2)*k23b
    py2b=pyb[i-1]+(h/2)*k24b
    k31b=px2b
    k32b=py2b
    k33b=(-1)*x2b-2*(x2b)*(y2b)
    k34b=(-1)*y2b-((x2b)**2)+((y2b)**2)
    x3b=xb[i-1]+h*k31b
    y3b=yb[i-1]+h*k32b
    px3b=pxb[i-1]+h*k33b
    py3b=pyb[i-1]+h*k34b
    k41b=px3b
    k42b=py3b
    k43b=(-1)*x3b-2*(x3b)*(y3b)
    k44b=(-1)*y3b-((x3b)**2)+((y3b)**2)
    k1b=(1/6)*(k11b+2*k21b+2*k31b+k41b)
    k2b=(1/6)*(k12b+2*k22b+2*k32b+k42b)
    k3b=(1/6)*(k13b+2*k23b+2*k33b+k43b)
    k4b=(1/6)*(k14b+2*k24b+2*k34b+k44b)
    xb[i]=xb[i-1]+k1b*h
    yb[i]=yb[i-1]+k2b*h 
    pxb[i]=pxb[i-1]+k3b*h
    pyb[i]=pyb[i-1]+k4b*h
    
    
    if xb[i]*xb[i-1]<0 and pxb[i]>0 and pxb[i-1]>0:
            dt=-xb[i-1]/k1b
            Yb[i]=(yb[i-1]+k2b*dt)
            PYb[i]=(pyb[i-1]+k4b*dt)
            xb[i]=0
            i=i+1
    else:
            Yb[i]=0
            PYb[i]=0
            i=i+1
else :           
    plt.scatter(Yb,PYb,s=0.1,c='g')
    
i=0
xb[i]=0
yb[i]=0
pyb[i]=0.2
pxb[i]=(2*E-(pyb[i]**2)-(xb[i]**2)-(yb[i]**2)-2*(xb[i]**2)*yb[i]+(2*(yb[i]**3)/3))**(1/2)
i=i+1
print(pxb[0])

        
while i<=n:
    
    k11b=pxb[i-1]
    k12b=pyb[i-1]
    k13b=(-1)*xb[i-1]-2*xb[i-1]*yb[i-1]
    k14b=(-1)*yb[i-1]-(xb[i-1]**2)+(yb[i-1]**2)
    x1b=xb[i-1]+(h/2)*k11b
    y1b=yb[i-1]+(h/2)*k12b
    px1b=pxb[i-1]+(h/2)*k13b
    py1b=pyb[i-1]+(h/2)*k14b
    k21b=px1b
    k22b=py1b
    k23b=(-1)*x1b-2*(x1b)*(y1b)
    k24b=(-1)*y1b-((x1b)**2)+((y1b)**2)
    x2b=xb[i-1]+(h/2)*k21b
    y2b=yb[i-1]+(h/2)*k22b
    px2b=pxb[i-1]+(h/2)*k23b
    py2b=pyb[i-1]+(h/2)*k24b
    k31b=px2b
    k32b=py2b
    k33b=(-1)*x2b-2*(x2b)*(y2b)
    k34b=(-1)*y2b-((x2b)**2)+((y2b)**2)
    x3b=xb[i-1]+h*k31b
    y3b=yb[i-1]+h*k32b
    px3b=pxb[i-1]+h*k33b
    py3b=pyb[i-1]+h*k34b
    k41b=px3b
    k42b=py3b
    k43b=(-1)*x3b-2*(x3b)*(y3b)
    k44b=(-1)*y3b-((x3b)**2)+((y3b)**2)
    k1b=(1/6)*(k11b+2*k21b+2*k31b+k41b)
    k2b=(1/6)*(k12b+2*k22b+2*k32b+k42b)
    k3b=(1/6)*(k13b+2*k23b+2*k33b+k43b)
    k4b=(1/6)*(k14b+2*k24b+2*k34b+k44b)
    xb[i]=xb[i-1]+k1b*h
    yb[i]=yb[i-1]+k2b*h 
    pxb[i]=pxb[i-1]+k3b*h
    pyb[i]=pyb[i-1]+k4b*h
    
    
    if xb[i]*xb[i-1]<0 and pxb[i]>0 and pxb[i-1]>0:
            dt=-xb[i-1]/k1b
            Yb[i]=(yb[i-1]+k2b*dt)
            PYb[i]=(pyb[i-1]+k4b*dt)
            xb[i]=0
            i=i+1
    else:
            Yb[i]=0
            PYb[i]=0
            i=i+1
else :           
    plt.scatter(Yb,PYb,s=0.1,c='g')
    
i=0
xb[i]=0
yb[i]=0
pyb[i]=-0.2
pxb[i]=(2*E-(pyb[i]**2)-(xb[i]**2)-(yb[i]**2)-2*(xb[i]**2)*yb[i]+(2*(yb[i]**3)/3))**(1/2)
i=i+1
print(pxb[0])

        
while i<=n:
    
    k11b=pxb[i-1]
    k12b=pyb[i-1]
    k13b=(-1)*xb[i-1]-2*xb[i-1]*yb[i-1]
    k14b=(-1)*yb[i-1]-(xb[i-1]**2)+(yb[i-1]**2)
    x1b=xb[i-1]+(h/2)*k11b
    y1b=yb[i-1]+(h/2)*k12b
    px1b=pxb[i-1]+(h/2)*k13b
    py1b=pyb[i-1]+(h/2)*k14b
    k21b=px1b
    k22b=py1b
    k23b=(-1)*x1b-2*(x1b)*(y1b)
    k24b=(-1)*y1b-((x1b)**2)+((y1b)**2)
    x2b=xb[i-1]+(h/2)*k21b
    y2b=yb[i-1]+(h/2)*k22b
    px2b=pxb[i-1]+(h/2)*k23b
    py2b=pyb[i-1]+(h/2)*k24b
    k31b=px2b
    k32b=py2b
    k33b=(-1)*x2b-2*(x2b)*(y2b)
    k34b=(-1)*y2b-((x2b)**2)+((y2b)**2)
    x3b=xb[i-1]+h*k31b
    y3b=yb[i-1]+h*k32b
    px3b=pxb[i-1]+h*k33b
    py3b=pyb[i-1]+h*k34b
    k41b=px3b
    k42b=py3b
    k43b=(-1)*x3b-2*(x3b)*(y3b)
    k44b=(-1)*y3b-((x3b)**2)+((y3b)**2)
    k1b=(1/6)*(k11b+2*k21b+2*k31b+k41b)
    k2b=(1/6)*(k12b+2*k22b+2*k32b+k42b)
    k3b=(1/6)*(k13b+2*k23b+2*k33b+k43b)
    k4b=(1/6)*(k14b+2*k24b+2*k34b+k44b)
    xb[i]=xb[i-1]+k1b*h
    yb[i]=yb[i-1]+k2b*h 
    pxb[i]=pxb[i-1]+k3b*h
    pyb[i]=pyb[i-1]+k4b*h
    
    
    if xb[i]*xb[i-1]<0 and pxb[i]>0 and pxb[i-1]>0:
            dt=-xb[i-1]/k1b
            Yb[i]=(yb[i-1]+k2b*dt)
            PYb[i]=(pyb[i-1]+k4b*dt)
            xb[i]=0
            i=i+1
    else:
            Yb[i]=0
            PYb[i]=0
            i=i+1
else :           
    plt.scatter(Yb,PYb,s=0.1,c='g')
    
i=0
xb[i]=0
yb[i]=0
pyb[i]=0.23
pxb[i]=(2*E-(pyb[i]**2)-(xb[i]**2)-(yb[i]**2)-2*(xb[i]**2)*yb[i]+(2*(yb[i]**3)/3))**(1/2)
i=i+1
print(pxb[0])

        
while i<=n:
    
    k11b=pxb[i-1]
    k12b=pyb[i-1]
    k13b=(-1)*xb[i-1]-2*xb[i-1]*yb[i-1]
    k14b=(-1)*yb[i-1]-(xb[i-1]**2)+(yb[i-1]**2)
    x1b=xb[i-1]+(h/2)*k11b
    y1b=yb[i-1]+(h/2)*k12b
    px1b=pxb[i-1]+(h/2)*k13b
    py1b=pyb[i-1]+(h/2)*k14b
    k21b=px1b
    k22b=py1b
    k23b=(-1)*x1b-2*(x1b)*(y1b)
    k24b=(-1)*y1b-((x1b)**2)+((y1b)**2)
    x2b=xb[i-1]+(h/2)*k21b
    y2b=yb[i-1]+(h/2)*k22b
    px2b=pxb[i-1]+(h/2)*k23b
    py2b=pyb[i-1]+(h/2)*k24b
    k31b=px2b
    k32b=py2b
    k33b=(-1)*x2b-2*(x2b)*(y2b)
    k34b=(-1)*y2b-((x2b)**2)+((y2b)**2)
    x3b=xb[i-1]+h*k31b
    y3b=yb[i-1]+h*k32b
    px3b=pxb[i-1]+h*k33b
    py3b=pyb[i-1]+h*k34b
    k41b=px3b
    k42b=py3b
    k43b=(-1)*x3b-2*(x3b)*(y3b)
    k44b=(-1)*y3b-((x3b)**2)+((y3b)**2)
    k1b=(1/6)*(k11b+2*k21b+2*k31b+k41b)
    k2b=(1/6)*(k12b+2*k22b+2*k32b+k42b)
    k3b=(1/6)*(k13b+2*k23b+2*k33b+k43b)
    k4b=(1/6)*(k14b+2*k24b+2*k34b+k44b)
    xb[i]=xb[i-1]+k1b*h
    yb[i]=yb[i-1]+k2b*h 
    pxb[i]=pxb[i-1]+k3b*h
    pyb[i]=pyb[i-1]+k4b*h
    
    
    if xb[i]*xb[i-1]<0 and pxb[i]>0 and pxb[i-1]>0:
            dt=-xb[i-1]/k1b
            Yb[i]=(yb[i-1]+k2b*dt)
            PYb[i]=(pyb[i-1]+k4b*dt)
            xb[i]=0
            i=i+1
    else:
            Yb[i]=0
            PYb[i]=0
            i=i+1
else :           
    plt.scatter(Yb,PYb,s=0.1,c='g')
i=0
xb[i]=0
yb[i]=0.08
pyb[i]=0.2
pxb[i]=(2*E-(pyb[i]**2)-(xb[i]**2)-(yb[i]**2)-2*(xb[i]**2)*yb[i]+(2*(yb[i]**3)/3))**(1/2)
i=i+1
print(pxb[0])

        
while i<=n:
    
    k11b=pxb[i-1]
    k12b=pyb[i-1]
    k13b=(-1)*xb[i-1]-2*xb[i-1]*yb[i-1]
    k14b=(-1)*yb[i-1]-(xb[i-1]**2)+(yb[i-1]**2)
    x1b=xb[i-1]+(h/2)*k11b
    y1b=yb[i-1]+(h/2)*k12b
    px1b=pxb[i-1]+(h/2)*k13b
    py1b=pyb[i-1]+(h/2)*k14b
    k21b=px1b
    k22b=py1b
    k23b=(-1)*x1b-2*(x1b)*(y1b)
    k24b=(-1)*y1b-((x1b)**2)+((y1b)**2)
    x2b=xb[i-1]+(h/2)*k21b
    y2b=yb[i-1]+(h/2)*k22b
    px2b=pxb[i-1]+(h/2)*k23b
    py2b=pyb[i-1]+(h/2)*k24b
    k31b=px2b
    k32b=py2b
    k33b=(-1)*x2b-2*(x2b)*(y2b)
    k34b=(-1)*y2b-((x2b)**2)+((y2b)**2)
    x3b=xb[i-1]+h*k31b
    y3b=yb[i-1]+h*k32b
    px3b=pxb[i-1]+h*k33b
    py3b=pyb[i-1]+h*k34b
    k41b=px3b
    k42b=py3b
    k43b=(-1)*x3b-2*(x3b)*(y3b)
    k44b=(-1)*y3b-((x3b)**2)+((y3b)**2)
    k1b=(1/6)*(k11b+2*k21b+2*k31b+k41b)
    k2b=(1/6)*(k12b+2*k22b+2*k32b+k42b)
    k3b=(1/6)*(k13b+2*k23b+2*k33b+k43b)
    k4b=(1/6)*(k14b+2*k24b+2*k34b+k44b)
    xb[i]=xb[i-1]+k1b*h
    yb[i]=yb[i-1]+k2b*h 
    pxb[i]=pxb[i-1]+k3b*h
    pyb[i]=pyb[i-1]+k4b*h
    
    
    if xb[i]*xb[i-1]<0 and pxb[i]>0 and pxb[i-1]>0:
            dt=-xb[i-1]/k1b
            Yb[i]=(yb[i-1]+k2b*dt)
            PYb[i]=(pyb[i-1]+k4b*dt)
            xb[i]=0
            i=i+1
    else:
            Yb[i]=0
            PYb[i]=0
            i=i+1
else :           
    plt.scatter(Yb,PYb,s=0.1,c='g')
    
i=0
xb[i]=0
yb[i]=0.08
pyb[i]=-0.2
pxb[i]=(2*E-(pyb[i]**2)-(xb[i]**2)-(yb[i]**2)-2*(xb[i]**2)*yb[i]+(2*(yb[i]**3)/3))**(1/2)
i=i+1
print(pxb[0])

        
while i<=n:
    
    k11b=pxb[i-1]
    k12b=pyb[i-1]
    k13b=(-1)*xb[i-1]-2*xb[i-1]*yb[i-1]
    k14b=(-1)*yb[i-1]-(xb[i-1]**2)+(yb[i-1]**2)
    x1b=xb[i-1]+(h/2)*k11b
    y1b=yb[i-1]+(h/2)*k12b
    px1b=pxb[i-1]+(h/2)*k13b
    py1b=pyb[i-1]+(h/2)*k14b
    k21b=px1b
    k22b=py1b
    k23b=(-1)*x1b-2*(x1b)*(y1b)
    k24b=(-1)*y1b-((x1b)**2)+((y1b)**2)
    x2b=xb[i-1]+(h/2)*k21b
    y2b=yb[i-1]+(h/2)*k22b
    px2b=pxb[i-1]+(h/2)*k23b
    py2b=pyb[i-1]+(h/2)*k24b
    k31b=px2b
    k32b=py2b
    k33b=(-1)*x2b-2*(x2b)*(y2b)
    k34b=(-1)*y2b-((x2b)**2)+((y2b)**2)
    x3b=xb[i-1]+h*k31b
    y3b=yb[i-1]+h*k32b
    px3b=pxb[i-1]+h*k33b
    py3b=pyb[i-1]+h*k34b
    k41b=px3b
    k42b=py3b
    k43b=(-1)*x3b-2*(x3b)*(y3b)
    k44b=(-1)*y3b-((x3b)**2)+((y3b)**2)
    k1b=(1/6)*(k11b+2*k21b+2*k31b+k41b)
    k2b=(1/6)*(k12b+2*k22b+2*k32b+k42b)
    k3b=(1/6)*(k13b+2*k23b+2*k33b+k43b)
    k4b=(1/6)*(k14b+2*k24b+2*k34b+k44b)
    xb[i]=xb[i-1]+k1b*h
    yb[i]=yb[i-1]+k2b*h 
    pxb[i]=pxb[i-1]+k3b*h
    pyb[i]=pyb[i-1]+k4b*h
    
    
    if xb[i]*xb[i-1]<0 and pxb[i]>0 and pxb[i-1]>0:
            dt=-xb[i-1]/k1b
            Yb[i]=(yb[i-1]+k2b*dt)
            PYb[i]=(pyb[i-1]+k4b*dt)
            xb[i]=0
            i=i+1
    else:
            Yb[i]=0
            PYb[i]=0
            i=i+1
else :           
    plt.scatter(Yb,PYb,s=0.1,c='g')
i=0
xb[i]=0
yb[i]=-0.35
pyb[i]=0
pxb[i]=(2*E-(pyb[i]**2)-(xb[i]**2)-(yb[i]**2)-2*(xb[i]**2)*yb[i]+(2*(yb[i]**3)/3))**(1/2)
i=i+1
print(pxb[0])

        
while i<=n:
    
    k11b=pxb[i-1]
    k12b=pyb[i-1]
    k13b=(-1)*xb[i-1]-2*xb[i-1]*yb[i-1]
    k14b=(-1)*yb[i-1]-(xb[i-1]**2)+(yb[i-1]**2)
    x1b=xb[i-1]+(h/2)*k11b
    y1b=yb[i-1]+(h/2)*k12b
    px1b=pxb[i-1]+(h/2)*k13b
    py1b=pyb[i-1]+(h/2)*k14b
    k21b=px1b
    k22b=py1b
    k23b=(-1)*x1b-2*(x1b)*(y1b)
    k24b=(-1)*y1b-((x1b)**2)+((y1b)**2)
    x2b=xb[i-1]+(h/2)*k21b
    y2b=yb[i-1]+(h/2)*k22b
    px2b=pxb[i-1]+(h/2)*k23b
    py2b=pyb[i-1]+(h/2)*k24b
    k31b=px2b
    k32b=py2b
    k33b=(-1)*x2b-2*(x2b)*(y2b)
    k34b=(-1)*y2b-((x2b)**2)+((y2b)**2)
    x3b=xb[i-1]+h*k31b
    y3b=yb[i-1]+h*k32b
    px3b=pxb[i-1]+h*k33b
    py3b=pyb[i-1]+h*k34b
    k41b=px3b
    k42b=py3b
    k43b=(-1)*x3b-2*(x3b)*(y3b)
    k44b=(-1)*y3b-((x3b)**2)+((y3b)**2)
    k1b=(1/6)*(k11b+2*k21b+2*k31b+k41b)
    k2b=(1/6)*(k12b+2*k22b+2*k32b+k42b)
    k3b=(1/6)*(k13b+2*k23b+2*k33b+k43b)
    k4b=(1/6)*(k14b+2*k24b+2*k34b+k44b)
    xb[i]=xb[i-1]+k1b*h
    yb[i]=yb[i-1]+k2b*h 
    pxb[i]=pxb[i-1]+k3b*h
    pyb[i]=pyb[i-1]+k4b*h
    
    
    if xb[i]*xb[i-1]<0 and pxb[i]>0 and pxb[i-1]>0:
            dt=-xb[i-1]/k1b
            Yb[i]=(yb[i-1]+k2b*dt)
            PYb[i]=(pyb[i-1]+k4b*dt)
            xb[i]=0
            i=i+1
    else:
            Yb[i]=0
            PYb[i]=0
            i=i+1
else :           
    plt.scatter(Yb,PYb,s=0.1,c='b')
    
i=0
xb[i]=0
yb[i]=-0.15
pyb[i]=-0.15
pxb[i]=(2*E-(pyb[i]**2)-(xb[i]**2)-(yb[i]**2)-2*(xb[i]**2)*yb[i]+(2*(yb[i]**3)/3))**(1/2)
i=i+1
print(pxb[0])

        
while i<=n:
    
    k11b=pxb[i-1]
    k12b=pyb[i-1]
    k13b=(-1)*xb[i-1]-2*xb[i-1]*yb[i-1]
    k14b=(-1)*yb[i-1]-(xb[i-1]**2)+(yb[i-1]**2)
    x1b=xb[i-1]+(h/2)*k11b
    y1b=yb[i-1]+(h/2)*k12b
    px1b=pxb[i-1]+(h/2)*k13b
    py1b=pyb[i-1]+(h/2)*k14b
    k21b=px1b
    k22b=py1b
    k23b=(-1)*x1b-2*(x1b)*(y1b)
    k24b=(-1)*y1b-((x1b)**2)+((y1b)**2)
    x2b=xb[i-1]+(h/2)*k21b
    y2b=yb[i-1]+(h/2)*k22b
    px2b=pxb[i-1]+(h/2)*k23b
    py2b=pyb[i-1]+(h/2)*k24b
    k31b=px2b
    k32b=py2b
    k33b=(-1)*x2b-2*(x2b)*(y2b)
    k34b=(-1)*y2b-((x2b)**2)+((y2b)**2)
    x3b=xb[i-1]+h*k31b
    y3b=yb[i-1]+h*k32b
    px3b=pxb[i-1]+h*k33b
    py3b=pyb[i-1]+h*k34b
    k41b=px3b
    k42b=py3b
    k43b=(-1)*x3b-2*(x3b)*(y3b)
    k44b=(-1)*y3b-((x3b)**2)+((y3b)**2)
    k1b=(1/6)*(k11b+2*k21b+2*k31b+k41b)
    k2b=(1/6)*(k12b+2*k22b+2*k32b+k42b)
    k3b=(1/6)*(k13b+2*k23b+2*k33b+k43b)
    k4b=(1/6)*(k14b+2*k24b+2*k34b+k44b)
    xb[i]=xb[i-1]+k1b*h
    yb[i]=yb[i-1]+k2b*h 
    pxb[i]=pxb[i-1]+k3b*h
    pyb[i]=pyb[i-1]+k4b*h
    
    
    if xb[i]*xb[i-1]<0 and pxb[i]>0 and pxb[i-1]>0:
            dt=-xb[i-1]/k1b
            Yb[i]=(yb[i-1]+k2b*dt)
            PYb[i]=(pyb[i-1]+k4b*dt)
            xb[i]=0
            i=i+1
    else:
            Yb[i]=0
            PYb[i]=0
            i=i+1
else :           
    plt.scatter(Yb,PYb,s=0.1,c='orange')
i=0
xb[i]=0
yb[i]=-0.15
pyb[i]=0.15
pxb[i]=(2*E-(pyb[i]**2)-(xb[i]**2)-(yb[i]**2)-2*(xb[i]**2)*yb[i]+(2*(yb[i]**3)/3))**(1/2)
i=i+1
print(pxb[0])

        
while i<=n:
    
    k11b=pxb[i-1]
    k12b=pyb[i-1]
    k13b=(-1)*xb[i-1]-2*xb[i-1]*yb[i-1]
    k14b=(-1)*yb[i-1]-(xb[i-1]**2)+(yb[i-1]**2)
    x1b=xb[i-1]+(h/2)*k11b
    y1b=yb[i-1]+(h/2)*k12b
    px1b=pxb[i-1]+(h/2)*k13b
    py1b=pyb[i-1]+(h/2)*k14b
    k21b=px1b
    k22b=py1b
    k23b=(-1)*x1b-2*(x1b)*(y1b)
    k24b=(-1)*y1b-((x1b)**2)+((y1b)**2)
    x2b=xb[i-1]+(h/2)*k21b
    y2b=yb[i-1]+(h/2)*k22b
    px2b=pxb[i-1]+(h/2)*k23b
    py2b=pyb[i-1]+(h/2)*k24b
    k31b=px2b
    k32b=py2b
    k33b=(-1)*x2b-2*(x2b)*(y2b)
    k34b=(-1)*y2b-((x2b)**2)+((y2b)**2)
    x3b=xb[i-1]+h*k31b
    y3b=yb[i-1]+h*k32b
    px3b=pxb[i-1]+h*k33b
    py3b=pyb[i-1]+h*k34b
    k41b=px3b
    k42b=py3b
    k43b=(-1)*x3b-2*(x3b)*(y3b)
    k44b=(-1)*y3b-((x3b)**2)+((y3b)**2)
    k1b=(1/6)*(k11b+2*k21b+2*k31b+k41b)
    k2b=(1/6)*(k12b+2*k22b+2*k32b+k42b)
    k3b=(1/6)*(k13b+2*k23b+2*k33b+k43b)
    k4b=(1/6)*(k14b+2*k24b+2*k34b+k44b)
    xb[i]=xb[i-1]+k1b*h
    yb[i]=yb[i-1]+k2b*h 
    pxb[i]=pxb[i-1]+k3b*h
    pyb[i]=pyb[i-1]+k4b*h
    
    
    if xb[i]*xb[i-1]<0 and pxb[i]>0 and pxb[i-1]>0:
            dt=-xb[i-1]/k1b
            Yb[i]=(yb[i-1]+k2b*dt)
            PYb[i]=(pyb[i-1]+k4b*dt)
            xb[i]=0
            i=i+1
    else:
            Yb[i]=0
            PYb[i]=0
            i=i+1
else :           
    plt.scatter(Yb,PYb,s=0.1,c='orange')
    
i=0
xb[i]=0
yb[i]=-0.15
pyb[i]=0
pxb[i]=(2*E-(pyb[i]**2)-(xb[i]**2)-(yb[i]**2)-2*(xb[i]**2)*yb[i]+(2*(yb[i]**3)/3))**(1/2)
i=i+1
print(pxb[0])

        
while i<=n:
    
    k11b=pxb[i-1]
    k12b=pyb[i-1]
    k13b=(-1)*xb[i-1]-2*xb[i-1]*yb[i-1]
    k14b=(-1)*yb[i-1]-(xb[i-1]**2)+(yb[i-1]**2)
    x1b=xb[i-1]+(h/2)*k11b
    y1b=yb[i-1]+(h/2)*k12b
    px1b=pxb[i-1]+(h/2)*k13b
    py1b=pyb[i-1]+(h/2)*k14b
    k21b=px1b
    k22b=py1b
    k23b=(-1)*x1b-2*(x1b)*(y1b)
    k24b=(-1)*y1b-((x1b)**2)+((y1b)**2)
    x2b=xb[i-1]+(h/2)*k21b
    y2b=yb[i-1]+(h/2)*k22b
    px2b=pxb[i-1]+(h/2)*k23b
    py2b=pyb[i-1]+(h/2)*k24b
    k31b=px2b
    k32b=py2b
    k33b=(-1)*x2b-2*(x2b)*(y2b)
    k34b=(-1)*y2b-((x2b)**2)+((y2b)**2)
    x3b=xb[i-1]+h*k31b
    y3b=yb[i-1]+h*k32b
    px3b=pxb[i-1]+h*k33b
    py3b=pyb[i-1]+h*k34b
    k41b=px3b
    k42b=py3b
    k43b=(-1)*x3b-2*(x3b)*(y3b)
    k44b=(-1)*y3b-((x3b)**2)+((y3b)**2)
    k1b=(1/6)*(k11b+2*k21b+2*k31b+k41b)
    k2b=(1/6)*(k12b+2*k22b+2*k32b+k42b)
    k3b=(1/6)*(k13b+2*k23b+2*k33b+k43b)
    k4b=(1/6)*(k14b+2*k24b+2*k34b+k44b)
    xb[i]=xb[i-1]+k1b*h
    yb[i]=yb[i-1]+k2b*h 
    pxb[i]=pxb[i-1]+k3b*h
    pyb[i]=pyb[i-1]+k4b*h
    
    
    if xb[i]*xb[i-1]<0 and pxb[i]>0 and pxb[i-1]>0:
            dt=-xb[i-1]/k1b
            Yb[i]=(yb[i-1]+k2b*dt)
            PYb[i]=(pyb[i-1]+k4b*dt)
            xb[i]=0
            i=i+1
    else:
            Yb[i]=0
            PYb[i]=0
            i=i+1
else :           
    plt.scatter(Yb,PYb,s=0.1,c='orange')
plt.show()
# Out:
# 0.5
# 0.4939041742416573
# 0.47658227691204236
# 0.4490167034754943
# 0.4208127057650866
# 0.40063751280511245
# 0.37682887362833545
# 0.3485535587730145
# 0.2724311839712921
# 0.21756225162774284
# 0.48949497784281026
# 0.4439594576084623
# 0.458257569495584
# 0.458257569495584
# 0.4439594576084623
# 0.45159864186391585
# 0.45159864186391585
# 0.31451020121240375
# 0.4502776920967771
# 0.4502776920967771
# 0.47460509900337144
