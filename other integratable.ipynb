# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy import optimize, special
from numpy import *
from pylab import *
import decimal
import math
E=1/100
plt.style.use("seaborn-whitegrid")
n=500000
h=5000/n
x=np.zeros(n+1,dtype='float64')
y=np.zeros(n+1,dtype='float64')
px=np.zeros(n+1,dtype='float64')
py=np.zeros(n+1,dtype='float64')
Y=np.zeros(n+1,dtype='float64')
PY=np.zeros(n+1,dtype='float64')
i=0
x[i]=0
y[i]=-0.02
py[i]=0
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(4*(y[i]**3)))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=n:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-6*(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    px1=px[i-1]+(h/2)*k13
    py1=py[i-1]+(h/2)*k14
    
    k21=px1
    k22=py1
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-6*((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    px2=px[i-1]+(h/2)*k23
    py2=py[i-1]+(h/2)*k24 
    
    k31=px2
    k32=py2
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-6*((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            dt=-x[i-1]/k1
            Y[i]=(y[i-1]+k2*dt)
            PY[i]=(py[i-1]+k4*dt)
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=1)
i=0
x[i]=0
y[i]=-0.01
py[i]=0
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(4*(y[i]**3)))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=n:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-6*(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    px1=px[i-1]+(h/2)*k13
    py1=py[i-1]+(h/2)*k14
    
    k21=px1
    k22=py1
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-6*((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    px2=px[i-1]+(h/2)*k23
    py2=py[i-1]+(h/2)*k24 
    
    k31=px2
    k32=py2
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-6*((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-6*((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            dt=-x[i-1]/k1
            Y[i]=(y[i-1]+k2*dt)
            PY[i]=(py[i-1]+k4*dt)
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=1)
    
i=0
x[i]=0
y[i]=0
py[i]=0
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(4*(y[i]**3)))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=n:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-6*(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    px1=px[i-1]+(h/2)*k13
    py1=py[i-1]+(h/2)*k14
    
    k21=px1
    k22=py1
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-6*((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    px2=px[i-1]+(h/2)*k23
    py2=py[i-1]+(h/2)*k24 
    
    k31=px2
    k32=py2
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-6*((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-6*((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            dt=-x[i-1]/k1
            Y[i]=(y[i-1]+k2*dt)
            PY[i]=(py[i-1]+k4*dt)
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=1)
i=0
x[i]=0
y[i]=0.01
py[i]=0
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(4*(y[i]**3)))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=n:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-6*(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    px1=px[i-1]+(h/2)*k13
    py1=py[i-1]+(h/2)*k14
    
    k21=px1
    k22=py1
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-6*((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    px2=px[i-1]+(h/2)*k23
    py2=py[i-1]+(h/2)*k24 
    
    k31=px2
    k32=py2
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-6*((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-6*((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            dt=-x[i-1]/k1
            Y[i]=(y[i-1]+k2*dt)
            PY[i]=(py[i-1]+k4*dt)
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=1)    
i=0
x[i]=0
y[i]=0.02
py[i]=0
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(4*(y[i]**3)))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=n:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-6*(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    px1=px[i-1]+(h/2)*k13
    py1=py[i-1]+(h/2)*k14
    
    k21=px1
    k22=py1
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-6*((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    px2=px[i-1]+(h/2)*k23
    py2=py[i-1]+(h/2)*k24 
    
    k31=px2
    k32=py2
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-6*((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-6*((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            dt=-x[i-1]/k1
            Y[i]=(y[i-1]+k2*dt)
            PY[i]=(py[i-1]+k4*dt)
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=1)
i=0
x[i]=0
y[i]=0.03
py[i]=0
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(4*(y[i]**3)))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=n:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-6*(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    px1=px[i-1]+(h/2)*k13
    py1=py[i-1]+(h/2)*k14
    
    k21=px1
    k22=py1
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-6*((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    px2=px[i-1]+(h/2)*k23
    py2=py[i-1]+(h/2)*k24 
    
    k31=px2
    k32=py2
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-6*((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-6*((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            dt=-x[i-1]/k1
            Y[i]=(y[i-1]+k2*dt)
            PY[i]=(py[i-1]+k4*dt)
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=1)
i=0
x[i]=0
y[i]=0.04
py[i]=0
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(4*(y[i]**3)))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=n:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-6*(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    px1=px[i-1]+(h/2)*k13
    py1=py[i-1]+(h/2)*k14
    
    k21=px1
    k22=py1
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-6*((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    px2=px[i-1]+(h/2)*k23
    py2=py[i-1]+(h/2)*k24 
    
    k31=px2
    k32=py2
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-6*((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-6*((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            dt=-x[i-1]/k1
            Y[i]=(y[i-1]+k2*dt)
            PY[i]=(py[i-1]+k4*dt)
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=1)
i=0
x[i]=0
y[i]=0.05
py[i]=0
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(4*(y[i]**3)))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=n:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-6*(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    px1=px[i-1]+(h/2)*k13
    py1=py[i-1]+(h/2)*k14
    
    k21=px1
    k22=py1
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-6*((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    px2=px[i-1]+(h/2)*k23
    py2=py[i-1]+(h/2)*k24 
    
    k31=px2
    k32=py2
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-6*((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-6*((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            dt=-x[i-1]/k1
            Y[i]=(y[i-1]+k2*dt)
            PY[i]=(py[i-1]+k4*dt)
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=1)
i=0
x[i]=0
y[i]=0.06
py[i]=0
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(4*(y[i]**3)))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=n:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-6*(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    px1=px[i-1]+(h/2)*k13
    py1=py[i-1]+(h/2)*k14
    
    k21=px1
    k22=py1
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-6*((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    px2=px[i-1]+(h/2)*k23
    py2=py[i-1]+(h/2)*k24 
    
    k31=px2
    k32=py2
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-6*((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-6*((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            dt=-x[i-1]/k1
            Y[i]=(y[i-1]+k2*dt)
            PY[i]=(py[i-1]+k4*dt)
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=1)
      
i=0
x[i]=0
y[i]=-0.08
py[i]=0
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(4*(y[i]**3)))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=n:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-6*(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    px1=px[i-1]+(h/2)*k13
    py1=py[i-1]+(h/2)*k14
    
    k21=px1
    k22=py1
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-6*((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    px2=px[i-1]+(h/2)*k23
    py2=py[i-1]+(h/2)*k24 
    
    k31=px2
    k32=py2
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-6*((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-6*((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            dt=-x[i-1]/k1
            Y[i]=(y[i-1]+k2*dt)
            PY[i]=(py[i-1]+k4*dt)
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=1)
    
i=0
x[i]=0
y[i]=-0.06
py[i]=0
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(4*(y[i]**3)))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=n:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-6*(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    px1=px[i-1]+(h/2)*k13
    py1=py[i-1]+(h/2)*k14
    
    k21=px1
    k22=py1
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-6*((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    px2=px[i-1]+(h/2)*k23
    py2=py[i-1]+(h/2)*k24 
    
    k31=px2
    k32=py2
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-6*((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-6*((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            dt=-x[i-1]/k1
            Y[i]=(y[i-1]+k2*dt)
            PY[i]=(py[i-1]+k4*dt)
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=1)
i=0
x[i]=0
y[i]=-0.07
py[i]=0
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(4*(y[i]**3)))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=n:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-6*(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    px1=px[i-1]+(h/2)*k13
    py1=py[i-1]+(h/2)*k14
    
    k21=px1
    k22=py1
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-6*((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    px2=px[i-1]+(h/2)*k23
    py2=py[i-1]+(h/2)*k24 
    
    k31=px2
    k32=py2
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-6*((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-6*((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            dt=-x[i-1]/k1
            Y[i]=(y[i-1]+k2*dt)
            PY[i]=(py[i-1]+k4*dt)
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=1)    
i=0
x[i]=0
y[i]=-0.04
py[i]=0
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(4*(y[i]**3)))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=n:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-6*(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    px1=px[i-1]+(h/2)*k13
    py1=py[i-1]+(h/2)*k14
    
    k21=px1
    k22=py1
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-6*((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    px2=px[i-1]+(h/2)*k23
    py2=py[i-1]+(h/2)*k24 
    
    k31=px2
    k32=py2
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-6*((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-6*((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            dt=-x[i-1]/k1
            Y[i]=(y[i-1]+k2*dt)
            PY[i]=(py[i-1]+k4*dt)
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=1)
i=0
x[i]=0
y[i]=-0.05
py[i]=0
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(4*(y[i]**3)))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=n:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-6*(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    px1=px[i-1]+(h/2)*k13
    py1=py[i-1]+(h/2)*k14
    
    k21=px1
    k22=py1
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-6*((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    px2=px[i-1]+(h/2)*k23
    py2=py[i-1]+(h/2)*k24 
    
    k31=px2
    k32=py2
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-6*((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-6*((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            dt=-x[i-1]/k1
            Y[i]=(y[i-1]+k2*dt)
            PY[i]=(py[i-1]+k4*dt)
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=1)
    
i=0
x[i]=0
y[i]=-0.03
py[i]=0
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(4*(y[i]**3)))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=n:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-6*(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    px1=px[i-1]+(h/2)*k13
    py1=py[i-1]+(h/2)*k14
    
    k21=px1
    k22=py1
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-6*((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    px2=px[i-1]+(h/2)*k23
    py2=py[i-1]+(h/2)*k24 
    
    k31=px2
    k32=py2
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-6*((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-6*((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            dt=-x[i-1]/k1
            Y[i]=(y[i-1]+k2*dt)
            PY[i]=(py[i-1]+k4*dt)
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=1)
plt.savefig("D:/temp7.png")
plt.show()
# Out:
# 0.14011423910509596
# 0.1410815367083872
# 0.1414213562373095
# 0.14105318146004364
# 0.1398856676003657
# 0.13781146541561773
# 0.1346996659238619
# 0.130384048104053
# 0.12464349160706306
# 0.12509196616889512
# 0.13139254164525474
# 0.12834328965707556
# 0.136586968631711
# 0.1341640786499874
# 0.13859292911256332

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy import optimize, special
from numpy import *
from pylab import *
import decimal
import math
E=1/1000
plt.style.use("seaborn-whitegrid")
n=500000
h=5000/n
x=np.zeros(n+1,dtype='float64')
y=np.zeros(n+1,dtype='float64')
px=np.zeros(n+1,dtype='float64')
py=np.zeros(n+1,dtype='float64')
Y=np.zeros(n+1,dtype='float64')
PY=np.zeros(n+1,dtype='float64')
i=0
x[i]=0
y[i]=-0.02
py[i]=0
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(4*(y[i]**3)))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=n:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-6*(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    px1=px[i-1]+(h/2)*k13
    py1=py[i-1]+(h/2)*k14
    
    k21=px1
    k22=py1
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-6*((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    px2=px[i-1]+(h/2)*k23
    py2=py[i-1]+(h/2)*k24 
    
    k31=px2
    k32=py2
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-6*((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            dt=-x[i-1]/k1
            Y[i]=(y[i-1]+k2*dt)
            PY[i]=(py[i-1]+k4*dt)
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=1)
i=0
x[i]=0
y[i]=-0.01
py[i]=0
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(4*(y[i]**3)))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=n:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-6*(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    px1=px[i-1]+(h/2)*k13
    py1=py[i-1]+(h/2)*k14
    
    k21=px1
    k22=py1
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-6*((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    px2=px[i-1]+(h/2)*k23
    py2=py[i-1]+(h/2)*k24 
    
    k31=px2
    k32=py2
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-6*((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            dt=-x[i-1]/k1
            Y[i]=(y[i-1]+k2*dt)
            PY[i]=(py[i-1]+k4*dt)
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=1)
    
i=0
x[i]=0
y[i]=0
py[i]=0
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(4*(y[i]**3)))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=n:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-6*(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    px1=px[i-1]+(h/2)*k13
    py1=py[i-1]+(h/2)*k14
    
    k21=px1
    k22=py1
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-6*((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    px2=px[i-1]+(h/2)*k23
    py2=py[i-1]+(h/2)*k24 
    
    k31=px2
    k32=py2
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-6*((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            dt=-x[i-1]/k1
            Y[i]=(y[i-1]+k2*dt)
            PY[i]=(py[i-1]+k4*dt)
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=1)
    
i=0
x[i]=0
y[i]=0.02
py[i]=0
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(4*(y[i]**3)))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=n:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-6*(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    px1=px[i-1]+(h/2)*k13
    py1=py[i-1]+(h/2)*k14
    
    k21=px1
    k22=py1
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-6*((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    px2=px[i-1]+(h/2)*k23
    py2=py[i-1]+(h/2)*k24 
    
    k31=px2
    k32=py2
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-6*((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            dt=-x[i-1]/k1
            Y[i]=(y[i-1]+k2*dt)
            PY[i]=(py[i-1]+k4*dt)
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=1)
i=0
x[i]=0
y[i]=0.04
py[i]=0
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(4*(y[i]**3)))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=n:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-6*(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    px1=px[i-1]+(h/2)*k13
    py1=py[i-1]+(h/2)*k14
    
    k21=px1
    k22=py1
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-6*((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    px2=px[i-1]+(h/2)*k23
    py2=py[i-1]+(h/2)*k24 
    
    k31=px2
    k32=py2
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-6*((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            dt=-x[i-1]/k1
            Y[i]=(y[i-1]+k2*dt)
            PY[i]=(py[i-1]+k4*dt)
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=1)

i=0
x[i]=0
y[i]=0.03
py[i]=0
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(4*(y[i]**3)))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=n:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-6*(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    px1=px[i-1]+(h/2)*k13
    py1=py[i-1]+(h/2)*k14
    
    k21=px1
    k22=py1
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-6*((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    px2=px[i-1]+(h/2)*k23
    py2=py[i-1]+(h/2)*k24 
    
    k31=px2
    k32=py2
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-6*((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            dt=-x[i-1]/k1
            Y[i]=(y[i-1]+k2*dt)
            PY[i]=(py[i-1]+k4*dt)
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=1)
    
i=0
x[i]=0
y[i]=0.025
py[i]=0
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(4*(y[i]**3)))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=n:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-6*(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    px1=px[i-1]+(h/2)*k13
    py1=py[i-1]+(h/2)*k14
    
    k21=px1
    k22=py1
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-6*((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    px2=px[i-1]+(h/2)*k23
    py2=py[i-1]+(h/2)*k24 
    
    k31=px2
    k32=py2
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-6*((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            dt=-x[i-1]/k1
            Y[i]=(y[i-1]+k2*dt)
            PY[i]=(py[i-1]+k4*dt)
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=1)
    
i=0
x[i]=0
y[i]=-0.025
py[i]=0
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(4*(y[i]**3)))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=n:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-6*(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    px1=px[i-1]+(h/2)*k13
    py1=py[i-1]+(h/2)*k14
    
    k21=px1
    k22=py1
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-6*((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    px2=px[i-1]+(h/2)*k23
    py2=py[i-1]+(h/2)*k24 
    
    k31=px2
    k32=py2
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-6*((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            dt=-x[i-1]/k1
            Y[i]=(y[i-1]+k2*dt)
            PY[i]=(py[i-1]+k4*dt)
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=1)
    
i=0
x[i]=0
y[i]=-0.03
py[i]=0
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(4*(y[i]**3)))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=n:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-6*(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    px1=px[i-1]+(h/2)*k13
    py1=py[i-1]+(h/2)*k14
    
    k21=px1
    k22=py1
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-6*((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    px2=px[i-1]+(h/2)*k23
    py2=py[i-1]+(h/2)*k24 
    
    k31=px2
    k32=py2
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-6*((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            dt=-x[i-1]/k1
            Y[i]=(y[i-1]+k2*dt)
            PY[i]=(py[i-1]+k4*dt)
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=1)
    
i=0
x[i]=0
y[i]=-0.04
py[i]=0
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(4*(y[i]**3)))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=n:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-6*(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    px1=px[i-1]+(h/2)*k13
    py1=py[i-1]+(h/2)*k14
    
    k21=px1
    k22=py1
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-6*((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    px2=px[i-1]+(h/2)*k23
    py2=py[i-1]+(h/2)*k24 
    
    k31=px2
    k32=py2
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-6*((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            dt=-x[i-1]/k1
            Y[i]=(y[i-1]+k2*dt)
            PY[i]=(py[i-1]+k4*dt)
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=1)
plt.savefig("D:/temp8.png")
    
plt.show()
# Out:
# 0.04039801975344831
# 0.04363484845854286
# 0.044721359549995794
# 0.03959797974644667
# 0.011999999999999997
# 0.031496031496047246
# 0.036228441865473596
# 0.037914377220257756
# 0.034756294393965534
# 0.025612496949731396

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy import optimize, special
from numpy import *
from pylab import *
import decimal
import math
E=1/5000
plt.style.use("seaborn-whitegrid")
n=500000
h=5000/n
x=np.zeros(n+1,dtype='float64')
y=np.zeros(n+1,dtype='float64')
px=np.zeros(n+1,dtype='float64')
py=np.zeros(n+1,dtype='float64')
Y=np.zeros(n+1,dtype='float64')
PY=np.zeros(n+1,dtype='float64')

pyk=-0.06
while pyk<0.03: 

    i=0
    x[i]=0
    y[i]=pyk
    py[i]=0
    px[i]=((32*E-16*(py[i]**2)-16*(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(32*(y[i]**3)/3))**(1/2))/4
    i=i+1
    J=0
    print(px[0])

        
    while i<=n:
        k11=px[i-1]
        k12=py[i-1]
        k13=(-1)*x[i-1]-(1/8)*x[i-1]*y[i-1]
        k14=(-1/16)*y[i-1]-(1/16)*(x[i-1]**2)-(y[i-1]**2)
    
        x1=x[i-1]+(h/2)*k11
        y1=y[i-1]+(h/2)*k12
        px1=px[i-1]+(h/2)*k13
        py1=py[i-1]+(h/2)*k14
    
        k21=px1
        k22=py1
        k23=(-1)*x1-(1/8)*(x1)*(y1)
        k24=(-1/16)*y1-(1/16)*((x1)**2)-((y1)**2)
        x2=x[i-1]+(h/2)*k21
        y2=y[i-1]+(h/2)*k22
        px2=px[i-1]+(h/2)*k23
        py2=py[i-1]+(h/2)*k24 
    
        k31=px2
        k32=py2
        k33=(-1)*x2-(1/8)*(x2)*(y2)
        k34=(-1/16)*y2-(1/16)*((x2)**2)-((y2)**2)
    
        x3=x[i-1]+h*k31
        y3=y[i-1]+h*k32
   
    
        k41=px[i-1]+h*k33
        k42=py[i-1]+h*k34 
        k43=(-1)*x3-(1/8)*(x3)*(y3)
        k44=(-1/16)*y3-(1/16)*((x3)**2)-((y3)**2)
    
        k1=(1/6)*(k11+2*k21+2*k31+k41)
        k2=(1/6)*(k12+2*k22+2*k32+k42)
        k3=(1/6)*(k13+2*k23+2*k33+k43)
        k4=(1/6)*(k14+2*k24+2*k34+k44)
        x[i]=x[i-1]+k1*h
        y[i]=y[i-1]+k2*h 
        px[i]=px[i-1]+k3*h
        py[i]=py[i-1]+k4*h
    
    
        if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
                dt=-x[i-1]/k1
                Y[i]=(y[i-1]+k2*dt)
                PY[i]=(py[i-1]+k4*dt)
                i=i+1
        else:
                Y[i]=0
                PY[i]=0
                i=i+1
    else :           
        plt.scatter(Y,PY,s=0.1)
        pyk=pyk+0.001
    
else:
    print(pyk)
plt.savefig("D:/temp11.png")    
plt.show()
# Out:
# 0.01786057109949175
# 0.017870557723063188
# 0.017883642432867716
# 0.01789970670150771
# 0.01791863090008088
# 0.01794029449776861
# 0.01796457625439576
# 0.017991354405195108
# 0.01802050683711939
# 0.018051911256152353
# 0.018085445345175588
# 0.01812098691204943
# 0.018158414027662217
# 0.018197605153792446
# 0.01823843926071161
# 0.018280795934531954
# 0.018324555474371906
# 0.018369598979473305
# 0.01841580842645796
# 0.018463066736957145
# 0.01851125783588643
# 0.01856026670067001
# 0.018609979401743932
# 0.018660283134686536
# 0.018711066244337868
# 0.018762218241277693
# 0.01881362981103505
# 0.018865192816401324
# 0.01891680029321379
# 0.018968346439968527
# 0.019019726601610238
# 0.01907083724783297
# 0.019121575946209734
# 0.019171841330451286
# 0.01922153306407513
# 0.019270551799745298
# 0.019318799134521798
# 0.019366177561236327
# 0.019412590416187807
# 0.019457941823327565
# 0.019502136635080103
# 0.019545080369920885
# 0.019586679146807916
# 0.019626839616538713
# 0.019665468890079044
# 0.019702474463883974
# 0.019737764142205506
# 0.019771245956354565
# 0.019802828080857544
# 0.019832418746419545
# 0.01985992614957736
# 0.019885258358894913
# 0.019908323217522197
# 0.01992902824190549
# 0.01994728051640123
# 0.019962986583508324
# 0.01997605232939348
# 0.019986382864340412
# 0.01999388239770689
# 0.019998454106922033
# 0.02
# 0.019998420770984227
# 0.019993615647667797
# 0.01998548223085948
# 0.019973916324379986
# 0.01995881175487826
# 0.01994006018045081
# 0.01991755088692717
# 0.0198911705705488
# 0.019860803105614836
# 0.019826329295493234
# 0.019787626605196153
# 0.019744568873490246
# 0.019697026002250522
# 0.01964486362046493
# 0.01958794271994892
# 0.01952611925942616
# 0.01945924373316359
# 0.019387160699803358
# 0.01930970826639629
# 0.01922671752189298
# 0.019138011913466868
# 0.019043406558001463
# 0.018942707479836837
# 0.018835710764396437
# 0.018722201615550802
# 0.018601953302453653
# 0.018474725979023335
# 0.018340265356131927
# 0.018198301202767976
# 0.03000000000000007
