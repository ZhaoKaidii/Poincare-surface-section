# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy import optimize, special
from numpy import *
from pylab import *
import decimal
import math
E=1/16
plt.style.use("seaborn-whitegrid")
n=500000
h=1500/n
x=np.zeros(n+1,dtype='float64')
y=np.zeros(n+1,dtype='float64')
px=np.zeros(n+1,dtype='float64')
py=np.zeros(n+1,dtype='float64')
Y=np.zeros(n+1,dtype='float64')
PY=np.zeros(n+1,dtype='float64')
i=0
x[i]=0
y[i]=0
py[i]=0.02
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(2*(y[i]**3)/3))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=500000:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    
    
    k21=px[i-1]+(h/2)*k13
    k22=py[i-1]+(h/2)*k14
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    
    
    k31=px[i-1]+(h/2)*k23
    k32=py[i-1]+(h/2)*k24 
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            Y[i]=(y[i]+y[i-1])/2
            PY[i]=(py[i]+py[i-1])/2
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=3)

i=0
x[i]=0
y[i]=0
py[i]=0.06
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(2*(y[i]**3)/3))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=500000:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    
    
    k21=px[i-1]+(h/2)*k13
    k22=py[i-1]+(h/2)*k14
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    
    
    k31=px[i-1]+(h/2)*k23
    k32=py[i-1]+(h/2)*k24 
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            Y[i]=(y[i]+y[i-1])/2
            PY[i]=(py[i]+py[i-1])/2
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=3)
i=0
x[i]=0
y[i]=0
py[i]=0.11
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(2*(y[i]**3)/3))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=500000:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    
    
    k21=px[i-1]+(h/2)*k13
    k22=py[i-1]+(h/2)*k14
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    
    
    k31=px[i-1]+(h/2)*k23
    k32=py[i-1]+(h/2)*k24 
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            Y[i]=(y[i]+y[i-1])/2
            PY[i]=(py[i]+py[i-1])/2
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=3)

i=0
x[i]=0
y[i]=0
py[i]=0.16
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(2*(y[i]**3)/3))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=500000:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    
    
    k21=px[i-1]+(h/2)*k13
    k22=py[i-1]+(h/2)*k14
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    
    
    k31=px[i-1]+(h/2)*k23
    k32=py[i-1]+(h/2)*k24 
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            Y[i]=(y[i]+y[i-1])/2
            PY[i]=(py[i]+py[i-1])/2
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=3)
    
i=0
x[i]=0
y[i]=0
py[i]=0.21
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(2*(y[i]**3)/3))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=500000:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    
    
    k21=px[i-1]+(h/2)*k13
    k22=py[i-1]+(h/2)*k14
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    
    
    k31=px[i-1]+(h/2)*k23
    k32=py[i-1]+(h/2)*k24 
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            Y[i]=(y[i]+y[i-1])/2
            PY[i]=(py[i]+py[i-1])/2
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=3)
    
i=0
x[i]=0
y[i]=0
py[i]=-0.21
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(2*(y[i]**3)/3))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=500000:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    
    
    k21=px[i-1]+(h/2)*k13
    k22=py[i-1]+(h/2)*k14
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    
    
    k31=px[i-1]+(h/2)*k23
    k32=py[i-1]+(h/2)*k24 
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            Y[i]=(y[i]+y[i-1])/2
            PY[i]=(py[i]+py[i-1])/2
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=3)
    
i=0
x[i]=0
y[i]=0
py[i]=-0.16
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(2*(y[i]**3)/3))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=500000:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    
    
    k21=px[i-1]+(h/2)*k13
    k22=py[i-1]+(h/2)*k14
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    
    
    k31=px[i-1]+(h/2)*k23
    k32=py[i-1]+(h/2)*k24 
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            Y[i]=(y[i]+y[i-1])/2
            PY[i]=(py[i]+py[i-1])/2
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=3)
    
i=0
x[i]=0
y[i]=0
py[i]=-0.11
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(2*(y[i]**3)/3))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=500000:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    
    
    k21=px[i-1]+(h/2)*k13
    k22=py[i-1]+(h/2)*k14
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    
    
    k31=px[i-1]+(h/2)*k23
    k32=py[i-1]+(h/2)*k24 
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            Y[i]=(y[i]+y[i-1])/2
            PY[i]=(py[i]+py[i-1])/2
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=3)
    
i=0
x[i]=0
y[i]=0
py[i]=-0.06
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(2*(y[i]**3)/3))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=500000:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    
    
    k21=px[i-1]+(h/2)*k13
    k22=py[i-1]+(h/2)*k14
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    
    
    k31=px[i-1]+(h/2)*k23
    k32=py[i-1]+(h/2)*k24 
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            Y[i]=(y[i]+y[i-1])/2
            PY[i]=(py[i]+py[i-1])/2
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=3)
    
i=0
x[i]=0
y[i]=0
py[i]=-0.02
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(2*(y[i]**3)/3))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=500000:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    
    
    k21=px[i-1]+(h/2)*k13
    k22=py[i-1]+(h/2)*k14
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    
    
    k31=px[i-1]+(h/2)*k23
    k32=py[i-1]+(h/2)*k24 
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            Y[i]=(y[i]+y[i-1])/2
            PY[i]=(py[i]+py[i-1])/2
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=3)
plt.show()
# Out:
# 0.35298725189445584
# 0.3484250278036869
# 0.33600595232822883
# 0.3152776554086889
# 0.2844292530665578
# 0.2844292530665578
# 0.3152776554086889
# 0.33600595232822883
# 0.3484250278036869
# 0.35298725189445584

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy import optimize, special
from numpy import *
from pylab import *
import decimal
import math
E=1/12
plt.style.use("seaborn-whitegrid")
n=500000
h=1500/n
x=np.zeros(n+1,dtype='float64')
y=np.zeros(n+1,dtype='float64')
px=np.zeros(n+1,dtype='float64')
py=np.zeros(n+1,dtype='float64')
Y=np.zeros(n+1,dtype='float64')
PY=np.zeros(n+1,dtype='float64')
i=0
x[i]=0
y[i]=0
py[i]=0.02
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(2*(y[i]**3)/3))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=500000:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    
    
    k21=px[i-1]+(h/2)*k13
    k22=py[i-1]+(h/2)*k14
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    
    
    k31=px[i-1]+(h/2)*k23
    k32=py[i-1]+(h/2)*k24 
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            Y[i]=(y[i]+y[i-1])/2
            PY[i]=(py[i]+py[i-1])/2
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=3)

i=0
x[i]=0
y[i]=0
py[i]=0.06
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(2*(y[i]**3)/3))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=500000:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    
    
    k21=px[i-1]+(h/2)*k13
    k22=py[i-1]+(h/2)*k14
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    
    
    k31=px[i-1]+(h/2)*k23
    k32=py[i-1]+(h/2)*k24 
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            Y[i]=(y[i]+y[i-1])/2
            PY[i]=(py[i]+py[i-1])/2
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=3)
i=0
x[i]=0
y[i]=0
py[i]=0.11
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(2*(y[i]**3)/3))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=500000:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    
    
    k21=px[i-1]+(h/2)*k13
    k22=py[i-1]+(h/2)*k14
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    
    
    k31=px[i-1]+(h/2)*k23
    k32=py[i-1]+(h/2)*k24 
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            Y[i]=(y[i]+y[i-1])/2
            PY[i]=(py[i]+py[i-1])/2
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=3)

i=0
x[i]=0
y[i]=0
py[i]=0.16
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(2*(y[i]**3)/3))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=500000:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    
    
    k21=px[i-1]+(h/2)*k13
    k22=py[i-1]+(h/2)*k14
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    
    
    k31=px[i-1]+(h/2)*k23
    k32=py[i-1]+(h/2)*k24 
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            Y[i]=(y[i]+y[i-1])/2
            PY[i]=(py[i]+py[i-1])/2
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=3)
    
i=0
x[i]=0
y[i]=0
py[i]=0.21
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(2*(y[i]**3)/3))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=500000:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    
    
    k21=px[i-1]+(h/2)*k13
    k22=py[i-1]+(h/2)*k14
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    
    
    k31=px[i-1]+(h/2)*k23
    k32=py[i-1]+(h/2)*k24 
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            Y[i]=(y[i]+y[i-1])/2
            PY[i]=(py[i]+py[i-1])/2
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=3)
    
i=0
x[i]=0
y[i]=0
py[i]=-0.21
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(2*(y[i]**3)/3))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=500000:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    
    
    k21=px[i-1]+(h/2)*k13
    k22=py[i-1]+(h/2)*k14
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    
    
    k31=px[i-1]+(h/2)*k23
    k32=py[i-1]+(h/2)*k24 
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            Y[i]=(y[i]+y[i-1])/2
            PY[i]=(py[i]+py[i-1])/2
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=3)
    
i=0
x[i]=0
y[i]=0
py[i]=-0.16
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(2*(y[i]**3)/3))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=500000:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    
    
    k21=px[i-1]+(h/2)*k13
    k22=py[i-1]+(h/2)*k14
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    
    
    k31=px[i-1]+(h/2)*k23
    k32=py[i-1]+(h/2)*k24 
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            Y[i]=(y[i]+y[i-1])/2
            PY[i]=(py[i]+py[i-1])/2
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=3)
    
i=0
x[i]=0
y[i]=0
py[i]=-0.11
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(2*(y[i]**3)/3))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=500000:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    
    
    k21=px[i-1]+(h/2)*k13
    k22=py[i-1]+(h/2)*k14
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    
    
    k31=px[i-1]+(h/2)*k23
    k32=py[i-1]+(h/2)*k24 
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            Y[i]=(y[i]+y[i-1])/2
            PY[i]=(py[i]+py[i-1])/2
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=3)
    
i=0
x[i]=0
y[i]=0
py[i]=-0.06
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(2*(y[i]**3)/3))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=500000:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    
    
    k21=px[i-1]+(h/2)*k13
    k22=py[i-1]+(h/2)*k14
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    
    
    k31=px[i-1]+(h/2)*k23
    k32=py[i-1]+(h/2)*k24 
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            Y[i]=(y[i]+y[i-1])/2
            PY[i]=(py[i]+py[i-1])/2
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=3)
    
i=0
x[i]=0
y[i]=0
py[i]=-0.02
px[i]=(2*E-(py[i]**2)-(x[i]**2)-(y[i]**2)-2*(x[i]**2)*y[i]-(2*(y[i]**3)/3))**(1/2)
i=i+1
J=0
print(px[0])

        
while i<=500000:
    k11=px[i-1]
    k12=py[i-1]
    k13=(-1)*x[i-1]-2*x[i-1]*y[i-1]
    k14=(-1)*y[i-1]-(x[i-1]**2)-(y[i-1]**2)
    
    x1=x[i-1]+(h/2)*k11
    y1=y[i-1]+(h/2)*k12
    
    
    k21=px[i-1]+(h/2)*k13
    k22=py[i-1]+(h/2)*k14
    k23=(-1)*x1-2*(x1)*(y1)
    k24=(-1)*y1-((x1)**2)-((y1)**2)
    x2=x[i-1]+(h/2)*k21
    y2=y[i-1]+(h/2)*k22
    
    
    k31=px[i-1]+(h/2)*k23
    k32=py[i-1]+(h/2)*k24 
    k33=(-1)*x2-2*(x2)*(y2)
    k34=(-1)*y2-((x2)**2)-((y2)**2)
    
    x3=x[i-1]+h*k31
    y3=y[i-1]+h*k32
   
    
    k41=px[i-1]+h*k33
    k42=py[i-1]+h*k34 
    k43=(-1)*x3-2*(x3)*(y3)
    k44=(-1)*y3-((x3)**2)-((y3)**2)
    k1=(1/6)*(k11+2*k21+2*k31+k41)
    k2=(1/6)*(k12+2*k22+2*k32+k42)
    k3=(1/6)*(k13+2*k23+2*k33+k43)
    k4=(1/6)*(k14+2*k24+2*k34+k44)
    x[i]=x[i-1]+k1*h
    y[i]=y[i-1]+k2*h 
    px[i]=px[i-1]+k3*h
    py[i]=py[i-1]+k4*h
    
    
    if x[i]*x[i-1]<0 and px[i]>0 and px[i-1]>0:
            Y[i]=(y[i]+y[i-1])/2
            PY[i]=(py[i]+py[i-1])/2
            i=i+1
    else:
            Y[i]=0
            PY[i]=0
            i=i+1
else :           
    plt.scatter(Y,PY,s=3)
plt.show()
# Out:
# 0.40775809822328074
# 0.4038151392242082
# 0.3931496746363485
# 0.37558842722675395
# 0.3500952251411988
# 0.3500952251411988
# 0.37558842722675395
# 0.3931496746363485
# 0.4038151392242082
# 0.40775809822328074
